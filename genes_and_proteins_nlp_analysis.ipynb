# %%
import json
import pandas as pd
import re
from tqdm import tqdm

# %%
# !pip3 install flair
# !pip3 install scispacy==0.2.5
# !pip3 install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.5/en_core_sci_sm-0.2.5.tar.gz
# !python3.8 -m spacy download en_core_web_sm
# !pip3 install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
# !pip3 install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.0/en_core_sci_sm-0.5.0.tar.gz

# %%
from flair.models import MultiTagger
from flair.data import Sentence
from flair.tokenization import SciSpacyTokenizer, SciSpacySentenceSplitter

# %%
texts_path = 'test.json'
ttd_path = 'P1-06-Target_disease.txt'

# %%
with open(texts_path, 'r') as f:
    disease_text_data = json.load(f)
    
with open(ttd_path, 'r') as f:
    ttd = f.read()

# %% [markdown]
# ## General plan
#
# - Get dictionary mapping diseases to set of genes/proteins extracted from sentences
# - Get dictionary mapping diseases to set of genes/proteins extracted from TTD
# - Find each disease from the first dict in the second dict and find intersection of the disease genes

# %% [markdown]
# ### 1. Extract genes from texts for each disease with flair library to get dictionaty mapping a disease to genes

# %%
tagger = MultiTagger.load("hunflair-gene")
splitter = SciSpacySentenceSplitter()
# Out:
# 2022-09-03 21:27:40,603 loading file /home/ed/.flair/models/hunflair-gene-full-v1.0.pt
# 2022-09-03 21:27:43,298 SequenceTagger predicts: Dictionary with 8 tags: <unk>, O, S-Gene, B-Gene, I-Gene, E-Gene, <START>, <STOP>

# %%
disease2genes = dict((disease, set()) for disease in disease_text_data)
    
for disease, texts in tqdm(disease_text_data.items()):
    for text in texts:
        sentences = splitter.split(text)
        tagger.predict(sentences)#, use_tokenizer=SciSpacyTokenizer())
        for sentence in sentences:
            for gene in sentence.get_spans("hunflair-gene"):
                unified_gene_name = re.sub(r'[^ \w+]', '', gene.text)
                disease2genes[disease].add(unified_gene_name)

# %%
disease2genes
# Out:
# {'Bacterial pneumonia': {'ATPase',
#   'Bacterial protein A',
#   'CD45',
#   'DNA methyltransferases',
#   'FIP3',
#   'Hsp70',
#   'LPS receptor',
#   'NS1B',
#   'NS4A',
#   'P  glycoprotein',
#   'Phosphatases',
#   'Proteases',
#   'Sulfolipase A2',
#   'TMY',
#   'TNF  alpha',
#   'TNF family',
#   'VAMP',
#   'anti  phosphatase',
#   'big gun  protein phosphatases',
#   'enzymes',
#   'phosphatidylinositol 3kinase',
#   'protease',
#   'proteases',
#   'protein phosphatases',
#   'tryptophan dehydrogenase II',
#   'tyrosine kinases',
#   'viral proteases'},
#  'Cutaneous leishmaniasis': {'Anti  IgM antibody',
#   'C5b  RFLP',
#   'C5b  RFLP2',
#   'CA',
#   'CD19',
#   'CD28',
#   'Class II antigens',
#   'Cytotoxic antigen',
#   'EBOV1',
#   'FCR1',
#   'FCR2',
#   'Hemoglobin',
#   'IL2 and 4',
#   'IgA  alpha',
#   'IgG',
#   'L  cART',
#   'L4 gene',
#   'LPL',
#   'LRRK2',
#   'MHC',
#   'MLL',
#   'Mucin',
#   'NGF',
#   'NTCA receptor',
#   'Nk42',
#   'PKA',
#   'RAS',
#   'T  beta1',
#   'T  beta2',
#   'T cell receptor',
#   'TCR',
#   'TGF  beta',
#   'TLA',
#   'TLA+cut2',
#   'TLR3',
#   'TLR3 receptor',
#   'TLR7',
#   'TLR8',
#   'TNF  a',
#   'TNF  alpha',
#   'Tubulin',
#   'VDRL',
#   'Yes',
#   'cut2',
#   'enzyme kinase tyrosine phosphatase',
#   'immunoglobulins',
#   'kinase',
#   'natural growth factor  2',
#   'proteases',
#   'protein kinase',
#   'urokinase'},
#  'Dedifferentiated liposarcoma': {'BAB1',
#   'BAP6',
#   'BRCA2',
#   'CD133',
#   'CD1d',
#   'CD20',
#   'CD20 receptor',
#   'CD38',
#   'CD73',
#   'CD74',
#   'DLL4',
#   'DNA polymerase  2',
#   'Dmbr1',
#   'EGFR',
#   'HSP1',
#   'HSP75',
#   'IKK kinase',
#   'K  ras',
#   'KDR',
#   'MMP9',
#   'NFK',
#   'NGF',
#   'PI3k',
#   'PIP3 K',
#   'PVF2',
#   'SOD1',
#   'TET receptors',
#   'TGF  β',
#   'TSC2',
#   'beta  catenin',
#   'c  Myc',
#   'collagen',
#   'collagenase',
#   'epidermal growth factor receptor',
#   'myostatin',
#   'p16INK4A',
#   'p16ink4a',
#   'phosphoinositide 3kinase',
#   'protease protease',
#   'protein tyrosine kinases',
#   'ribosomal protein factor K subunit'},
#  'Methylmalonic acidemia': {'ARB1',
#   'ATP synthase',
#   'BIF1',
#   'CACNA1',
#   'CEA',
#   'CYP1A2',
#   'CYP1C1',
#   'CYP1C5',
#   'CYP2D6',
#   'Corticotrophin releasing factor receptor',
#   'GPR107',
#   'GPR83',
#   'GPR94',
#   'HIS1',
#   'HLA  B27',
#   'HMG CoA reductase',
#   'HMG CoR',
#   'HMO1',
#   'MCAF',
#   'MECP2',
#   'MELR1',
#   'MME',
#   'MMP1',
#   'MMP16',
#   'MMP3',
#   'MMP31',
#   'MMP9',
#   'MMT',
#   'MPN',
#   'MRR',
#   'MTF',
#   'MTFR',
#   'MTHFR',
#   'MTR',
#   'Malonyl  CoA synthase',
#   'Melanin',
#   'Methyl  malonyl  CoA synthetase',
#   'Methylmalonic Acetylcholinesterase',
#   'Methyltetrahydrofolate receptor',
#   'NTRC',
#   'PTH',
#   'Tachykinins',
#   'Thymidylate synthase',
#   'acetoacetate synthase',
#   'enzyme',
#   'malate dehydrogenase',
#   'malonyl  CoA synthase',
#   'me',
#   'methylcatechol1O  methyltransferase',
#   'methylmalonylase',
#   'methyltransferase',
#   'methyltransferases',
#   'potassium channels',
#   'protease',
#   'protein tyrosine kinase'},
#  'Conjunctival melanoma': {'ALK',
#   'APC',
#   'APOBEC3A',
#   'APOP3A',
#   'Abl',
#   'Akt',
#   'B7H1',
#   'BCL2',
#   'BCR',
#   'BRAF',
#   'BRCA1  2',
#   'CD38',
#   'CTLA4',
#   'DGF8',
#   'DNA polymerase',
#   'EGFR',
#   'EPM',
#   'ERB',
#   'G  protein coupled receptors',
#   'HER2',
#   'KIT',
#   'LIF',
#   'MAP1A',
#   'MAP2B',
#   'MAPK',
#   'MBL1',
#   'MELANOGENHDA1',
#   'MET',
#   'NEMO',
#   'NGF',
#   'PD  L1',
#   'PD1',
#   'PDGFBB',
#   'PDGFRα',
#   'PI3K',
#   'PIK3CA',
#   'PSA',
#   'RPE',
#   'T antigen',
#   'TGN1',
#   'VEGF',
#   'VLA',
#   'Wnt',
#   'Yes',
#   'dfr8',
#   'human epidermal growth factor receptor',
#   'melanopsin',
#   'p53'},
#  'Acute myocardial infarction': {'2 H+ATPase 3',
#   'ACE',
#   'ACK1',
#   'AMP  activated protein kinase',
#   'AMPK',
#   'ARB',
#   'ATPases',
#   'ApoB  I',
#   'Apolipoproteins',
#   'B  cell lymphoma molecule',
#   'C  reactive protein',
#   'CCL2',
#   'CCR5',
#   'CD19',
#   'CD38',
#   'CD38specific Natural Killer  NK  cell  specific antibody',
#   'COX',
#   'CRP',
#   'CXCR4',
#   'CYP22B1',
#   'CYP2D6',
#   'Cystatin C',
#   'E  selectin',
#   'EDLR',
#   'EGF',
#   'FGF',
#   'FGF11',
#   'FGF6',
#   'FGF8',
#   'FGF9',
#   'GSK3B',
#   'GSK3B kinase',
#   'IL6',
#   'Myc',
#   'Myeloperoxidase',
#   'NDE2 transporter',
#   'NDR2',
#   'NF  kB',
#   'P  glycoprotein',
#   'P2X7',
#   'PDGF1',
#   'PGT2',
#   'PKB',
#   'Protein kinase C and T',
#   'Pumilin',
#   'RNA polymerase family',
#   'TACE',
#   'TGFA',
#   'TNF',
#   'TNF  ARAX',
#   'TNF  related target enzyme',
#   'TNFα',
#   'TRPV1',
#   'Vascular smooth muscle actin',
#   'Yes',
#   'actin',
#   'angiotensin  converting enzyme',
#   'angiotensin II',
#   'angiotensin II receptor',
#   'angiotensin receptor',
#   'calcium channels',
#   'calmodulin',
#   'cardiac troponins',
#   'cell signaling protein',
#   'chymotrypsin',
#   'collagen',
#   'collagenase',
#   'cystatin',
#   'cytokines',
#   'eGF',
#   'endothelial growth factor',
#   'endothelium  derived relaxin',
#   'fibrin',
#   'fibronectin',
#   'inflammatory cytokines',
#   'insulin',
#   'kinase',
#   'lipoprotein lipase',
#   'matrix metalloproteinase',
#   'myosin',
#   'p70 serine  threonine Kinase',
#   'p75',
#   'p90',
#   'p90d',
#   'platelet  derived growth factor1',
#   'prolactin 2',
#   'proline hydrolases',
#   'protease',
#   'proteases',
#   'proteolytases',
#   'receptor tyrosine kinase',
#   'tPA',
#   'thrombin',
#   'vascular endothelial growth factor',
#   'β  catenin'},
#  'Psoriatic arthritis': {'39  43  Nitrosynthetase',
#   'C  jun  A',
#   'C3endothelial cell receptor',
#   'CCR1',
#   'CCR2',
#   'CD105',
#   'CD105mediated',
#   'CD107',
#   'CD107mediated',
#   'CDK3  4',
#   'DNA polymerase',
#   'DPP4',
#   'ECOR1',
#   'ECR',
#   'EGRF',
#   'ERK',
#   'F  actin',
#   'FASA',
#   'FASL',
#   'FASP2',
#   'FBP1',
#   'FC',
#   'FVIII  vLA4 family',
#   'FasL',
#   'Follicle stimulation factors',
#   'GM  CSF  related 1',
#   'GPCR',
#   'GPCR transcription factor',
#   'IL1',
#   'IL12A',
#   'IL1β',
#   'IL2',
#   'IL2R',
#   'IL3 receptor',
#   'IL33',
#   'IL4',
#   'IL5',
#   'IL6',
#   'IL8',
#   'IR',
#   'IgG',
#   'Interferon beta',
#   'JAK',
#   'LKB',
#   'MCP1',
#   'MCP2',
#   'MCP3',
#   'MIP10',
#   'MIP2',
#   'MIP4',
#   'MIP9',
#   'MLNase',
#   'Mature Insulin Receptor',
#   'Metallo  beta  lactamase',
#   'N  acetylaspartyl  glycoprotein II',
#   'NAgpII',
#   'NF  kappa alpha',
#   'Natural small GTPases',
#   'P  selectin family',
#   'PDL1',
#   'PSA',
#   'PSR2',
#   'PSR5',
#   'Protein kinase',
#   'RANTES',
#   'Ras',
#   'Receptor Activated T Cell Enolase',
#   'SOD2',
#   'SP5',
#   'SRX',
#   'T4 immune complex',
#   'TGF',
#   'TNF',
#   'TNF  Aβ',
#   'TNF  CCR  PA family',
#   'TNF  alpha',
#   'TNF  α',
#   'TNF Receptor',
#   'TNF receptor  alpha',
#   'TR',
#   'Tumor necrosis factor α',
#   'UGT 2A10',
#   'calcineurin',
#   'calcitonin',
#   'calcium  calmodulin receptor',
#   'cell surface protein 5',
#   'chemokines',
#   'collagen',
#   'collagen fibronectin complex',
#   'cytokine',
#   'cytokines',
#   'elastin',
#   'enzymes',
#   'fibrillin binding protein 1',
#   'fibronectin',
#   'insulin',
#   'interferon',
#   'interferon beta',
#   'interleukin 2',
#   'interleukin6',
#   'protease',
#   'psA',
#   'rFGF3  9',
#   'tumor necrosis factor  alpha2 beta',
#   'urokinases',
#   'vitamin D receptor'},
#  'Ataxia-telangiectasia': {'A  type tyrosine phosphatase',
#   'AAT',
#   'ADAM20',
#   'ADP  ribose  phosphate carboxylase',
#   'ALKB1',
#   'APOBEC class III transmembrane protein',
#   'APT1',
#   'APT2',
#   'ATA',
#   'ATM',
#   'ATTR',
#   'ATX',
#   'ATX1',
#   'ATXN12  16  18',
#   'ATXN3',
#   'ATXN30  32  39',
#   'ATXN6  12  11',
#   'Apolipoprotein E',
#   'AtXH',
#   'AtaR',
#   'Atx2',
#   'Atx3',
#   'C  Raf',
#   'C2H4based',
#   'Caspases',
#   'FMRP',
#   'FMRP1',
#   'FMRP2',
#   'FOXO',
#   'FOXO3',
#   'FOXO4',
#   'GATA2',
#   'GPR32',
#   'H3K9me3',
#   'HER4',
#   'HIF2B',
#   'MAP1K  2  3  4  6  7  8  9',
#   'MAPK kinase family',
#   'NAM3',
#   'Nf  ATXN16',
#   'Nrf2',
#   'Oxytocin',
#   'POT1',
#   'PTC1',
#   'SOD1',
#   'T  DNA binding protein',
#   'TBNP',
#   'TBNP  ATXN16',
#   'TBNP  ATXN60',
#   'TBP1',
#   'TBP4',
#   'TERT',
#   'TSC1',
#   'TTR',
#   'Tau',
#   'Yes',
#   'ataxia  telangiectasia ',
#   'c  Met',
#   'caspase',
#   'caspases',
#   'glycogen synthase kinase 3c',
#   'mURA1',
#   'mURA2',
#   'p21',
#   'p53',
#   'pRb',
#   'protein kinase C',
#   'protein polymerase 1',
#   'tau',
#   'telomerase',
#   'thefoxo'},
#  'Chronic kidney disease': {'AFL',
#   'Amylin',
#   'BMP',
#   'CCL20',
#   'CPT1',
#   'EYPTI2',
#   'EYPTI3',
#   'FK506 receptors',
#   'GPCR',
#   'GPCRs',
#   'GSH  GSSG  protein complex',
#   'HDL',
#   'JAK2',
#   'NGF',
#   'NHE1NHE1',
#   'Rheb',
#   'Rho GTPase',
#   'SIRT1',
#   'albumin',
#   'alpha fetoprotein',
#   'bovine serum albumin',
#   'calcitonin',
#   'glomerulocyte activating factor',
#   'hemoglobin',
#   'insulin',
#   'insulin receptor',
#   'insulin receptors',
#   'interferon  gamma',
#   'interleukin12',
#   'plasmin',
#   'protein kinase',
#   'rHylin',
#   'urokinase'},
#  'Cholangio carcinoma': {'APC',
#   'BRCA1',
#   'BRCA1 and 2',
#   'BRCA3',
#   'CD30',
#   'CD30deficiency',
#   'CD30related',
#   'CDKN2A',
#   'CEA2',
#   'CEA3',
#   'CXCL12',
#   'Cytokines',
#   'E  selectin',
#   'FANC',
#   'FASNA',
#   'FUS',
#   'GAL3',
#   'GFR',
#   'HIF1 alpha',
#   'Ig5',
#   'Ig7',
#   'KRNE',
#   'LAP1',
#   'LIF',
#   'MALT',
#   'MB  MHC3',
#   'MCH1',
#   'MCHC1',
#   'MCR1',
#   'MDR',
#   'MECP2',
#   'MHC  I',
#   'MHC  II',
#   'MHC  III',
#   'MHC  binding proteins',
#   'MHC class I',
#   'MMPs',
#   'P  glycoprotein',
#   'P16',
#   'PARP',
#   'PLCB',
#   'PUC1',
#   'Polyponin',
#   'RAS',
#   'RB1',
#   'SLC26A10',
#   'SOD1',
#   'TERT',
#   'TIGIT',
#   'alpha helicase',
#   'cGMP responsive regulator of nuclear export',
#   'chapt8',
#   'cholesteryl ester transfer protein',
#   'lipocalin A',
#   'mitochondrial respiratory chain',
#   'p13',
#   'p16',
#   'p19',
#   'p30',
#   'p32',
#   'p53'},
#  'Werner syndrome': {'Alpha1 antitrypsin',
#   'Androgen receptor',
#   'BASKAP1',
#   'CR  K11',
#   'CR  K11 protein',
#   'DMDM1',
#   'DPP4',
#   'FAS',
#   'FMR1',
#   'FOXO3A',
#   'FOXO3B',
#   'FOXO3C',
#   'GABA  A beta',
#   'GABA  E beta receptors',
#   'HEML1',
#   'HSP90',
#   'Hsp90',
#   'IL6',
#   'KSP1',
#   'LYBRA1',
#   'MHC1',
#   'MHC1  2',
#   'MTHFR',
#   'MTHFR family',
#   'N  cadherin',
#   'NMDA  Kappa opioid receptors',
#   'NPC1',
#   'Rheopsin',
#   'S100A9',
#   'S6K1',
#   'SLC6A7',
#   'SNOD2A',
#   'SOD1',
#   'SOD2',
#   'TDP41',
#   'TDP43',
#   'TGF  beta ligand receptor',
#   'TGF  β',
#   'WRNX16N',
#   'WSEN1',
#   'alpha  synuclein',
#   'alpha1antitrypsin',
#   'dad',
#   'dad 2',
#   'enzyme',
#   'fatty acid synthase',
#   'glycogen synthase',
#   'hyper  thrombomodulin',
#   'polymerase',
#   'rhodopsin',
#   'tau',
#   'thrombomodulin',
#   'tyrosine hydroxylase'},
#  'Osteoarthritis': {'ALK1',
#   'Acyl Coenzyme A reductase',
#   'Apicellular Fibroblast growth factor',
#   'Bcl2',
#   'CC3a',
#   'CD68',
#   'CGRP',
#   'COX2',
#   'CPT2',
#   'CXCL12',
#   'Cyclooxygenase2',
#   'EphA4',
#   'IL17',
#   'IL1β',
#   'IL6',
#   'Insulin',
#   'Insulin receptors',
#   'MMP7',
#   'MMP9',
#   'N  arrestin',
#   'NGF',
#   'NMDA receptor',
#   'PDZ  binding  protein',
#   'PTH1R1',
#   'PTH1Rs',
#   'Phospholipase D',
#   'Protease',
#   'Prothrombin',
#   'RhoA',
#   'SGLT2',
#   'SOD1',
#   'TGF  Beta',
#   'TGF  Beta_',
#   'TGF  beta',
#   'TGF  β',
#   'TNF',
#   'TNF family',
#   'calcitonin',
#   'chemokine',
#   'collagen',
#   'enzyme',
#   'enzymes',
#   'epinephrine receptors',
#   'glycoprotein receptor',
#   'inflammatory cytokines',
#   'osteopontin',
#   'protein phosphatases',
#   'synthase'},
#  'Interstitial cystitis': {'AP2',
#   'BMP10',
#   'Brain  derived neurotrophic factor',
#   'C  reactive protein',
#   'CD11b and 8',
#   'CD22',
#   'CEA',
#   'Caspase 6',
#   'Caspase6',
#   'FGF',
#   'FIB1',
#   'FIB2',
#   'Fibroblast Growth Factor 2',
#   'GIP family',
#   'GIP protein',
#   'GIPs',
#   'HLA DQB1  0201',
#   'HSP90',
#   'IL1',
#   'IL12',
#   'IL17P',
#   'IL1β',
#   'IL2',
#   'ILs1A',
#   'ILs7',
#   'IgA',
#   'IgE',
#   'Interleukin family',
#   'Interleukin18',
#   'Interleukin7',
#   'Interleukins2',
#   'MDA  CD15',
#   'NRP5',
#   'NRP5  6',
#   'NRP6',
#   'TGF  β',
#   'TLR5',
#   'TNF',
#   'TNF receptors',
#   'TNFα',
#   'Thrombin receptor',
#   'Tumor necrosis factor alpha',
#   'VEGF',
#   'chemokine',
#   'chemokines',
#   'cyclooxygenases',
#   'cytokine',
#   'cytokines',
#   'enzymes',
#   'human albumin',
#   'insulin',
#   'interleukin1 receptor',
#   'interleukins',
#   'serotonin receptors',
#   'sodium pump',
#   'transcription factors',
#   'tumor necrosis factor alpha'},
#  'Optic neuritis': {'Aneurin',
#   'Aneurins',
#   'CCL5',
#   'CSF',
#   'CXCL12',
#   'DCC1',
#   'GPCR',
#   'GPCR3a',
#   'GPCRs',
#   'GRP78',
#   'GSK3β',
#   'Glucoisomerases',
#   'Glycoprotein G',
#   'IL13 receptor',
#   'IL1β',
#   'LKB1',
#   'LKC1',
#   'MDRP',
#   'MHC class II',
#   'MLD  MDRP',
#   'MUC1',
#   'NER1',
#   'NFκA',
#   'NFκB',
#   'NGF',
#   'Neuraminidase',
#   'OCRF',
#   'PPAR  γ',
#   'PRL',
#   'Retinal1',
#   'TAC2',
#   'TAC3',
#   'TGF  beta',
#   'TGF  β',
#   'TGFβ',
#   'TIR1A',
#   'TNF  α',
#   'TTF1',
#   'Target  2',
#   'Tumor necrosis factor  alpha',
#   'UCP',
#   'VEGF',
#   'Yes',
#   'cytokine',
#   'cytokines',
#   'glial fibrillary acidic protein',
#   'glutamate receptors',
#   'interferon gamma',
#   'major histocompatibility complex  MHC  class I protein C4',
#   'myeloid  derived suppressor of  degeneration regulatory protein',
#   'nerve growth factor',
#   'optocorticotropin  releasing factor',
#   'p38',
#   'reverse transcriptase',
#   'tumor necrosis factor alpha'},
#  'Eosinophilic esophagitis': {'AgrA',
#   'Akt',
#   'C  reR  g',
#   'C  reactive protein',
#   'CXCL cytokines',
#   'CXCL11',
#   'CXCL12',
#   'E  CSF',
#   'E3 ligase',
#   'EOS1',
#   'EoE protein',
#   'Eosinophil receptors',
#   'Eosinophila asperagine synthase',
#   'HLA',
#   'Hp2 enzyme',
#   'IgA',
#   'IgE',
#   'IgG',
#   'IgM',
#   'MDS',
#   'MDS1',
#   'MMP2',
#   'PDE4',
#   'Tau',
#   'chemokine',
#   'cytokine',
#   'cytokines',
#   'eosinophil granulocyte colony  stimulating factor',
#   'fibronectin',
#   'immunoglobulin',
#   'immunoglobulin A',
#   'inflammatory cytokine',
#   'interleukin 18',
#   'interleukin18',
#   'lipocalin2',
#   'protein kinase1',
#   'tau'},
#  'Dermatomyositis': {'AKT',
#   'Antiproton  H+  channel',
#   'B  cell receptor',
#   'B6 nuclear receptor',
#   'B71',
#   'CD19',
#   'CD27',
#   'CD28',
#   'CD3beta',
#   'CD45',
#   'CD45RA',
#   'CTLA4',
#   'CXCR2',
#   'DMPK',
#   'E2F4',
#   'EGF receptor',
#   'EZH2',
#   'Fcα2',
#   'FcγR3',
#   'GRO1',
#   'Gc subtype receptor',
#   'Glucagon',
#   'Glycoprotein',
#   'HSP30',
#   'ICSI2',
#   'IFN  γ',
#   'IGF  I',
#   'IL1 receptor',
#   'IL10',
#   'IL12',
#   'IL13',
#   'IL13 receptor',
#   'IL18 receptor',
#   'IL19',
#   'IL2',
#   'IL21 receptor',
#   'IL22',
#   'IL23',
#   'IL3',
#   'IL31',
#   'IL32',
#   'IL33',
#   'IL36',
#   'IL4',
#   'IL6',
#   'IL8',
#   'Iba1',
#   'IgG',
#   'Lactalbumin',
#   'Lck',
#   'Lef1',
#   'M  cell receptors',
#   'M  cell surface receptor',
#   'MAPK',
#   'MIF',
#   'MMP',
#   'MMP1  3',
#   'MMPs',
#   'MPS',
#   'MRD1',
#   'MTHFR',
#   'Methionine Dehydrogenase',
#   'Methylenetetrahydrofolate reductase',
#   'Myeloperoxidase',
#   'Myosin regulatory domain containing 1',
#   'NF  κB',
#   'P10',
#   'P11',
#   'P14',
#   'P15',
#   'P16',
#   'PD1',
#   'PGF',
#   'PKA',
#   'Protein kinase B',
#   'RBC  alpha',
#   'Ras',
#   'S  adenosylmethionine ammonia lyase',
#   'SAMAL',
#   'SDFR4',
#   'Src',
#   'TGF  beta',
#   'TNF',
#   'TNF  alpha',
#   'TNF family',
#   'TNFa',
#   'TNFs',
#   'Tumor necrosis factor alpha',
#   'Viscocortin',
#   'Vsc',
#   'actin',
#   'c  Myb protein',
#   'collagen',
#   'cytokine',
#   'cytokines',
#   'fibronectin',
#   'glucuronidase',
#   'immunoglobulin G3  G4 class 1 receptor',
#   'insulin',
#   'interferon gamma',
#   'interferons',
#   'met',
#   'myosin',
#   'myostatin',
#   'serine protease'},
#  'Hermansky-Pudlak syndrome': {'1  C  KIT',
#   'A2',
#   'ADAR1',
#   'AKT',
#   'AKT2',
#   'BCRF',
#   'CAB3',
#   'CD23',
#   'CD9',
#   'CFTR',
#   'CPP1B',
#   'CYP3A',
#   'CYP3A1  1',
#   'CYP9A1',
#   'Cpf1a',
#   'Cystic Fibrosis Transmembrane Conductance Regulator',
#   'DHR',
#   'Dysplasia of Hormone Receptors',
#   'FGF',
#   'FKBP9',
#   'FKBP9ALK',
#   'GADD45',
#   'GFP',
#   'GPI1',
#   'GPI2',
#   'GPI3',
#   'GPI3 family',
#   'GPxcex1',
#   'GSK3B',
#   'GSK3C',
#   'H  PHS',
#   'HDO',
#   'HDP2',
#   'HDPE protein',
#   'HER2',
#   'HERC2',
#   'HERMS',
#   'HERMS receptor',
#   'HPS3',
#   'HTL',
#   'KPT1',
#   'L  type calcium channel',
#   'LMD2',
#   'MECP2',
#   'MLC1',
#   'MPS IIA and IIB',
#   'Myostatin',
#   'Nrf2',
#   'Nrf2s',
#   'O  Neg antibody',
#   'PEP2',
#   'PINK1',
#   'PKA',
#   'PKC',
#   'Pudlak',
#   'RAR',
#   'SLC25A5',
#   'SLC26A2',
#   'Syndrome  Specific Receptor Co  Stimulating Protein',
#   'TEC1',
#   'TGF  b',
#   'TGF  beta',
#   'TNF',
#   'adenosine receptor',
#   'anti  CD18',
#   'anti  CD23 antibodies',
#   'cystic fibrosis transmembrane conductance regulator',
#   'insulin',
#   'neu',
#   'p110',
#   'p23',
#   'p33',
#   'p33 gene',
#   'p53',
#   'phosphodiesterase type 4',
#   'progesterone receptor',
#   'thrombin',
#   'xcex31A'},
#  'IGA glomerulonephritis': {'ACE',
#   'BCL2 family',
#   'BMP15',
#   'Bcl2',
#   'CD20',
#   'CD38',
#   'CD40',
#   'CD44',
#   'CTLA4',
#   'CXCL10',
#   'CXCL12',
#   'CXCL2',
#   'CXCL9',
#   'CXCR4',
#   'Cytokine',
#   'DUSP3',
#   'FGF21',
#   'FGF22',
#   'FXR  A',
#   'G  CSF',
#   'G protein',
#   'G protein  coupled receptors',
#   'G protein GβRI',
#   'G2 protein of IGA',
#   'GAG',
#   'GDNFR2',
#   'GLP1',
#   'GPR10',
#   'GRB2',
#   'GSK3',
#   'GTPase',
#   'Glomerular Endothelin Receptor',
#   'Glomerular filtration protein A',
#   'Glomerular filtration receptor S',
#   'Growth differentiation factor 15',
#   'HMG  CoA reductase',
#   'HNF',
#   'IFN receptors',
#   'IGA Phase 1 Receptor',
#   'IGA antibodies',
#   'IGA2',
#   'IGF  R',
#   'IGLIP',
#   'IGM',
#   'IGM1',
#   'IGSN',
#   'IL1',
#   'IL12',
#   'IL18',
#   'IL19',
#   'IL1β',
#   'IL20',
#   'IL20dependent',
#   'IL4',
#   'IL8',
#   'IL8 receptor',
#   'IgA',
#   'IgG',
#   'Igal1c6',
#   'LH',
#   'MCP1',
#   'MCP2',
#   'MCP3',
#   'MDA  1',
#   'MDA  1 receptor',
#   'MMP13',
#   'MMP22',
#   'MMP9',
#   'MUC16 G',
#   'NFKB',
#   'NGF',
#   'NGF receptor',
#   'PKC',
#   'PLCGAP',
#   'RANTES',
#   'RANTES  α',
#   'T cell receptors',
#   'TIGAR',
#   'TNF',
#   'TNF  alpha',
#   'TNF  α',
#   'TNF receptors',
#   'TSH',
#   'UGT1A4',
#   'VEGF  A',
#   'albumin',
#   'alpha  beta  granule intermembrane protein C',
#   'angiotensin II',
#   'anti  GM1 antibodies',
#   'collagen receptor',
#   'cytochrome P450  CYP  2A4',
#   'cytokine',
#   'cytokines',
#   'enzyme',
#   'glomerulin',
#   'glucagon  like peptide 1',
#   'glucagon  like peptide1',
#   'glycoproteins',
#   'insulin',
#   'interleukin1 beta',
#   'interleukin6',
#   'nephrotic factor',
#   'protein S6 K',
#   'protein kinase',
#   'rheumatoid factor',
#   'sodium channel',
#   'tissue factor',
#   'tumor necrosis factor'},
#  'Cirrhosis of liver': {'APXs',
#   'Apolipoprotein B4',
#   'BMP2  3',
#   'CCK  A',
#   'CCK  E',
#   'CDK',
#   'CDK1  3',
#   'CDK4  5',
#   'CDK6  7',
#   'CDP',
#   'CHT1',
#   'CHT2',
#   'CRL1',
#   'CYP1A2',
#   'FGF21',
#   'HBB',
#   'HDL',
#   'Hemagglutinin',
#   'Hepatocyte cytoplasmic phosphorylase S6A',
#   'IGF',
#   'IGF1',
#   'IL1',
#   'IL6',
#   'Kallikrein',
#   'LDL',
#   'Lamin B',
#   'MMP family',
#   'MMP1',
#   'NAR',
#   'NAR1',
#   'NR2',
#   'NR2A',
#   'NR2B',
#   'NR2C',
#   'NR3',
#   'Norepinephrine Receptor type 1',
#   'PKB',
#   'Protein',
#   'RNA polymerase',
#   'S100A11',
#   'SOD',
#   'TGF',
#   'TGF  B',
#   'TNF',
#   'Tumor Necrosis Factor Receptor 2',
#   'alpha  amino  xyloglutamate  family',
#   'amylase',
#   'asparaginase',
#   'brain cell acetylcholine receptor',
#   'choline dehydrogenase',
#   'collagen',
#   'cytokines',
#   'insulin',
#   'p53',
#   'phosphorylase S6A'},
#  'Seckel syndrome': {' C  GAG2A  C  N  C  ATPases',
#   '4methyl4cis  hydroxytryptamine  4methyl4CC  receptor',
#   '5methyl4hydroxytryptamine  5methyl4HT  receptor',
#   'BAF1B',
#   'BRCA2',
#   'CAG3',
#   'CDKL19',
#   'CDKL21',
#   'CDKL22',
#   'CDKL27',
#   'CDKL6',
#   'CDKL7',
#   'CDKN1',
#   'CDKN11',
#   'CDKN12',
#   'CDKN13',
#   'CDKN14',
#   'CDKN15',
#   'CDKN151',
#   'CDKN17',
#   'CDKN2A',
#   'CDKN2B',
#   'CDKN3A',
#   'CDKN3B',
#   'CDKN9',
#   'CET1',
#   'CGAG1',
#   'Cortical GTPase Activation Gene1',
#   'Crispr',
#   'DAF2',
#   'DAF2A',
#   'DAF2B',
#   'DAF2C',
#   'DMDPS1',
#   'DMPK',
#   'DPF2C',
#   'FADD',
#   'FADD2B',
#   'GAPDH',
#   'GHRF',
#   'HER1',
#   'HET',
#   'HMG CoA reductase',
#   'HSPD1',
#   'HSPR5',
#   'KIF7R',
#   'KIF7R1',
#   'MAPK  PKB family of kinases',
#   'MECP2',
#   'PKA',
#   'PKB',
#   'PKC',
#   'PKD',
#   'SNIP3R',
#   'Seckel',
#   'Seckelase',
#   'Seckley syndrome protein',
#   'growth hormone',
#   'lipid receptor',
#   'methylase',
#   'protein kinase A',
#   'protein kinase B',
#   'protein kinase C',
#   'protein kinases',
#   'telomerase'},
#  'Sickle cell anemia': {'B  carboxy protein',
#   'B  protein complex',
#   'Endostatin receptors',
#   'HIF',
#   'HIF1A',
#   'HIF1α',
#   'HLA  A2',
#   'HbA1',
#   'HbA1C',
#   'HbS',
#   'IL1 family',
#   'IL1 receptor',
#   'IL1β',
#   'IL22',
#   'IL23',
#   'IL27',
#   'IL31',
#   'IgG',
#   'Insulin',
#   'Insulin  like receptors',
#   'Insulin dependent cell adhesion molecule',
#   'Kinases',
#   'MIMP',
#   'MMP',
#   'MmesEn',
#   'S  Adenosyl  Ligulan Monosulfate  SGLT  receptors',
#   'S  protein  related aCJD',
#   'SCA1',
#   'SCA2',
#   'SLC25A2',
#   'SLC40A2',
#   'SceC family',
#   'SceL',
#   'Scex2',
#   'Scl',
#   'Sickle Cell Anemia Factor',
#   'Sickle hemoglobin',
#   'TNF  alpha',
#   'beta amylin',
#   'beta globin',
#   'beta purinolyl transferase',
#   'dystrophin',
#   'erythropoietin',
#   'factor VIIa',
#   'haem',
#   'haem  alpha',
#   'haemoglobin',
#   'hemoglobin',
#   'hemoglobin A',
#   'hemoglobin A2',
#   'hemoglobin S',
#   'hemoglobin S1',
#   'human Factor VIIa',
#   'human IgG',
#   'human factor VIIa',
#   'kinase',
#   'kinases',
#   'monocyte membrane protein',
#   'sialyltransferase',
#   'sickle cell receptor',
#   'sickle factor',
#   'sickle1',
#   'sickling factor  binding protein'},
#  'Type II diabetes mellitus': {'ACE',
#   'APOE',
#   'APOE  e4',
#   'APOE e4',
#   'Akt',
#   'ApoE4',
#   'Bcl  xL',
#   'Bcl2 family',
#   'CD79a',
#   'D2A chaperone',
#   'D2A chaperone protein',
#   'D2a',
#   'FTO',
#   'FTO4',
#   'GLP1like',
#   'GLUT1',
#   'Glucagon',
#   'Hsp90',
#   'IGF',
#   'IR1A',
#   'InsRP',
#   'Insulin',
#   'Insulin  like Growth Factor',
#   'Insulin receptor',
#   'LDL',
#   'LDL Receptor',
#   'LPR',
#   'Limb  Pressure Responsive protein',
#   'Lipase',
#   'PDE',
#   'PGC1alpha',
#   'PGC1α',
#   'PTH',
#   'PTH receptor',
#   'SGLT2',
#   'Sirtuin  like 2',
#   'TATP',
#   'TIF5A',
#   'TIGIT3',
#   'TIGIT4',
#   'alpha receptors',
#   'beta  secretase',
#   'glucose  dependent kinase 4',
#   'glucose transporter',
#   'glucosidase',
#   'glucosyltransferases',
#   'glycerophosphatase',
#   'insulin',
#   'insulin  receptor',
#   'insulin receptor',
#   'insulin receptor alpha',
#   'insulin receptors',
#   'insulin resistant growth factors',
#   'interferons',
#   'protein kinase',
#   'protein kinases  glycosyltransferases  phosphodiesterase',
#   'sirtuin type III family',
#   'transcription factor'},
#  'Mucocutaneous lymph node syndrome': {'AFAIK',
#   'AKT',
#   'BRCA2',
#   'C  reactive protein',
#   'CAT',
#   'CD11',
#   'CD27',
#   'CD28',
#   'CD8',
#   'CTLA4',
#   'Fibroblast growth factor receptor 2',
#   'G  protein',
#   'GATA1',
#   'HER2',
#   'HLA B27',
#   'Ig',
#   'JAK2',
#   'LECR',
#   'MCLNS',
#   'MLCN',
#   'MLEN',
#   'MLLN',
#   'MLLNP',
#   'MUC',
#   'MUC1',
#   'MUC11',
#   'MUC11B4',
#   'MUC13',
#   'MUC1B12',
#   'MUC1CD4',
#   'MUC1D4',
#   'MUC2',
#   'MUC2C3A',
#   'MUC2C3B',
#   'MUC3',
#   'MUC4',
#   'MUC5ACL',
#   'MUC5GD4',
#   'MUC5b',
#   'MUC6',
#   'Mucin1',
#   'NFAT',
#   'NFκB',
#   'NKG2D',
#   'NTRK5',
#   'P450s',
#   'PSA',
#   'PTEN',
#   'Rbfx1',
#   'Rbfx3',
#   'TGFb',
#   'TLN1',
#   'TLN11',
#   'TLN13',
#   'TLN14',
#   'TLN2',
#   'TLN8',
#   'TLN9',
#   'TNF',
#   'TNF  RKB',
#   'TNF  alpha',
#   'TNF receptor',
#   'TRPM3',
#   'Yes',
#   'adhesion molecules',
#   'cell surface receptors',
#   'interferon inducer MUC1B12',
#   'mTORC1  2',
#   'receptor kinase 3B',
#   'rhBXO3',
#   'tumor necrosis factor 2'},
#  'Basal-like breast carcinoma': {'AKT',
#   'ALK',
#   'APO',
#   'ATM',
#   'Abl',
#   'BARC1',
#   'BARC1A',
#   'BRAF',
#   'BRCA',
#   'BRCA1',
#   'BRCA1  2',
#   'BRCA2',
#   'BRD',
#   'BRG2',
#   'BRIDL',
#   'CCR5',
#   'CD133',
#   'CD137',
#   'CD68',
#   'CDK',
#   'CDK4  6',
#   'CDKN2A',
#   'CDKN2C',
#   'DLL3',
#   'DNA polymerases',
#   'DNF1',
#   'DREBP1',
#   'E7 beta receptor',
#   'EGFR',
#   'EIF3B',
#   'ER',
#   'ERBB2',
#   'ERG3',
#   'ErbB',
#   'Estrogen receptors',
#   'FGF',
#   'FGFalpha',
#   'FOSL1B',
#   'GPR100',
#   'H1b',
#   'HCRB1',
#   'HER1',
#   'HER2',
#   'HER2  neu',
#   'HER3',
#   'HER4',
#   'IGF',
#   'IGF  I',
#   'IL6',
#   'JAK',
#   'KIT',
#   'LBP',
#   'LHRH',
#   'LRRK2',
#   'MOR202',
#   'MUC1',
#   'Metaproteinases',
#   'N  acetylglucosamine synthetase',
#   'NBSP',
#   'NF  κB',
#   'NOS',
#   'NUC9',
#   'Nucleoside  binding protein',
#   'PD1',
#   'PI3 K',
#   'PI3ks',
#   'PIK3CA',
#   'PIK3H',
#   'PIK3L  B',
#   'PKA',
#   'PR',
#   'Polyubiquitin',
#   'ROLIP 1',
#   'ROLIP1',
#   'ROR',
#   'RORγt',
#   'Raf family',
#   'Rb',
#   'S100A8',
#   'SINE',
#   'SRC',
#   'STAT3',
#   'TAS2',
#   'TGF  beta',
#   'TNF receptor receptor',
#   'TP53',
#   'TSL',
#   'VEGF',
#   'Yes',
#   'epithelial cell adhesion molecule',
#   'estrogen receptor',
#   'estrogen receptors',
#   'estrogen receptors 1  5',
#   'fibroblast growth factor receptor alpha',
#   'histone  Lanthanide  binding protein',
#   'kinases',
#   'laminin',
#   'neu',
#   'nuclease',
#   'p21',
#   'p24AR',
#   'pIK3CA',
#   'pIK3CA  F',
#   'pikinase',
#   'progesterone receptor',
#   'protein kinases',
#   'ras',
#   'tyrosine kinase'},
#  'Facioscapulohumeral muscular dystrophy': {' fibroblast growth factor',
#   'AAT',
#   'CRISPR  Cas9',
#   'Cas9',
#   'DMD',
#   'DYC1',
#   'DyStr',
#   'F  actin',
#   'FAH',
#   'FKBP13',
#   'FSH',
#   'FSH  receptor',
#   'FSH receptor',
#   'FSHD',
#   'FSHD1',
#   'FSHM',
#   'GALCR2',
#   'GAPDH',
#   'GLUT4',
#   'Glioblastoma inhibitory factor',
#   'HBDT',
#   'HBDT complex',
#   'HBDT interacting proteins',
#   'HDAC',
#   'HDAC3',
#   'HDAC4',
#   'HSP70',
#   'HSP90',
#   'IFN  gamma',
#   'IGF1 receptor',
#   'KCsC',
#   'Kv631',
#   'LRRK2',
#   'MDR',
#   'MIR',
#   'MSH',
#   'Myostatin',
#   'NERRF1',
#   'NF  KB',
#   'PDGF',
#   'PTPN12',
#   'RALF1',
#   'RPE65',
#   'RSK2',
#   'SDP',
#   'SMA1a',
#   'SOD1',
#   'SR',
#   'Serine protease',
#   'TATA  binding protein 3',
#   'TBP3',
#   'TDP43',
#   'TGF  alpha',
#   'TGF  beta family receptor',
#   'TGFbeta family',
#   'TGFβ',
#   'alpha  synuclein',
#   'c  jun transmembrane receptor',
#   'chondroitin sulfate proteoglycan',
#   'collagen',
#   'dystrophin',
#   'fibrin',
#   'fsh1',
#   'fsh2',
#   'fsh3',
#   'myosin heavy chain family',
#   'myostatin',
#   'myotubularin',
#   'protease',
#   'proteases',
#   'somatodendrocyte  associated protein'},
#  "Alzheimer's disease": {' tau proteins',
#   'APOE  E42',
#   'APOE4',
#   'APP',
#   'Alpha  synuclein',
#   'Amyloid beta',
#   'BACE1',
#   'BACE1targeted',
#   'BetaAmyloid precursor  epithelial precursor protein',
#   'CEA',
#   'MAP1',
#   'N  terminal hydroxylases',
#   'NfL',
#   'Nrf2',
#   'TDP32',
#   'TDP40',
#   'TDP43',
#   'TREM2',
#   'TUMor Necrosis Factor',
#   'Tumor Necrosis Factor',
#   'alpha  synuclein',
#   'alpha 2 adrenergic receptor',
#   'amyloid  beta',
#   'amyloid beta',
#   'amyloid beta peptide',
#   'amyloid precursor protein',
#   'amyloid related protein',
#   'beta  amyloid',
#   'beta  secretase',
#   'beta amyloid',
#   'beta amyloid 1',
#   'calcium channel',
#   'enzyme',
#   'insulin',
#   'microtubule  associated protein 1',
#   'neuroflagellin',
#   'tau',
#   'β  amyloid protein'},
#  'Rett syndrome': {' target RNA ',
#   'APOE',
#   'APP',
#   'ATP1',
#   'ATTR2',
#   'AVP13',
#   'AXL',
#   'Alpha2antitrypsin',
#   'CACNA1',
#   'CCAAT16',
#   'CCAAT5',
#   'CFTR',
#   'Cytokine receptor',
#   'EGF',
#   'FET1',
#   'FMR1',
#   'FSH  CRY1',
#   'GATA3',
#   'GSK3α',
#   'GSK3β',
#   'Glutamate transporter',
#   'HGH',
#   'HIP',
#   'HLA  A801C2',
#   'HSP40',
#   'HSP70',
#   'Hsp40',
#   'IL1RL',
#   'Insulin',
#   'Insulin receptor',
#   'Interleukin1 receptor  like ligand',
#   'MHC Class I  related gene HLA  A801C2',
#   'MIP67',
#   'Mdm2',
#   'N  cadherin',
#   'NF1',
#   'NF1L',
#   'Neuropilin',
#   'PEPI3',
#   'PIM',
#   'POMC',
#   'POMC  M',
#   'PRIM5',
#   'PTPN11',
#   'RNA polymerase II',
#   'RNA polymerase III',
#   'RPR2',
#   'RTE',
#   'Rets',
#   'Rett',
#   'Rett hormone receptor',
#   'SLC6A8',
#   'TERT',
#   'TMPRSS1',
#   'TNF receptors',
#   'TSP1',
#   'Transcription factor',
#   'alpha2antitrypsin',
#   'androgen receptor',
#   'cystic fibrosis transmembrane regulator',
#   'dystrophin',
#   'immunoglobulins',
#   'insulin',
#   'mTARC',
#   'mouse T  cell receptor',
#   'neuropilin',
#   'p53',
#   'retinol  binding protein',
#   'tau'},
#  'Obesity': {'Bcl2',
#   'C  R  S protein tyrosine kinases',
#   'CRISPR',
#   'CYC1',
#   'CYP3A4',
#   'FGRP',
#   'GABRA',
#   'GATA3',
#   'GLUT1',
#   'GPCR',
#   'GSK3',
#   'HSP80',
#   'Insulin',
#   'KIDC',
#   'LDL',
#   'LIGG receptors',
#   'LRP5',
#   'Lipoprotein receptor',
#   'Lipoxygenase',
#   'MGH',
#   'NRF2',
#   'ORF11',
#   'OXPHOS',
#   'OXPHOS1',
#   'PI3Ks',
#   'RARF',
#   'SLC19A4',
#   'TGLI  CRP',
#   'TGLIC',
#   'TNF',
#   'TRPVs',
#   'adiponectin',
#   'adrenocorticotropic hormone',
#   'fibrinogen',
#   'human chorionic gonadotropin',
#   'insulin',
#   'leptin',
#   'leptin I',
#   'leptin receptor',
#   'lipoprotein receptors',
#   'lipoxygenase',
#   'metabotropic glutamate receptor',
#   'taste receptors',
#   'tongue taste receptors'},
#  'Ichthyosis': {'BMP4',
#   'CD146',
#   'CD163',
#   'CD8+CD4',
#   'COMTs',
#   'Catechol  O  methyltransferases',
#   'D1',
#   'D2',
#   'Dicer',
#   'E3 ligase',
#   'E6',
#   'FGF14',
#   'FSH',
#   'HD1',
#   'HD2',
#   'HLA',
#   'ICAMB',
#   'IL2',
#   'IL31',
#   'Ich',
#   'IgA',
#   'IgE',
#   'K  ras',
#   'MAF',
#   'MAPK1b',
#   'MHC',
#   'PD1',
#   'PDGF  BB',
#   'PNP',
#   'PPIH7',
#   'PTEN',
#   'Protein H  H',
#   'Protein kinases',
#   'T cell receptors',
#   'TDP43',
#   'Yes',
#   'ZAP101',
#   'ZAP115',
#   'ZAP117',
#   'ZAP70',
#   'ZAP71',
#   'ZAP72',
#   'ZAP79',
#   'ZAP86',
#   'ZAP88',
#   'ZAP95',
#   'Zap70',
#   'actin',
#   'protein tyrosine kinases',
#   'receptor tyrosine kinases',
#   'somatidyltransferase 5',
#   'tyrosine kinase',
#   'tyrosine phosphatases'},
#  'Familial adenomatous polyposis': {'ADAM',
#   'ADAP',
#   'ADOS1',
#   'ADP receptor',
#   'AP',
#   'APA',
#   'APC',
#   'APC family',
#   'APC1',
#   'APC1 family',
#   'APC1A1',
#   'APC1A1APC1A1',
#   'Adnexin1 and 3',
#   'BRCA',
#   'BRCA 1',
#   'BRCA+',
#   'BRCA1',
#   'BRCA1  2',
#   'CAPS',
#   'D927 G gene',
#   'DIC1',
#   'EGFR',
#   'FAP',
#   'FAP family',
#   'H  B ',
#   'H2AX',
#   'HAP',
#   'HLA',
#   'MEK',
#   'Methylmalonylphosphotrithioamide methyltransferase',
#   'NRAS',
#   'POLP',
#   'POLP1',
#   'PRAS1',
#   'Pol X',
#   'Polyposis coli',
#   'Rb',
#   'S  adenosylmethionine synthetase',
#   'SABP',
#   'TP53',
#   'TTM',
#   'TTR',
#   'Trithioaminomethyltransferases',
#   'VEGF',
#   'adenomatous polyposis gene',
#   'apixaban gene',
#   'cadherins',
#   'heat shock protein AX',
#   'p53',
#   'p61',
#   'poly  ADP  ribose  polymerase',
#   'poly  ADP  ribose  polymerase1',
#   'type I polymerase'},
#  'Hypertension': {'ACE',
#   'ACE  I',
#   'Angiotensin I',
#   'Angiotensin II receptor',
#   'DPP4',
#   'GLP1',
#   'H1R',
#   'HDL',
#   'IGF  I',
#   'Insulin',
#   'LDL',
#   'Ldl',
#   'N  methylD  aspartate receptor',
#   'NMDAR',
#   'Nrf2',
#   'Protease',
#   'SLC1 kinase',
#   'Sodium channels',
#   'VNG3',
#   'Valine N  methyltransferase 3',
#   'angiotensin',
#   'angiotensin  converting enzyme',
#   'angiotensin II',
#   'angiotensin receptor',
#   'angiotensinogen decarboxylase',
#   'asparase',
#   'calcitonin',
#   'high  density lipoprotein',
#   'insulin',
#   'insulin  like growth factor',
#   'protein kinases',
#   'renin',
#   'transcription factor',
#   'vasopressin'},
#  'Inflammatory bowel disease': {'C  Reactive Protein',
#   'CD107a',
#   'CD13',
#   'CD163',
#   'CD17A',
#   'CD20',
#   'CD61',
#   'CD8 + T  cell receptor',
#   'CD83  82',
#   'CD95',
#   'CRISPR',
#   'CTLA4',
#   'DMPK',
#   'EGFR',
#   'EGR1',
#   'EMT2',
#   'Fibronectin',
#   'G  protein coupled receptors',
#   'GABP',
#   'GLP1',
#   'Glycogen Activated Protein Kinase',
#   'IBB',
#   'IFNA',
#   'IIT4',
#   'IL1',
#   'IL10',
#   'IL12',
#   'IL13',
#   'IL1R',
#   'IL23',
#   'IL4',
#   'IL6',
#   'IL8',
#   'IL8R',
#   'ILC1',
#   'ITGB1',
#   'IgA4',
#   'IgG4',
#   'IgM',
#   'MDR1',
#   'NF  kappa B',
#   'NKG2D',
#   'P450',
#   'PDE',
#   'PDEs',
#   'PDGFR',
#   'T  cell factor',
#   'TLR4  6',
#   'TNF',
#   'TNF  alpha',
#   'TNF  related peptide',
#   'TNF receptor',
#   'chemokines',
#   'cytokine',
#   'cytokines',
#   'inflammatory bowel associated protein',
#   'insulin',
#   'interferon',
#   'interferon alpha',
#   'interleukin 1 receptors',
#   'lipoxygenase',
#   'proteases'},
#  'Vitiligo': {'C  EBPα',
#   'CCL4',
#   'CCR2',
#   'CD44',
#   'Capsular polyglutamine proteoglycan',
#   'FGF',
#   'FcRn',
#   'Follicle stimulating hormone receptor',
#   'HNF1',
#   'HSP70',
#   'IL10',
#   'IL17',
#   'IL18',
#   'IgA',
#   'IgG',
#   'IgM',
#   'MECP1',
#   'MSF',
#   'NAK1',
#   'NAK2',
#   'PDGF',
#   'TGF  beta',
#   'TNF',
#   'WNT',
#   'Wnt  like hormone receptor',
#   'Yes',
#   'anti  M antigen',
#   'cytokine',
#   'glycoproteins',
#   'iDARP',
#   'iDARPs',
#   'insulin',
#   'melanin receptors',
#   'melanocortin',
#   'melanocyte  stimulating antigen',
#   'melanocyte stimulating factor',
#   'melanophore receptor',
#   'tumor necrosis factor  related cytokines',
#   'tyrosine kinase'},
#  'Esophageal carcinoma, adenocarcinoma': {'1st protein tyrosine kinases',
#   '5  exonuclease  RNA polymerase',
#   'ABL2',
#   'ALK',
#   'ALK2',
#   'ATF',
#   'ATP6',
#   'BCR',
#   'BCRF',
#   'BRCA1',
#   'CCR5',
#   'CDK8',
#   'DNA methyltransferases',
#   'E  cadherin',
#   'E6',
#   'EGFR',
#   'ER',
#   'ErbB3',
#   'Fibroblast growth factor family',
#   'Fused',
#   'G  proteins',
#   'GAS2',
#   'GTPases',
#   'H  ras',
#   'HRAS',
#   'HSP70s',
#   'HoxB 2',
#   'IL8',
#   'IRF5',
#   'Interleukin8',
#   'LAG3',
#   'MMP9',
#   'NF  κB',
#   'NGF',
#   'PDGF',
#   'PI3 K',
#   'Protein kinase C  AKT  kinase',
#   'TNF  a',
#   'VEGF',
#   'VEGF  R3',
#   'VEGF  R6',
#   'VEGF family',
#   'VEGF receptor 2',
#   'VEGF receptor 3',
#   'VEGF receptor 4',
#   'VEGFR1',
#   'VEGFR2',
#   'VEGFR4',
#   'Vascular endothelial growth factor',
#   'Vitronectin',
#   'Wnt',
#   'ZNF24',
#   'brca protein family',
#   'c  myc',
#   'cancer causing protein',
#   'death receptor',
#   'fosB',
#   'glycosyltransferases',
#   'growth factors',
#   'p16',
#   'p17',
#   'p53',
#   'vitronectin',
#   'znfp24'},
#  'Graves disease': {'Anti  thyroid factor',
#   'Antibody',
#   'CCR4',
#   'CD40',
#   'CGRP',
#   'CREB',
#   'FOXC2',
#   'G protein  coupled receptor',
#   'GPCR',
#   'GPCRs',
#   'H1A',
#   'HGF',
#   'IL17',
#   'IL17A',
#   'IL22',
#   'IL23',
#   'IgG3',
#   'Insulin',
#   'Ipf4',
#   'Ipf4l',
#   'KIF1',
#   'LRRK2',
#   'MHC class II',
#   'NGF',
#   'Nerve Growth Factor',
#   'P2X7',
#   'PDE5',
#   'PDE5A1',
#   'PDE5B1',
#   'PDEs',
#   'Proton Pump',
#   'RAGE',
#   'SLC6A1',
#   'Sulfuryl transferase',
#   'TGF  beta',
#   'TGF  β',
#   'TGFb',
#   'TGFbeta',
#   'TNF',
#   'TRPV1',
#   'TSH',
#   'Trophin  like receptor',
#   'angiotensin II',
#   'anti  thyroid factor',
#   'antibodies',
#   'calcitonin',
#   'calcitonin  releasing peptide',
#   'calcitonin gene  related peptide',
#   'class I antibody',
#   'cytokines',
#   'glutamate receptors',
#   'glycoproteins',
#   'growth hormone',
#   'insulin',
#   'phosphodiesterases',
#   'serotonin receptor',
#   'sodium channels',
#   'sulfuryl transferase',
#   'transcription factors'},
#  'endometriosis': {'ATM',
#   'ATRA1',
#   'Androgen Receptor',
#   'BRCA2',
#   'CDKN2A',
#   'CYP14A2',
#   'EGF',
#   'ER+',
#   'Endorphins',
#   'FSH',
#   'GCRM1',
#   'HCG',
#   'Ig  A',
#   'KRAS',
#   'LH',
#   'Luteinizing hormone',
#   'MYDD1',
#   'PCSK9',
#   'PGF  beta1',
#   'RAGE',
#   'SFRP1',
#   'Yes',
#   'estrogen receptor',
#   'estrogen receptor  alpha',
#   'estrogen receptor alpha',
#   'growth factors',
#   'insulin',
#   'insulin  like growth factor'},
#  'Alveolar rhabdomyosarcoma': {'AAFP',
#   'ARRK',
#   'ATPase',
#   'Akt',
#   'Alveolar rhabdomyosarcoma  associated caspase',
#   'Aromatase',
#   'BRCA',
#   'CCL2',
#   'CD38',
#   'CD45',
#   'CDG1',
#   'CDK 4 and 6',
#   'CDK13',
#   'CDK5',
#   'CDK6',
#   'Caspase3',
#   'Caspase8',
#   'CpF2',
#   'E2F',
#   'EGFR',
#   'F  box DNA binding protein',
#   'FGF19',
#   'FOXO1',
#   'FOXO2',
#   'FOXO3',
#   'GDF14',
#   'GDF7',
#   'GP1',
#   'GSK3',
#   'GSK3fusion',
#   'HER2',
#   'HER3',
#   'HMG Co  A reductase',
#   'Hsp70',
#   'Hsp90',
#   'IL15',
#   'IL17',
#   'IL2',
#   'IL4',
#   'Interferons',
#   'Langerhans epithelial growth factor',
#   'MAPKK',
#   'MHC  I',
#   'MMP',
#   'Myosin II',
#   'NEG2',
#   'P53',
#   'PI3K',
#   'PIK3CR1',
#   'PIM2',
#   'PIM3A',
#   'PIM3B',
#   'PIM5A',
#   'RAB2A',
#   'RAS',
#   'RAS oncogene',
#   'RPA1',
#   'Rad51',
#   'RhabD family',
#   'Rrbs',
#   'S100B',
#   'SRC',
#   'T  cell receptor',
#   'TCR',
#   'TGFβ',
#   'TNF',
#   'TNF beta',
#   'TP53',
#   'Wnt  binding protein',
#   'anti  tumor necrosis factor alpha',
#   'c5associated serine protease',
#   'caspase7',
#   'gp130',
#   'gp130  132',
#   'gp139',
#   'gp146',
#   'kinase',
#   'kinases',
#   'microtubule associated protein',
#   'myoglobin',
#   'myosin',
#   'p53',
#   'protease  activated receptor  like serine protease',
#   'protein kinase',
#   'ribosomal protein',
#   'type II collagen'},
#  'Lung adenocarcinoma': {'AAT',
#   'AAT transactivator',
#   'ABL',
#   'APO',
#   'APO family',
#   'BCL2',
#   'BCL7',
#   'BCR',
#   'BHLP',
#   'BRAF',
#   'CD127',
#   'CD40',
#   'CJNK',
#   'CTGF',
#   'EGF',
#   'EGF family transcription factors',
#   'EGFR',
#   'EGR1',
#   'EGRF',
#   'EIF2',
#   'ENOS',
#   'ERBB2',
#   'ErbB2',
#   'GADD65',
#   'GADD81',
#   'HIF1A',
#   'HIF1B',
#   'IFN  α  receptor',
#   'IL3 receptor',
#   'JAK',
#   'LRP5',
#   'Lung adenosine receptors',
#   'MAPK kinase 1',
#   'MART',
#   'MDR',
#   'MEK',
#   'MEK1  2',
#   'MMP11',
#   'MMP9',
#   'MYC',
#   'Molecular Target  2',
#   'Molecular Target  3',
#   'Molecular Target  4',
#   'Molecular Target  5',
#   'Molecular Target  6',
#   'Molecular Target  7',
#   'P  glycoprotein',
#   'PD  L1',
#   'PD1',
#   'PDL1',
#   'PI3 K',
#   'PI3 K  p38 MAPK',
#   'RAS',
#   'TGF  beta',
#   'TGFb',
#   'TGFb family',
#   'TGR2',
#   'TLRs',
#   'TNF  alpha',
#   'VEGF',
#   'VEGF receptors',
#   'Wnt',
#   'adenocarcinoma  specific protein kinase',
#   'c  Jun',
#   'corticokine receptor',
#   'cytokines',
#   'eGCG',
#   'eNOS',
#   'epidermal growth factor receptors',
#   'extracellular matrix metalloproteinase',
#   'fibronectin',
#   'interferons',
#   'interleukins',
#   'lung CTGF receptors',
#   'lung adenosine receptors',
#   'mTOR',
#   'p53',
#   'phosphorylase',
#   'protein kinase',
#   'tubule  associated protein 5',
#   'tyrosine kinases',
#   'vascular endothelial growth factor  receptor'},
#  'X-linked cerebral adrenoleukodystrophy': {'5alpha reductase',
#   'ACC',
#   'ACE2+CAT5+CYP1A1',
#   'ALK3',
#   'APO',
#   'APP',
#   'ATXN11',
#   'AXL',
#   'Acetyl  CoA carboxylase',
#   'BCL',
#   'CCA',
#   'CCA1',
#   'CD38',
#   'CSAD1',
#   'CXCL3',
#   'CXCL4',
#   'CYP1A2',
#   'CYP1C1',
#   'CYP1D2',
#   'CYP2C17',
#   'CYP2C19',
#   'CYP2D6',
#   'CYP2L6D',
#   'CYP3A4',
#   'FAD1',
#   'FGF',
#   'GFBP',
#   'GGT',
#   'GGT A and B',
#   'LRRR',
#   'MECP2L',
#   'N  methyl  D  aspartate receptor',
#   'NMDAR',
#   'P185A  D',
#   'PS1',
#   'PXR1',
#   'SLC62A20',
#   'TERT',
#   'TGF  Beta',
#   'TGF  β',
#   'Xcex1',
#   'Xcex2chromosome',
#   'Xp212',
#   'Yes',
#   'acetyl  CoA carboxylase',
#   'adenosine deaminase',
#   'adrenoleukotrophic protein3',
#   'dopamine receptor',
#   'dopamine receptors',
#   'enzyme',
#   'glucagon receptor',
#   'glucocorticoid receptor',
#   'myosin',
#   'oleurins',
#   'p185A  D ',
#   'protein kinase',
#   'protein kinase C',
#   'tau',
#   'β1hydroxysteroid dehydrogenase'},
#  'head and neck squamous cell carcinoma, larynx': {'AKT',
#   'B7  2 ligand 5',
#   'B7  3 ligand 6',
#   'BRCA',
#   'BRCA1',
#   'BRCA2',
#   'CCRN39',
#   'CD44',
#   'CRCP1',
#   'CTCF',
#   'CXC8',
#   'CXCL1',
#   'CXCL11',
#   'Dihydrofolate reductase',
#   'E2F',
#   'E6',
#   'E7',
#   'EGFR',
#   'ErbB',
#   'FGF21',
#   'FGF23',
#   'GATA2',
#   'GATA3',
#   'Growth Hormone',
#   'HER2',
#   'HGF',
#   'HIF1',
#   'HLA',
#   'Head and Neck Nerve Growth Factor',
#   'Head and neck',
#   'Human Leukocyte Antigen',
#   'KRAS',
#   'L1',
#   'LAP1',
#   'MAPK',
#   'MAPT',
#   'MC2Rγ',
#   'Melanocortin II receptor gamma',
#   'NFK',
#   'PCNA',
#   'PI3K',
#   'PIGR1',
#   'POMC',
#   'PSEN1',
#   'PSEN2',
#   'Ras',
#   'TGF  β1',
#   'TGFβ',
#   'TIGITA1',
#   'TKIs',
#   'Tumor necrosis factor  alpha',
#   'Wnt kinase',
#   'adenylate cyclase',
#   'c  Jun N  terminal kinase  JNK  3',
#   'caspase9',
#   'cysteine protease genes 2',
#   'epidermal growth factor receptor',
#   'epidermal growth factor receptor 4',
#   'hnRNP1',
#   'hnRNP1 1',
#   'hnRNP1 2',
#   'mTOR',
#   'mek',
#   'p16',
#   'p26',
#   'p38',
#   'p53',
#   'p53B',
#   'p57',
#   'protein caspase9',
#   'tyrosine  protein kinases',
#   'tyrosine kinase'},
#  'Dyskeratosis congenita': {'C10orf52',
#   'C5n7',
#   'C9orf72',
#   'CACNA1a',
#   'CTP80',
#   'Cas12a',
#   'DAT7',
#   'DD3',
#   'DYK2',
#   'Dcn',
#   'DsC',
#   'Dy45',
#   'Dystrophin',
#   'EZH2',
#   'HSP',
#   'HSP70',
#   'HSP70like',
#   'HSPC',
#   'Hsc2',
#   'HyabP',
#   'Hyakurenin  binding protein',
#   'Hyplo3',
#   'KCNQ2',
#   'KDM1',
#   'KSR1',
#   'LIRB',
#   'Lactate dehydrogenase',
#   'MCHN',
#   'MCP1',
#   'MSTK2',
#   'N  acetyl  alpha  D  glucosaminidase',
#   'N  terminal tyrosine kinase',
#   'NF  kB',
#   'NHE1',
#   'NRP',
#   'NRP2',
#   'Nsp4',
#   'PDGFRA',
#   'RAS',
#   'RASSF',
#   'RPE65',
#   'RPS2',
#   'SCN3A',
#   'SLC6A5',
#   'TGF  β',
#   'TKC1',
#   'TNF',
#   'TNFB',
#   'Tyrosine kinases',
#   'VEGF',
#   'VIP',
#   'X  linked protein alpha 5',
#   'YK',
#   'YKs',
#   'Yes',
#   'alpha5β',
#   'cholesterol receptor',
#   'collagen',
#   'dystrophin',
#   'fibrin',
#   'fibroblast growth factor',
#   'gla',
#   'h13',
#   'h21',
#   'hsc2',
#   'human epidermal growth factor receptor',
#   'insulin',
#   'interstitial growth factors',
#   'lipotyrosine hydroxylase',
#   'myostatin',
#   'p14',
#   'p19',
#   'phosphatidylinositol3kinase 2',
#   'phosphodiesterase 5',
#   'phosphodiesterases',
#   'sirtuin3',
#   'spherulin',
#   'syncytin1',
#   'tau',
#   'transmembrane helicase'},
#  'Spinocerebellar ataxia with axonal neuropathy type 2': {'1  Protein kinase C kinase 5  2  Drosophila melanogaster  S2  3',
#   '5  EGF',
#   '6  Cyclin B2',
#   '7  Cyclin B3',
#   'AAT',
#   'ABL',
#   'ALDH2',
#   'ATN1',
#   'ATRAP1',
#   'ATXN1',
#   'ATXN2',
#   'B  CAM  B',
#   'B  cell receptor family',
#   'B  complex aminoacyl  tissue  derived factor',
#   'BCR',
#   'C1q',
#   'C9ORF',
#   'C9ORF9',
#   'C9orf72',
#   'CAR',
#   'CRD2',
#   'CXCR11',
#   'Cyclin B1',
#   'DANR',
#   'DMD',
#   'Drosophila protein tyrosine phosphatase  I',
#   'E1',
#   'E2',
#   'E3 ligase',
#   'E3α',
#   'E3β',
#   'FADH1fMRP',
#   'FGF9',
#   'GABAA receptors',
#   'GAMRA',
#   'GATA1',
#   'GPCRs',
#   'GluR5',
#   'HGF',
#   'IL6',
#   'KLIF1',
#   'Kif 2',
#   'LAG3',
#   'LDL',
#   'LRRK2',
#   'MAP',
#   'MAP1',
#   'MTHFR',
#   'Metabotropic glutamate receptor 1',
#   'Methacholine receptor',
#   'Mitochondria  associated protein',
#   'N  Acetylspondinase',
#   'N  methyl  D  aspartate receptors',
#   'NFAT2',
#   'NHEJ3B',
#   'NIP3D',
#   'NOS',
#   'NSC homo  interacting protein',
#   'NSE',
#   'Nucleofuscin',
#   'PBP',
#   'PKAa2',
#   'PTP1',
#   'RhoA',
#   'S100A10',
#   'SCAAN2',
#   'SCAAT',
#   'SCN2',
#   'SLC40A6',
#   'SMA',
#   'SNS  alpha',
#   'SNX1',
#   'SPAN1',
#   'SPAN2',
#   'SPCAT2',
#   'SPGK1',
#   'SbA2',
#   'Sigma70',
#   'Spinocerebellar ataxia type 1',
#   'TDP43',
#   'TGF  alpha',
#   'TGRF',
#   'TNF',
#   'V1s',
#   'VAMP',
#   'VZF6',
#   'YKK1',
#   'YKK2',
#   'adenosine kinase',
#   'ataxin1',
#   'ataxinogen',
#   'atxNod2',
#   'c  myc',
#   'cassinin  related protein',
#   'cdk4',
#   'chemokine receptor',
#   'cyclin',
#   'enzyme',
#   'extracellular tyrosine kinase domain',
#   'fos',
#   'kinases',
#   'p50',
#   'p53',
#   'p85',
#   'protein kinase A2',
#   'protein phosphatase',
#   'protein tyrosine kinase family',
#   'scA2a',
#   'small GTPase',
#   'tyrosine kinase motifs',
#   'ubiquitin ligase'},
#  'Urticaria': {'5HT3',
#   'C  reactive protein',
#   'CD19',
#   'CDK10',
#   'CDKN1A',
#   'CXCR4',
#   'CYP2D6',
#   'E  selectin',
#   'EGF',
#   'EL',
#   'FGFs',
#   'FGFα',
#   'G  proteins',
#   'GM  CSF',
#   'GluA2A',
#   'H1',
#   'H1  C and H1  C receptors',
#   'H2 receptors',
#   'HLA  DQ2',
#   'HSP70',
#   'HSP70containing',
#   'HSP72',
#   'HUBD1',
#   'IL',
#   'IL1',
#   'IL10',
#   'IL12',
#   'IL15',
#   'IL2',
#   'IL5',
#   'IL6',
#   'ILs',
#   'IgE',
#   'IgE antibodies',
#   'IgE antibody family',
#   'N  glycosidase',
#   'NF  kappaB',
#   'PDE8',
#   'PDGF  α',
#   'TNF',
#   'TNFRSF1',
#   'Thrombin',
#   'UBA3',
#   'UBA4  5',
#   'Vascular endothelial growth factor',
#   'aminotransferase',
#   'angiotensin',
#   'angiotensin II',
#   'angiotensin receptors',
#   'epinephrine receptor',
#   'growth hormone',
#   'histamine H1',
#   'histamine H1  C  receptor',
#   'histamine H1  H1   H3  H5 and H6 histamine proleukins',
#   'histamine H1 and H1  O receptor',
#   'histamine H1s',
#   'histamine H3 receptor',
#   'histamine H3 receptors',
#   'histamine receptors',
#   'inositol phosphate 5phosphate binding domain',
#   'interleukin2',
#   'kinase',
#   'matrix metalloproteinases',
#   'rHuPE',
#   'recombinant human erythropoietin',
#   'urea transporters',
#   'α  subtype histamine receptors'},
#  'Hurler syndrome': {'3CID',
#   '3CID protein',
#   'ATP synthase',
#   'Adeno  associated virus inducible protein',
#   'BRCA',
#   'CCTN',
#   'CEA',
#   'CGRP',
#   'CGRP receptor',
#   'CRLF9',
#   'DAD',
#   'FMR1',
#   'FMR2',
#   'GAS1',
#   'GPP1',
#   'GPR102which',
#   'GlcNAc  GlcT  GluT',
#   'H3',
#   'H3A',
#   'HLA',
#   'HRS1',
#   'HSP30',
#   'HSP30  34',
#   'HSP50 family',
#   'HSP60',
#   'HSP70',
#   'HSP70A',
#   'HSP70B',
#   'HSP72',
#   'HSP80',
#   'HSP84',
#   'HSP90',
#   'HSR',
#   'HSp84',
#   'HTRA2',
#   'HsT',
#   'Hsp80',
#   'Hsp95',
#   'Human Leukocyte Antigen',
#   'Insulin',
#   'LKX11',
#   'NAD+ oxidoreductase',
#   'NF  kB',
#   'NPM',
#   'Nod',
#   'PD1',
#   'PDKIT',
#   'PEDG',
#   'PGPN',
#   'PI3kinase kinase kinase',
#   'PLC',
#   'PPARγ',
#   'PRNT6',
#   'PTPN14',
#   'PTPN14A',
#   'RNA polymerase II',
#   'SLC15A2',
#   'STAT3',
#   'STAT9',
#   'Src',
#   'TERT',
#   'TGF',
#   'TGF  Beta',
#   'TGF  Beta receptor',
#   'TGF  beta',
#   'TIE1',
#   'TIE3',
#   'TNF receptor',
#   'UDP  N  acetylglucosaminyl transferase',
#   'UGGT',
#   'VEGF',
#   'Yes',
#   'ZNF27',
#   'acetyltransferase',
#   'epsA',
#   'glycosidase',
#   'histone deacetylase',
#   'histones',
#   'hsp70',
#   'htrA2',
#   'p38 MAP kinase',
#   'polyketide  like receptor tyrosine kinase',
#   'protein kinase',
#   'transcription factor'},
#  'Testicular Germ Cell Tumors; seminoma': {'AKT',
#   'BRCA',
#   'BRCA1',
#   'BRCA2',
#   'CAM',
#   'CDK7',
#   'CRL17B',
#   'DNA Damage DNA  mRNA Damage Protein Kinase',
#   'E2F transcription factor',
#   'EGF',
#   'EGFR',
#   'EGFR2',
#   'EGFRγ',
#   'FADD',
#   'FET2',
#   'FGFRs',
#   'GAL4',
#   'HER2',
#   'HSP70',
#   'JAK  JAK2  7',
#   'JAK3  7',
#   'KLH',
#   'LINK1',
#   'Mitogen activated protein kinases',
#   'P53',
#   'PIK3RA',
#   'PKC',
#   'PKCδ',
#   'PSA',
#   'PTCB  R protein',
#   'RAS',
#   'S6K4',
#   'SGC  T',
#   'TCR',
#   'TCRs',
#   'TGF  beta1',
#   'TGF  beta2',
#   'TGF  β',
#   'Yes',
#   'anti  immunoglobulin G antibody',
#   'aromatase',
#   'c  Jun',
#   'epidermal growth factor receptor',
#   'epidermal growth factor receptor 2',
#   'epidermal growth factor receptor γ',
#   'epidermal growth factor receptor δ',
#   'epidermal growth factor receptors',
#   'estrogen receptor',
#   'estrogen receptors',
#   'gliadin',
#   'growth factor',
#   'immunoglobulin G',
#   'p53',
#   'p53targeting',
#   'prostate cancer antigen',
#   'protein kinases',
#   'protein tyrosine phosphatase',
#   'receptor tyrosine kinases',
#   'transcription factors'},
#  'Acne': {'5alpha reductase',
#   'BMP',
#   'BMP4',
#   'BMP7',
#   'Cytokine',
#   'Cytokines',
#   'DERM',
#   'FGF1',
#   'FGF19',
#   'HLA',
#   'IGF  I',
#   'IGF  I receptor',
#   'IGF  binding protein',
#   'IGF2r',
#   'IL 1',
#   'IL1',
#   'IL1 alpha',
#   'IL10',
#   'IL12A',
#   'IL13',
#   'IL16',
#   'IL17A',
#   'IL17B',
#   'IL23',
#   'IL27',
#   'IL7',
#   'Interleukin 1',
#   'Interleukin IL 6',
#   'Interleukin10',
#   'Interleukin23',
#   'Interleukin27',
#   'MAF',
#   'MAF receptors',
#   'MCP  E',
#   'PCSK9',
#   'PDE II',
#   'PDE IV',
#   'PDE VII',
#   'PDE5A',
#   'PI3 K',
#   'SGLT2  3',
#   'Sirt1',
#   'Sirt3',
#   'Sirt4',
#   'Sirta',
#   'Sirtuins',
#   'T  REX2',
#   'TGF  beta',
#   'TGFβ',
#   'TNF  alpha',
#   'Tumor Repressor and Nuclear Expression Factor 2',
#   'cyclins',
#   'cytokine',
#   'cytokines',
#   'growth hormone',
#   'histamine receptors',
#   'imho',
#   'insulin',
#   'interleukin 16',
#   'proprotein convertase subtilisin  kexin type 9',
#   'seb',
#   'tumor necrosis factor  TNF  alpha',
#   'viral reverse transcriptase'},
#  'Heart failure': {'A  Beta receptor',
#   'ACE',
#   'ACE1',
#   'ACE2',
#   'AKT',
#   'AMPK',
#   'Akt2',
#   'Atriomyosin',
#   'B2',
#   'BCL2',
#   'C9orf72',
#   'CK',
#   'CK1',
#   'CK2',
#   'CRH',
#   'Corticotropin  releasing hormone',
#   'D2R',
#   'Fibroblast growth factor receptor',
#   'Gq',
#   'IL6',
#   'Ile  inhibiting factor',
#   'Interleukin6',
#   'JAK2',
#   'KIAA1',
#   'LINC2',
#   'Myosin',
#   'Myostatin',
#   'Nerve growth factor',
#   'Nrf2',
#   'Nrf32',
#   'P300',
#   'Protein kinase B',
#   'Protein kinase C',
#   'Protein kinase D',
#   'Protein kinase E',
#   'Protein kinase F',
#   'Protein kinase G',
#   'Protein kinase H',
#   'Protein kinase K',
#   'Protein kinases',
#   'Serine  threonine kallikrein  phosphatidylinositol 4kinase',
#   'TCD2',
#   'TNF family',
#   'Tissue plasminogen activator',
#   'UGT1B1',
#   'Vitamin D2 receptor',
#   'Yes',
#   'angiotensin  converting enzyme',
#   'angiotensin II receptor',
#   'angiotensin converting enzyme',
#   'angiotensinogen',
#   'beta2 microglobulin',
#   'calcium channel',
#   'creatine kinase',
#   'cytokine',
#   'fibrin',
#   'fibrin protein',
#   'fibrinogen',
#   'insulin',
#   'low  density lipoprotein lipase',
#   'myostatin',
#   'protein kinases',
#   'statin receptor'},
#  'Metabolic syndrome': {'BDNF',
#   'C  Met',
#   'C  Reactive Protein  CRP  2',
#   'C  peptide',
#   'C  reactive protein',
#   'CCAMP',
#   'CK1A',
#   'CRP',
#   'GAPDH',
#   'GLUT2',
#   'HDL',
#   'HbA',
#   'HbA1C',
#   'IGF1',
#   'IKZF1',
#   'IKZF4',
#   'IL6',
#   'Insulin',
#   'LDL',
#   'LDL  P',
#   'LDL 1c',
#   'Low  density lipoprotein triglyceride  LDL    1a',
#   'Lp  a ',
#   'M1R',
#   'MMP9',
#   'Met7',
#   'MetS2',
#   'MetS2Lock',
#   'MetS2Locked',
#   'MetS2Locks',
#   'PI3 K',
#   'SIRT1',
#   'TNF1',
#   'angiotensin II receptor',
#   'cytokines',
#   'hemoglobin',
#   'insulin',
#   'leptin',
#   'low  density lipoprotein  LDL  3',
#   'met1',
#   'met7',
#   'myoglobin',
#   'pectinesterase',
#   'protein 1b'},
#  'Celiac disease': {'CD20',
#   'CD3',
# ...
#   'insulin receptor',
#   'interferon',
#   'luciferase',
#   'opioid receptors',
#   'proteases',
#   'tubulin'},
#  'Uterine leiomyosarcoma': {'4 tyrosine kinases 1 and 6',
#   'ABO',
#   'B7',
#   'HLA  A2',
#   'HLA  DQ2',
#   'HMP95A',
#   'HSP70',
#   'IL2',
#   'IL23',
#   'JAK2',
#   'MIF2',
#   'MLL',
#   'NTRK2',
#   'PARP',
#   'PARP1',
#   'PI3K',
#   'PTGM1',
#   'RARGs',
#   'S1 proteins',
#   'STAT',
#   'TERT kinase',
#   'TGF  beta',
#   'TGFβ superfamily',
#   'TRK',
#   'ULTEM',
#   'VEGFR2',
#   'antibodies',
#   'estrogen receptor',
#   'growth factors',
#   'jak2',
#   'kallikrein1',
#   'kinases',
#   'leiomyosin',
#   'mitogen activated protein kinase 3  6 kinases',
#   'mitosis dependent proliferation  associated protein  coupled kinase',
#   'nestin',
#   'p27 Kip1',
#   'p53',
#   'pam 3p',
#   'protein kallikrein',
#   'protein kinase C',
#   'ras'},
#  'Machado-Joseph disease': {'ARF',
#   'CDK4  6',
#   'CHEN',
#   'CNTNAP',
#   'DYRK1A',
#   'EAPs',
#   'EPRV',
#   'ERBP1',
#   'FAS',
#   'FSH',
#   'FTO',
#   'FUS1',
#   'FUS2',
#   'G  actin',
#   'G  protein',
#   'G protein coupled receptor',
#   'G3A10',
#   'GAD6',
#   'GATA1',
#   'GPCR',
#   'GPR16',
#   'GUS',
#   'Insulin  like growth factor',
#   'KMD',
#   'LEK',
#   'LH',
#   'LaminA2',
#   'MAPK',
#   'MCD1',
#   'MCHG',
#   'MCM2',
#   'MDM1',
#   'MDM2',
#   'MDR1',
#   'MEF1',
#   'MST1',
#   'MTD1A',
#   'MTD1B',
#   'MTD1C',
#   'MTHFR',
#   'MTHFR3',
#   'MTT2',
#   'MjD',
#   'NAPA11',
#   'NRP',
#   'Nr5A',
#   'PDL1',
#   'PI3 K',
#   'PIK3CA',
#   'Proteases',
#   'RNA polymerase III',
#   'RNA polymerase alpha 3',
#   'RNA polymerase alpha 6',
#   'SNSF',
#   'TCF2A',
#   'TCR',
#   'TEC',
#   'TECAT',
#   'TTR',
#   'Xp31',
#   'acetyl CoA dehydrogenase',
#   'alpha 3  4',
#   'cyclin A',
#   'fibrinogen',
#   'hsp90',
#   'kinase',
#   'machosins',
#   'myosin',
#   'nRP1 families',
#   'nucleases',
#   'p53',
#   'proteases',
#   'tumor suppressor protein alpha'},
#  'head and neck squamous cell carcinoma, tongue': {'Akt',
#   'BCRP',
#   'BRCA',
#   'BRCA2',
#   'CD154',
#   'CD8',
#   'CDKN1A',
#   'EGFR',
#   'EIF3A3',
#   'Endothelin receptor  ETR',
#   'FMR1',
#   'FUBAR2  3',
#   'G protein',
#   'Gp85',
#   'IGF1R',
#   'IL6',
#   'INF alpha',
#   'Interleukin 8  IL8',
#   'LCR1',
#   'MDA3',
#   'MUC15',
#   'Mucin5',
#   'NF1',
#   'Nef',
#   'PD  L1',
#   'PD1',
#   'PDB2',
#   'PDL1',
#   'RANTES',
#   'SIRT1',
#   'T cell receptors',
#   'TNF',
#   'TNF alpha',
#   'TNF receptors',
#   'Tumor  associated lipoprotein  TALP',
#   'VEGF',
#   'epidermal growth factor receptor',
#   'g  protein',
#   'p53',
#   'protein kinases',
#   'transcription factor',
#   'vAMP1'},
#  'Leigh syndrome': {'A4 locus',
#   'AFAIK',
#   'BRCA1',
#   'BRCA2',
#   'BRCA2B',
#   'Btk',
#   'CEA',
#   'DIP',
#   'EPR',
#   'FK506',
#   'FMS1',
#   'FOXG1',
#   'FOXN1',
#   'Foxg1',
#   'HIF1α',
#   'HLA',
#   'HLA  B27',
#   'HLA  DQ2',
#   'HLA  DR2',
#   'HLA  DR8',
#   'HN',
#   'HNPC3',
#   'LHRH',
#   'Leigh',
#   'MAL1',
#   'MHC',
#   'MHC  A4',
#   'MKK1',
#   'MTHFR',
#   'Ml4',
#   'Ml8',
#   'NHT1',
#   'NOD3',
#   'PK1',
#   'RNA polymerase',
#   'RNase F',
#   'RNase M',
#   'RTK',
#   'RXR',
#   'SLC6A6',
#   'SMA1',
#   'SMC1',
#   'TDP receptor',
#   'TDP43',
#   'TL',
#   'collagen',
#   'glutamate receptors',
#   'kinases',
#   'myostatin',
#   'p53',
#   'polymerase',
#   'protein kinase alpha',
#   'protein tyrosine kinases',
#   'receptor tyrosine kinase',
#   'retinoid X receptor',
#   'tachykinin',
#   'thromboplastin',
#   'transcription factor',
#   'trypsin',
#   'α  synuclein'},
#  'Hutchinson-Gilford progeria syndrome': {' polypleuralin proteins',
#   'CCR4',
#   'DNA polymerase',
#   'DYRK1A',
#   'EGR',
#   'EGR receptor',
#   'EML4',
#   'FGF',
#   'FHIRs',
#   'GAP',
#   'H  G',
#   'H  GPRS',
#   'HGF',
#   'HGF1',
#   'HGP',
#   'HGP genes',
#   'HGP1',
#   'IGF1 receptor',
#   'IGF1 receptors',
#   'KIN1',
#   'KIN2',
#   'KIR',
#   'KIR41  61',
#   'MDM2',
#   'MDM3',
#   'Myc',
#   'NAMPT',
#   'Nucleoside phosphorylated tRNA synthetase',
#   'P3P3',
#   'P3P3 genes',
#   'PIK3CA',
#   'PKK',
#   'RAS',
#   'SAR',
#   'SHH',
#   'TIFRS',
#   'collagen',
#   'eML4',
#   'epidermal growth factor receptor',
#   'growth factors',
#   'insulin',
#   'kinases',
#   'p53',
#   'phosphodiesterase type 3',
#   'phosphodiesterase type 4',
#   'polycistronin II beta  barrel',
#   'polypleura',
#   'polypleuralins',
#   'protein kinase C family',
#   'telomerase',
#   'transcription factors'},
#  'Ullrich congenital muscular dystrophy': {'ABO',
#   'ATP synthase',
#   'Allelin',
#   'AβPPR1',
#   'AβPPR2',
#   'B  raf',
#   'BCR2',
#   'D10 gene',
#   'D3D10',
#   'Fibroblast growth factor 1',
#   'G  protein coupled factors',
#   'GATA3',
#   'GDNF',
#   'GMP  inositol  modifying protein',
#   'GMPIP',
#   'GRN',
#   'GSK3B',
#   'LAMDA2',
#   'MDA1',
#   'MECP2',
#   'MSPC1',
#   'MTHFR',
#   'MTHFRA',
#   'Myostatin',
#   'PANM1',
#   'Protein Kinase A  C',
#   'RGC  I',
#   'S  CDS1',
#   'SDP  A2',
#   'SOD1',
#   'Sirtuin 1',
#   'TGF2',
#   'TRPs',
#   'UCCM1',
#   'UCDM',
#   'UCT11',
#   'UDC1',
#   'UGT1A4',
#   'ULC3 M',
#   'ULCN1',
#   'UPT1',
#   '_ b  raf',
#   '_ b  raf  l_',
#   'amyloid β  protein related protein',
#   'b  raf  l',
#   'beta  amyloid  like proteins',
#   'cardiac myosin',
#   'collagen',
#   'collagen type VIIB',
#   'dystrophin',
#   'dystrophin family',
#   'insulin',
#   'lsd1',
#   'mdm12',
#   'myostatin',
#   'sirtuin 1',
#   'transcription factors',
#   'uld1p',
#   'uld2',
#   'uld3'},
#  'Epidermolysis bullosa simplex': {'A  Glycoprotein complex',
#   'B  Reactive Protein 1',
#   'BACALAC',
#   'BMP',
#   'Bcl2b',
#   'CCR1',
#   'CRL6',
#   'CXCL9',
#   'Chymotrypsin',
#   'DPP  IV',
#   'EB gene products',
#   'EB gene receptor',
#   'EBG',
#   'EBP3',
#   'EBS',
#   'ECRF',
#   'EDI',
#   'EGF',
#   'EGFR',
#   'EGFR  α',
#   'EPPCR',
#   'ERBB2',
#   'ERK',
#   'FGF2',
#   'FGF21',
#   'FMT',
#   'G  protein',
#   'GDF15',
#   'GPIb  A  Glycoprotein complex',
#   'Glycoproteins',
#   'H1glycoproteins',
#   'H2proteases',
#   'HGF',
#   'IGF1',
#   'IL1β',
#   'KDM1',
#   'KGF',
#   'LAG1',
#   'LAG1A',
#   'M  ATF',
#   'MEK',
#   'MIP1β',
#   'MLL',
#   'Mck1',
#   'Mcl2',
#   'Metalloproteases',
#   'Mucin',
#   'Myosin',
#   'NFAT',
#   'NTR1like',
#   'PARP',
#   'PDGF2',
#   'PDGFR  α',
#   'PGC1α',
#   'PGE2',
#   'PI3K  kappa',
#   'PI3Kinase',
#   'PIK3CA',
#   'Psm2',
#   'Rb',
#   'Serine  threonine proteases',
#   'TGF  beta',
#   'TNF',
#   'TNF  α',
#   'TTR',
#   'VEGF',
#   'VEGF receptors',
#   'Xsensin1',
#   'actin',
#   'alpha  NTR1α + α  NTR1β',
#   'alpha  sialoglycoprotein',
#   'alphaSGP',
#   'chondroitin sulfate proteoglycan deaminase',
#   'collagen',
#   'collagenase',
#   'elastase',
#   'epidermal development inhibitor',
#   'epidermal growth factor',
#   'epidermal growth factor receptor',
#   'epidermal growth factor receptor 2',
#   'epidermal growth factors',
#   'fibroblast growth factor receptor 2',
#   'glycoproteins',
#   'growth factor receptor',
#   'growth factor receptors',
#   'human CD49b  CD40b  CD80 family',
#   'human M  RANKL receptor',
#   'human TRIM14 ligand',
#   'insulin',
#   'interferon',
#   'keratalin tyrosine kinase c',
#   'keratin',
#   'keratin 11',
#   'keratin 8',
#   'keratinocyte exfoliative proteins',
#   'keratinocyte growth factor',
#   'lacZ',
#   'leukodystrophin  encoded glycoprotein',
#   'lysase',
#   'p16',
#   'p38',
#   'pOMALEE family',
#   'pepsin',
#   'poly  ADP  ribose  polymerase',
#   'pomALEE1',
#   'pomalee1',
#   'protease',
#   'protein elastase',
#   'protein kinase c',
#   'rheumatoid factor protein',
#   'sensin1',
#   'transthyretin',
#   'transthyretin protein',
#   'trypsin',
#   'type 1 collagen  binding protein antigen',
#   'type I DNA polymerase family',
#   'type I DNA polymerases',
#   'tyrosine kinase kinase kinase c'},
#  'Stroke': {'A1 enzyme',
#   'A2A',
#   'A2B',
#   'ABIF',
#   'Abeta',
#   'Abl',
#   'Angiotensin II',
#   'Apo E4',
#   'C  Reactive Protein',
#   'COX2',
#   'CRLY',
#   'CRLY2',
#   'CRP',
#   'FotC',
#   'LDL',
#   'NMDA receptors',
#   'NPY',
#   'Neuropeptide Y',
#   'PFC',
#   'PGC1alpha',
#   'PKC',
#   'TDP43',
#   'VAP',
#   'VSD3',
#   'Yes',
#   'adenylate cyclase',
#   'alpha  synuclein',
#   'amyloid  beta',
#   'amyloid beta',
#   'blood vessel growth factor',
#   'chIP',
#   'fibrin',
#   'low  density lipoprotein',
#   'neuropeptide Y',
#   'tau',
#   'β  secretase'},
#  'chromophobe renal cell carcinoma': {'BMP7',
#   'BRAF',
#   'C  SIF',
#   'CD19',
#   'CD25',
#   'CD4',
#   'CD47',
#   'CD63',
#   'CD73',
#   'CD8',
#   'CDK',
#   'CDK4',
#   'CDKN2A',
#   'CDKs',
#   'CDNA1',
#   'CRK',
#   'CTGF',
#   'CTGF receptor',
#   'CTLA4',
#   'CYPSS4',
#   'DNA  proteinases',
#   'EGFR',
#   'EYAC',
#   'EZH2',
#   'Endostatin',
#   'Fibronectin',
#   'GATA6',
#   'Glp  kinase  like  rephosphorylated Glycogenyl  Glucosamine  phosphate Glycobiotin  binding Protein',
#   'Glypho  kinase',
#   'HER2',
#   'HoxB1',
#   'MDRB',
#   'MMP9',
#   'NTRKL receptor',
#   'PARP',
#   'PD  L1',
#   'PD1',
#   'PD1 receptors',
#   'PDGF',
#   'PDGF receptor protein',
#   'PDGF receptor type I',
#   'PDGF receptor type II',
#   'PDGF receptor type III',
#   'PDGFR',
#   'PI3 kinase',
#   'PIK3CA',
#   'PLC',
#   'Prolactin1 receptor',
#   'RANKL  A',
#   'RCC2',
#   'RIG  I',
#   'Rho',
#   'Rho group proteins',
#   'Src',
#   'T cell receptor family',
#   'TEGE',
#   'TGF  β',
#   'TGFBSR1',
#   'TP53',
#   'Tissue Inhibin',
#   'VEGFR2',
#   'Yes',
#   'aldosterone receptor',
#   'amyloid proteins',
#   'anti  PD  L1',
#   'c  Met',
#   'c  myc',
#   'fibronectin',
#   'histones',
#   'kinase',
#   'kinases',
#   'membrane  associated tyrosine kinases',
#   'p16',
#   'protein tyrosine kinases',
#   'superfamily of membrane associated tyrosine kinases',
#   'tel',
#   'telomerase',
#   'tyrosine kinases'},
#  'Guillain-Barre syndrome': {'A2B proteins',
#   'A8V1',
#   'C  type G  protein  coupled receptor',
#   'CD44',
#   'CD73',
#   'CNA1 receptor  I',
#   'EPP1',
#   'FADD',
#   'Fibrinogen',
#   'G  CSF',
#   'G protein',
#   'GABAA receptor',
#   'GADD45',
#   'GAG1',
#   'GDNF',
#   'Gag',
#   'IL1',
#   'IgA',
#   'IgE',
#   'KRAB',
#   'Nag',
#   'Ras',
#   'TGF  b',
#   'TGF family',
#   'TNF',
#   'TNF receptor',
#   'TNF receptor alpha',
#   'TNF receptors alpha',
#   'TNFs',
#   'TRPC8',
#   'Yes',
#   '_ nucleases',
#   'acetylcholine receptor',
#   'cdb1',
#   'cdc2',
#   'collagens',
#   'cytokines',
#   'gbs',
#   'glutamate protein',
#   'glutamate receptor',
#   'guanine nucleotide binding proteins',
#   'guanylyl cyclase',
#   'immunoglobulin',
#   'insulin',
#   'interferon',
#   'interferon  α1a',
#   'myelin protective protein',
#   'neurotropin  C',
#   'protein C',
#   'thrombin',
#   'trypsin',
#   'ubiquitin'},
#  'Embryonal rhabdomyosarcoma': {'Abl',
#   'BCL2',
#   'C  EBP',
#   'CD23',
#   'CD34',
#   'CD4',
#   'CD40',
#   'CD45',
#   'CD68',
#   'CD8',
#   'Cytokines',
#   'EGFR',
#   'EMT2',
#   'EPO',
#   'ER  ligand',
#   'ERG',
#   'ERK',
#   'ErbB',
#   'Erythropoietin',
#   'HDACs',
#   'IGF',
#   'IL31',
#   'IgA',
#   'IgB',
#   'Irskine',
#   'MDR1',
#   'NGF',
#   'PDGF  Ribonuclease  J',
#   'PKA',
#   'RAS',
#   'RIG  I',
#   'RMS',
#   'SRC',
#   'Yes',
#   'histone deacetylases',
#   'kinases',
#   'let',
#   'mRNCC1',
#   'mammalian RAS genes',
#   'myostatin',
#   'transcription factor'},
#  'Primary biliary cirrhosis': {'ALDH',
#   'ATM',
#   'ATR',
#   'BCL1',
#   'BCL1 molecule',
#   'BCL2',
#   'BCL2 molecule',
#   'BRCA',
#   'Bcl  xL',
#   'C3  4',
#   'CD30',
#   'CD4+CD25',
#   'CD73',
#   'CD73based',
#   'CTLA4',
#   'CYP 2D6',
#   'CYP1A2',
#   'ETS1 family',
#   'FGF',
#   'FSH',
#   'GAP',
#   'GATA1',
#   'GATA2',
#   'GATA4',
#   'GFRC4',
#   'GSK3',
#   'HCG',
#   'IL17A',
#   'LH',
#   'MTHFR',
#   'NAG',
#   'NFKB',
#   'Nrf1',
#   'PBC',
#   'PIP36',
#   'PPAR  alpha',
#   'PPARs',
#   'RAS',
#   'SIRT1',
#   'SOD',
#   'SOD1',
#   'TAR2',
#   'TCR',
#   'TFIIS',
#   'TGF  beta',
#   'TGFβ',
#   'TNFalpha',
#   'TNFα',
#   'alpHD',
#   'chemokine',
#   'chemokine receptor',
#   'cytokine',
#   'fatty acid methyltransferase',
#   'fibroblast growth factor',
#   'fibronectin',
#   'mTOR',
#   'neTNFalpha',
#   'p17Akt',
#   'p53'},
#  'Hyperglycemia': {'2phosphoglycerate kinase',
#   'A  S  glyk  phosphoglycerate kinase',
#   'A1 receptor',
#   'A12 receptor',
#   'A1A1',
#   'A1A2',
#   'A3 receptors',
#   'AMP phosphotyrosine binding protein',
#   'AMPPH',
#   'CHDM5F',
#   'CRF4',
#   'DPP4',
#   'DPP9',
#   'FGF2',
#   'GIP',
#   'GLP1',
#   'GLP1 receptors',
#   'GLUT1',
#   'GLUT4',
#   'GLUT5',
#   'GPCR  alpha  beta  gamma  epsilon  5',
#   'GPCRs',
#   'Glucocerebrosidase',
#   'HACE1',
#   'HDL',
#   'HMG  CoA dehydrogenase',
#   'HMG  CoA reductase',
#   'HMG  CoA reductase  synthetase',
#   'IGF1',
#   'IGF3',
#   'IL13',
#   'Insulin',
#   'Insulin Receptor Subtype 1',
#   'LDL',
#   'LICA2',
#   'LRP1',
#   'Leucine Releasing Peptide Receptors 1',
#   'MALP1',
#   'NF  κB',
#   'NHE2',
#   'NHE3',
#   'PDE5',
#   'PDGFRalpha',
#   'PKA',
#   'PR1A',
#   'RAB',
#   'SGLT2',
#   'TGR5',
#   'TGR6',
#   'TNF  alpha',
#   'cholesterol carrier factor   4',
#   'glucose transporter',
#   'insulin',
#   'insulin receptor',
#   'insulin receptors',
#   'lipoprotein  a  transporter',
#   'me',
#   'phospholipase A2',
#   'protein kinase'},
#  'Kidney renal clear cell carcinoma': {'B7',
#   'BH4',
#   'CCR5',
#   'CD25',
#   'CD4',
#   'CK2Eli3p',
#   'CK3',
#   'CK3 superfamily',
#   'CTX2',
#   'Cpf1',
#   'ECL2',
#   'EGF',
#   'EGF  R',
#   'EGF2α',
#   'EGFR',
#   'FGF18',
#   'FOXO',
#   'Fgf18',
#   'GBA1',
#   'GDF6',
#   'HER2  3',
#   'Hb',
#   'IFN  γ',
#   'IL6',
#   'JAK',
#   'K2R',
#   'KCR',
#   'KIR',
#   'KRCA2',
#   'Klk',
#   'MAP2K1',
#   'MMP',
#   'MMP12',
#   'MMP13',
#   'MMP2',
#   'MMP9',
#   'MMPs A and B',
#   'MUC15',
#   'Mucin 1',
#   'Nrf2',
#   'Nrf3',
#   'Nrf4',
#   'PDGF  alpha',
#   'PDGF receptor 1',
#   'PDGF receptor 2',
#   'PDGF receptor 3',
#   'PDGF receptor family',
#   'PDGF receptors',
#   'PI3 K',
#   'PIK3CA',
#   'RARG',
#   'Ras  Kd  Vq  kinase',
#   'SLC7A4',
#   'TGF  b',
#   'TGF1',
#   'TGFB',
#   'TLRs',
#   'TNF',
#   'V  SIRP',
#   'VEGF',
#   'adenosine triphosphate  mediated kinase',
#   'adhesion molecule',
#   'c  Jun N  terminal kinase',
#   'c  Myc',
#   'c  kit',
#   'collagen',
#   'cyclophilin3',
#   'epithelins',
#   'lck',
#   'low density lipoproteins',
#   'p53',
#   'receptor for IL6 RING',
#   'tumor suppressor protein 1  2',
#   'α integrin'},
#  'Melanocytic nevus': {'ABC transporter',
#   'ATP synthases',
#   'BRAF',
#   'CBLT3',
#   'CD19',
#   'Cd73',
#   'Cytochrome p family',
#   'EGFR',
#   'FcγRs',
#   'GAL4',
#   'GPR10',
#   'GPR25',
#   'HLA  A2',
#   'IgG4',
#   'LHRH',
#   'Luteinizing hormone  releasing hormone',
#   'M3 gene',
#   'MECP1',
#   'MECP2',
#   'MHC',
#   'MLL',
#   'MMP',
#   'MMP1',
#   'MMP2',
#   'MMP9',
#   'MUC1',
#   'Melanin receptor',
#   'Melanocyte stimulating factors',
#   'Melanocyte stimulating hormone antibody',
#   'Mito kinase 3',
#   'Nfld1',
#   'P53',
#   'PGE receptor',
#   'PGER2',
#   'SCC4',
#   'SRPK1 G',
#   'SRPT',
#   'SRPT2',
#   'SRPT7',
#   'SRPTB',
#   'SRPT_B',
#   'TIGIT',
#   'TNF',
#   'Thrombospondin',
#   'Yes',
#   'anti  CD40 antibodies',
#   'cytokines',
#   'mTOR',
#   'melanocyte stimulating hormone',
#   'melanocytic receptor',
#   'melanoma  associated protein',
#   'melanoproteinase',
#   'molecullin',
#   'p53',
#   'serine  threonine kinase',
#   'transcription factors',
#   'tumor necrosis factor alpha'},
#  'Prostate adenocarcinoma': {'5α  reductase',
#   'ADAPT',
#   'APC',
#   'ATPase',
#   'ATPases',
#   'Abreastin',
#   'Aromatase',
#   'CTLL1',
#   'DNA29',
#   'ERBB2',
#   'Enzyme1110',
#   'ErbB',
#   'FSH',
#   'G12c protein',
#   'GIST1',
#   'H  RAS',
#   'H3 kinases',
#   'HER2',
#   'HER2  neu',
#   'Interferons',
#   'Interleukin',
#   'Interleukin 1 alpha',
#   'Interleukin2 alpha',
#   'LHRH',
#   'Leydig cell1513 Microtubule  associated protein 2b2016',
#   'MAPK1',
#   'MMP',
#   'MMP9',
#   'MMPs',
#   'Mcl1',
#   'Nucleotide Acid Polymerase',
#   'PADC',
#   'PARP',
#   'PAdC',
#   'PAdCs',
#   'PCA1',
#   'PCAF1',
#   'PD  L1',
#   'PDE3  4 Receptors',
#   'PGRP1',
#   'PGRP2',
#   'PIK3P',
#   'PLC',
#   'PP1',
#   'PPD1',
#   'PSA',
#   'PSD95',
#   'PSH',
#   'PSMA',
#   'PTH2  9',
#   'Prolactin',
#   'Prostate  specific Antigen',
#   'Prostate  specific antigen',
#   'Prostate Stimulating Hormone',
#   'Prostate cancer antigen 1',
#   'Prostate specific antigen  1  2',
#   'Prostate specific membrane antigen  2  3',
#   'Prostatic Adenomethylate Kinase 1',
#   'Prostatic Protease 1',
#   'Prostatic Protease 2',
#   'Prostatic secretory duct protein',
#   'RIF1',
#   'SINE',
#   'SINE1',
#   'SINE6',
#   'TGF  beta',
#   'TGF  beta 2',
#   'TIGIT',
#   'TNF',
#   'TURBT',
#   'Tumor Necrosis Factor',
#   'Yes',
#   'adenine nucleotide methyltransferase',
#   'adenocarcinoma  specific proteases',
#   'adenylate cyclase',
#   'aromatase',
#   'c  myc',
#   'chemokine binding protein',
#   'chemokine8',
#   'cytokines',
#   'epidermal growth factor receptor',
#   'glycogen synthase kinase3',
#   'glycoprotein in the cell membrane',
#   'histone H3',
#   'lymphokine',
#   'nuclear factor  kappa B receptor',
#   'p110',
#   'p16',
#   'p21',
#   'p53',
#   'p56',
#   'phosphoinositide 3kinase',
#   'prostate  specific antigen',
#   'prostate  specific membrane antigen',
#   'prostate specific antigen',
#   'transcription factor',
#   'tyrosine hydroxylase'}}

# %%
len(disease2genes)
# Out:
# 207

# %% [markdown]
# ### 2. Get dictionary mapping diseases to set of genes/proteins extracted from TTD

# %%
ttd_data = ttd.split('\n\n')[-1].split('\n\t\t\n')

# %%
disease_tagger = MultiTagger.load("hunflair-disease")


def process_target_ttd_info(s):
    data = list(map(lambda x: x.split('\t'), s.split('\n')))

    target_dict = {'TARGETID': data[0][-1], 
                   'TARGNAME': data[1][-1], 
                   'DISEASES': set()
                  }
    for row in data[2:]:
        sentence = Sentence(row[-1])
        disease_tagger.predict(sentence)
        disease = re.sub(r'[^ \w+]', '', sentence.text)
        target_dict['DISEASES'].add(disease)
        
    return target_dict
# Out:
# 2022-09-03 21:28:44,081 loading file /home/ed/.flair/models/hunflair-disease-full-v1.0.pt
# 2022-09-03 21:28:47,346 SequenceTagger predicts: Dictionary with 8 tags: <unk>, O, B-Disease, E-Disease, I-Disease, S-Disease, <START>, <STOP>

# %%
disease2genes_ttd = {}
t_name2t_id = {}
t_id2t_meta = {}

for data in tqdm(ttd_data):
    target_dict = process_target_ttd_info(data)
    t_name2t_id[target_dict['TARGNAME']] = target_dict['TARGETID']
    t_id2t_meta[target_dict['TARGETID']] = [target_dict['TARGNAME'], target_dict['DISEASES']]
    for disease in target_dict['DISEASES']:
        if disease not in disease2genes_ttd:
            disease2genes_ttd[disease] = set([target_dict['TARGNAME']])
        else:
            disease2genes_ttd[disease].add(target_dict['TARGNAME'])
# Out:
# 100%|██████████████████████████████████████▉| 2372/2373 [01:53<00:00, 15.15it/s]
# 2022-09-03 21:30:54,973 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 100%|███████████████████████████████████████| 2373/2373 [01:53<00:00, 20.85it/s]

# %%
t_name2t_id
# Out:
# {'Transforming growth factor alpha (TGFA)': 'T00033',
#  'CTGF messenger RNA (CTGF mRNA)': 'T00039',
#  'HUMAN cyclin G-associated kinase (GAK)': 'T00043',
#  'HUMAN calpain-1/calpain small subunit 1 heterodimer (CAPN1/CAPNS1)': 'T00099',
#  'Ubiquitin-activating enzyme (UBA)': 'T00100',
#  'Arachidonate 5-lipoxygenase (5-LOX)': 'T00140',
#  'HUMAN pH-dependent viral fusion/replication (pH-DVF/R)': 'T00145',
#  'Short transient receptor potential channel 5 (TRPC5)': 'T00156',
#  'HUMAN glycosylation of host receptor (GHR)': 'T00158',
#  'Ubiquitin-protein ligase E3 Mdm2 (MDM2)': 'T00176',
#  'HUAMN alpha-1 adrenergic receptor (ADRA1)': 'T00216',
#  'NFKB messenger RNA (NFKB mRNA)': 'T00238',
#  'Interleukin-4 (IL4)': 'T00239',
#  'V-erbA-related protein 1 (NR1D1)': 'T00254',
#  'HUAMN eIF4E-eIF4G interaction (eIF4E-eIF4G)': 'T00259',
#  'Fast skeletal muscle troponin complex (TNNC2)': 'T00419',
#  'Human immunodeficiency virus Rev protein (HIV rev)': 'T00420',
#  'Serine Racemase (SRR)': 'T00477',
#  'Interleukin 23 receptor (IL23R)': 'T00484',
#  'ATP-binding cassette transporter A1 (ABCA1)': 'T00494',
#  'Prostate apoptosis response-4 (PAWR)': 'T00496',
#  'Glucose transporter type 9 (GLUT9)': 'T00523',
#  'Stress-activated protein kinase JNK3 (JNK3)': 'T00663',
#  'MEK kinase kinase 1 (MAP4K1)': 'T00749',
#  'Galactoside 3(4)-L-fucosyltransferase (FUT3)': 'T00750',
#  'C-X-C chemokine receptor type 1 (CXCR1)': 'T00884',
#  'Hydroxycarboxylic acid receptor 3 (HCAR3)': 'T00890',
#  'Protein kinase C epsilon (PRKCE)': 'T00895',
#  'Neurotrophin-4 (NTF4)': 'T00902',
#  'Melanoma antigen gp75 (TYRP1)': 'T00938',
#  'Human immunodeficiency virus Envelope glycoprotein gp120 (HIV gp120)': 'T00972',
#  'Endoplasmic reticulum to nucleus signaling 1 (ERN1)': 'T01003',
#  'Aurora kinase (AURK)': 'T01011',
#  'Colony stimulating factor-1 receptor (CSF-1R)': 'T01110',
#  'microRNA hsa-miR-191 (MIR191)': 'T01141',
#  'T-cells (T-cells)': 'T01232',
#  'Fusion protein Bcr-Abl T315I mutant (Bcr-Abl T315I)': 'T01271',
#  'Beta-site APP-cleaving enzyme 2 (BACE2)': 'T01280',
#  'Tumor susceptibility gene protein 101 (TSG101)': 'T01283',
#  'Plasmodium Dihydroorotate dehydrogenase (Malaria DHOdehase)': 'T01318',
#  'Cell cycle (CC)': 'T01358',
#  'HUMAN valosin-containing protein p97 (VCP)': 'T01385',
#  'NEDD8-activating enzyme (NAE)': 'T01447',
#  'Glutathione S-transferase omega-1 (GSTO-1)': 'T01521',
#  'Sphingosine-1-phosphate lyase 1 (SGPL1)': 'T01575',
#  'Catalase (CAT)': 'T01597',
#  'CEP290 messenger RNA (CEP290 mRNA)': 'T01674',
#  'Adrenergic receptor alpha-2C (ADRA2C)': 'T01777',
#  'COVID-19 non-structural protein 14 (nsp14)': 'T01788',
#  'Haematin (HA)': 'T01822',
#  'Protease unspecific (PRO)': 'T01840',
#  'Integrin beta-1 (ITGB1)': 'T01851',
#  'Plasmodium Hexose transporter 1 (Malaria ht1)': 'T01865',
#  'Tissue kallikrein (KLK2)': 'T01908',
#  'Plasmodium Beta-hydroxyacyl-ACP dehydratase (Malaria FabZ)': 'T01943',
#  'Macrophage-stimulating protein receptor (RON)': 'T01973',
#  'Phosphodiesterase 4D (PDE4D)': 'T02001',
#  "HUMAN inosine-5'-monophosphate dehydrogenase 1 (IMPDH1)": 'T02024',
#  'COVID-19 replicase polyprotein 1ab (pp1ab)': 'T02107',
#  'N-acetylgalactosamine-4-sulfatase (G4S)': 'T02119',
#  'HUAMN monocyte differentiation antigen CD14 (CD14)': 'T02122',
#  'Glutamate--cysteine ligase modifier (GCLM)': 'T02134',
#  'HUAMN serine protease factor Xa (SERPINA5)': 'T02203',
#  'HUMAN calcitonin gene-related peptide type 1 receptor (CALCRL)': 'T02226',
#  'Streptococcus Topoisomerase IV A (Stre-coc parC)': 'T02228',
#  'Iron (Fe)': 'T02246',
#  'DNA-dependent DNA polymerase (DPOL)': 'T02258',
#  'Calcium-activated potassium channel KCa4.1 (KCNT1)': 'T02262',
#  'B-cell-activating factor (TNFSF13B)': 'T02318',
#  'Growth hormone receptor (GHR)': 'T02333',
#  'HUMAN cysteinyl leukotriene receptor (CysLTR)': 'T02389',
#  'HUMAN dipeptidyl peptidase 1 (CTSC)': 'T02392',
#  'Phosphatidylinositol-3-phosphate 5-kinase (PIP5K3)': 'T02469',
#  'HUMAN estrogen receptor (ESR1)': 'T02506',
#  'T-cell surface antigen CD2 (CD2)': 'T02532',
#  'Voltage-gated sodium channel alpha Nav1.4 (SCN4A)': 'T02546',
#  'Dopamine D3 receptor (D3R)': 'T02551',
#  'Prostaglandin E synthase (PTGES)': 'T02562',
#  'Mycobacterium Leucine-tRNA ligase (MycB leuS)': 'T02584',
#  'Human immunodeficiency virus Envelope glycoprotein gp160 (HIV env)': 'T02591',
#  'Leukocyte (WBC)': 'T02598',
#  'Transferrin (TF)': 'T02617',
#  'HUMAN mineralocorticoid receptor (MR)': 'T02653',
#  'Apoptosis inhibitor survivin (BIRC5)': 'T02677',
#  'Bacterial Dihydrofolate reductase (Bact DHFR)': 'T02702',
#  'Nitric-oxide synthase inducible (NOS2)': 'T02703',
#  'Metabotropic glutamate receptor 3 (mGluR3)': 'T02719',
#  'Neurotensin receptor type 1 (NTSR1)': 'T02728',
#  'C-C chemokine receptor type 3 (CCR3)': 'T02752',
#  'ATP-binding cassette transporter C9 (ABCC9)': 'T02777',
#  'Dystrophin nonsense mutant (DMD)': 'T02779',
#  'Interferon-beta (IFNB1)': 'T02808',
#  'HUMAN phosphatidylinositol 3-phosphate 5-kinase (PIKfyve)': 'T02918',
#  'HUMAN programmed cell death protein 1 (PD-1)': 'T02957',
#  'Interleukin 1 receptor accessory protein (IL1RAP)': 'T02974',
#  'Acetylcholine release (Ach rele)': 'T03006',
#  'Mutated KRAS (mKRAS)': 'T03046',
#  'Tumor expressed melanoma antigen (PRAME)': 'T03189',
#  'Ribosomal protein S6 kinase alpha-3 (RSK3)': 'T03279',
#  'Interleukin 2 receptor alpha (IL2RA)': 'T03313',
#  'Interleukin 4 receptor alpha (IL4R)': 'T03346',
#  'Prostaglandin G/H synthase (COX)': 'T03403',
#  'Mycobacterium Membrane protein mmpL3 (MycB mmpL3)': 'T03410',
#  'CFB messenger RNA (CFB mRNA)': 'T03485',
#  'Matrix metalloproteinase-12 (MMP-12)': 'T03500',
#  'Dopamine receptor (DR)': 'T03513',
#  'Immunoglobulin gamma Fc receptor IIB (FCGR2B)': 'T03573',
#  'CREB-binding protein (CREBBP)': 'T03634',
#  'Synuclein alpha (SNCA)': 'T03644',
#  'Adenosine deaminase (ADA)': 'T03661',
#  'Cellular disintegrin-related protein (ADAM9)': 'T03672',
#  'Leukotriene A-4 hydrolase (LTA4H)': 'T03691',
#  'Apoptosis regulator Bcl-W (BCL-W)': 'T03755',
#  'PPAR-gamma messenger RNA (PPARG mRNA)': 'T03818',
#  'H-ras messenger RNA (HRAS mRNA)': 'T03871',
#  'Hepatitis C virus Serine protease NS3/4A (HCV NS3/4A)': 'T03896',
#  'Sodium/potassium-transporting ATPase (SPT ATPase)': 'T03917',
#  'Heat shock protein 90 (HSP90)': 'T03963',
#  'Pneumocystis jirovecii DNA topoisomerase 2 (PJ top2)': 'T03985',
#  'Plasmodial phospholipid metabolism (PPP metab)': 'T04079',
#  'ERBB3 messenger RNA (ERBB3 mRNA)': 'T04084',
#  'P-glycoprotein (P-GP)': 'T04183',
#  'Staphylococcus Alpha-hemolysin (Stap-coc hly)': 'T04321',
#  'TGF-beta-activated kinase 1 (MAP3K7)': 'T04361',
#  'Calcium-activated potassium channel KCa2.3 (KCNN3)': 'T04388',
#  'ATP phosphatase (ATPase)': 'T04389',
#  'Vasopressin receptor (VR)': 'T04394',
#  'Presynaptic density protein 95 (DLG4)': 'T04507',
#  'Neuronal acetylcholine receptor alpha-1 (CHRNA1)': 'T04689',
#  'Phosphoribosylaminoimidazolecarboxamide formyltransferase (ATIC)': 'T04741',
#  'Stromal cell-derived factor 1 (CXCL12)': 'T04773',
#  'Plasmodium CDK Pfmrk (Malaria Pfmrk)': 'T04820',
#  'Liver and activation-regulated chemokine (CCL20)': 'T04894',
#  'Calpain-2 (CAPN2)': 'T04902',
#  'Hepatitis C virus Non-structural 4B (HCV NS4B)': 'T04911',
#  'Oxalate absorption (Oxalate absor)': 'T04977',
#  'PI3-kinase beta (PIK3CB)': 'T05031',
#  'Fatty acid-binding protein (FABP)': 'T05034',
#  'Calcium-dependent chloride channel anoctamin (ANO)': 'T05089',
#  'Histone deacetylase 3 (HDAC3)': 'T05090',
#  'Chymase (CYM)': 'T05114',
#  'Hepatitis C virus RNA-directed RNA polymerase (HCV NS5B)': 'T05152',
#  'Uric acid (URA)': 'T05196',
#  'Myristoylated alanine-rich C-kinase substrate (MARCKS)': 'T05351',
#  'Tissue transglutaminase (TG2)': 'T05387',
#  'Neutral endopeptidase (MME)': 'T05409',
#  'Leucine-rich repeat neuronal protein 1 (LINGO1)': 'T05643',
#  'Lecithin-cholesterol acyltransferase (LCAT)': 'T05661',
#  'Gastrin/cholecystokinin type B receptor (CCKBR)': 'T05849',
#  'Ebola virus Envelope glycoprotein (EV GP)': 'T05876',
#  'Gamma-secretase subunit APH-1A/1B (APH-1)': 'T05880',
#  'Phosphodiesterase 8 (PDE8)': 'T05904',
#  'Ovarian carcinoma antigen CA125 (MUC16)': 'T05938',
#  'Transforming growth factor beta (TGFB)': 'T06011',
#  'Neonatal Fc receptor (FCGRT)': 'T06020',
#  'JNK2 messenger RNA (JNK2 mRNA)': 'T06037',
#  'Sinus node I(f) channel (SA node IfC)': 'T06042',
#  'Nitric-oxide synthase endothelial (NOS3)': 'T06046',
#  'Rho-associated protein kinase 2 (ROCK2)': 'T06093',
#  'Insulin receptor substrate 2 (IRS2)': 'T06128',
#  'Helodermin-preferring VIP receptor (VIPR2)': 'T06182',
#  'Poly [ADP-ribose] polymerase 1 (PARP1)': 'T06273',
#  'Klebsiella Fimbrial subunit type 3 (Klebsiella mrkA)': 'T06281',
#  'Galectin (LGALS)': 'T06320',
#  'Alanine glyoxylate aminotransferase (AGXT)': 'T06365',
#  'PKC-alpha messenger RNA (PRKCA mRNA)': 'T06413',
#  'Interferon alpha/beta receptor 2 (IFNAR2)': 'T06421',
#  'Oxidoreductase unspecific (OR)': 'T06438',
#  'Leukotriene biosynthesis (LT synth)': 'T06446',
#  'Cytochrome P450 2A6 (CYP2A6)': 'T06455',
#  'Nucleolin (NCL)': 'T06475',
#  'Cytokine ML-1 (IL17F)': 'T06542',
#  'Carbonic anhydrase VI (CA-VI)': 'T06569',
#  'Choriogonadotropin beta (CG-beta)': 'T06575',
#  'Interleukin-18 (IL18)': 'T06671',
#  'Human immunodeficiency virus Glycoprotein 41 (HIV gp41)': 'T06770',
#  'Interleukin-23 (IL23)': 'T06841',
#  'Ghrelin (GHRL)': 'T06850',
#  'Platelet-derived growth factor A (PDGFA)': 'T06869',
#  'C-C chemokine receptor type 4 (CCR4)': 'T06955',
#  'DNA polymerase beta (POLB)': 'T06958',
#  'Cytomegalovirus IE2 region messenger RNA (CMV IE2 mRNA)': 'T07035',
#  'Pituitary adenylate cyclase-activating 38 (PACAP-38)': 'T07045',
#  'Sodium/iodide cotransporter (SLC5A5)': 'T07063',
#  'Hydroxyphenylpyruvate dioxygenase (HPD)': 'T07137',
#  'Tropomyosin-related kinase A (TrkA)': 'T07173',
#  'MEK kinase kinase 2 (MAP4K2)': 'T07191',
#  'Calgranulin D (S100A12)': 'T07247',
#  'Serine/threonine-protein kinase pim-2 (PIM2)': 'T07279',
#  'Duffy antigen chemokine receptor (ACKR1)': 'T07289',
#  'Vascular endothelial growth factor receptor 3 (FLT-4)': 'T07303',
#  'Dabigatran (Dabi)': 'T07341',
#  'Beta-microseminoprotein (MSMB)': 'T07374',
#  'Notch-1 receptor (NOTCH1)': 'T07394',
#  'Advanced glycosylation end product receptor (AGER)': 'T07400',
#  'Integrin alpha-4/beta-7 (ITGA4/B7)': 'T07403',
#  'Mannan-binding lectin serine protease-2 (MASP2)': 'T07448',
#  'Respiratory syncytial virus protein F (RSV F)': 'T07485',
#  'Myosin-7 (MYH7)': 'T07507',
#  'Apolipoprotein B-100 (APOB)': 'T07533',
#  'Electron transport complex III (Complex III)': 'T07569',
#  'Ubiquitin carboxyl-terminal hydrolase 13 (USP13)': 'T07584',
#  'Calcium signal-modulating cyclophilin ligand (CAML)': 'T07601',
#  'Phosphodiesterase 5A (PDE5A)': 'T07663',
#  '5-HT 1B receptor (HTR1B)': 'T07806',
#  'Leishmania major Proteasome (Leishm Proteasome)': 'T07816',
#  'IL-1 synthesis/release (IL-1 synth/rele)': 'T07861',
#  'Polyamine transport (Poly trans)': 'T07893',
#  'Leukocyte immunoglobulin-like receptor B2 (LILRB2)': 'T07931',
#  'Erythropoietin (EPO)': 'T07958',
#  'TAR DNA binding protein 43 (TARDBP)': 'T08014',
#  'Complement factor P (CFP)': 'T08029',
#  'Leucine-rich repeat kinase 2 (LRRK2)': 'T08123',
#  'Transient receptor potential cation channel V6 (TRPV6)': 'T08133',
#  'Fanconi anemia group A protein (FANCA)': 'T08139',
#  'Interferon-alpha 5 (IFNA5)': 'T08156',
#  'HLA-DR antigens-associated invariant (CD74)': 'T08231',
#  'Granzyme B (GZMB)': 'T08298',
#  'B-cell-specific glycoprotein B29 (CD79B)': 'T08306',
#  'Cyclin-dependent kinase 12 (CDK12)': 'T08326',
#  'Solute carrier family 23 member 2 (SLC23A2)': 'T08378',
#  'Ketogenesis (KG)': 'T08383',
#  'Janus kinase 2 (JAK-2)': 'T08391',
#  'Viral Maturation (VM)': 'T08441',
#  'Caterpiller protein 1.1 (NLRP3)': 'T08499',
#  'Thrombomodulin (THBD)': 'T08583',
#  'Aspergillus Mannitol 2-dehydrogenase (Asperg M2DH)': 'T08735',
#  'Aminopeptidase (AMP)': 'T08743',
#  'Matrix metalloproteinase-8 (MMP-8)': 'T08856',
#  'Plasmodium Thrombospondin relate anonymous protein (Plasm TRAP)': 'T08884',
#  'Melanocortin receptor 2 (MC2R)': 'T08898',
#  'GABA(A) receptor gamma-2 (GABRG2)': 'T08910',
#  'Acetyl-CoA carboxylase 2 (ACACB)': 'T08922',
#  'Corynebacterium Mutated CRM197 (Cory mTOX)': 'T09005',
#  'Ebola virus VP35 messenger RNA (EV VP35 mRNA)': 'T09037',
#  'Oncotrophoblast glycoprotein 5T4 (TPBG)': 'T09058',
#  'Interleukin-10 (IL10)': 'T09092',
#  'Muscarinic acetylcholine receptor (CHRM)': 'T09130',
#  'Protein tyrosine phosphatase (PTP)': 'T09227',
#  'Neurotransmitter release (NT rele)': 'T09347',
#  'Inward rectifier potassium channel Kir1.2 (KCNJ10)': 'T09423',
#  'EGR1 messenger RNA (EGR1 mRNA)': 'T09483',
#  'APOB messenger RNA (APOB mRNA)': 'T09507',
#  'C-X-C chemokine receptor type 5 (CXCR5)': 'T09528',
#  'Alkaline phosphatase tissue-nonspecific (ALPL)': 'T09538',
#  'Melanin-concentrating hormone receptor 1 (MCHR1)': 'T09572',
#  'Polyamine unspecific (PLA)': 'T09756',
#  'DNA topoisomerase I (TOP1)': 'T09826',
#  'Angiotensin II receptor type-2 (AGTR2)': 'T09909',
#  'Receptor unspecific (Rec)': 'T09937',
#  'C-C chemokine receptor type 5 (CCR5)': 'T09960',
#  'G1/S-specific cyclin-E1 (CCNE1)': 'T10052',
#  'Rhodopsin (RHO)': 'T10091',
#  'Follicle stimulating hormone (FSHB)': 'T10092',
#  'Protein-tyrosine phosphatase sigma (R-PTP-sigma)': 'T10147',
#  'T-cell surface glycoprotein CD4 (CD4)': 'T10191',
#  'Histamine/peptide leukotriene release (His/p-LT rele)': 'T10249',
#  'Phosphodiesterase 4B (PDE4B)': 'T10265',
#  'Lipoxygenase (ALOX)': 'T10339',
#  'Enzyme unspecific (Enz)': 'T10362',
#  'Phospholipase D2 (PLD2)': 'T10383',
#  'Lipase unspecific (LIP)': 'T10445',
#  'Factor XII messenger RNA (FA12 mRNA)': 'T10482',
#  'C-X-C chemokine receptor type 7 (ACKR3)': 'T10491',
#  'Integrin beta-2 (ITGB2)': 'T10513',
#  'DNM2 messenger RNA (DNM2 mRNA)': 'T10592',
#  'Neuropeptide Y receptor type 2 (NPY2R)': 'T10670',
#  'Histidine decarboxylase (HDC)': 'T10735',
#  'Bone morphogenetic protein 6 (BMP6)': 'T10762',
#  "MERS-CoV spike glycoprotein S2' HR1 region (S S2'HR1)": 'T10783',
#  'Cyclin-dependent kinase 8 (CDK8)': 'T10822',
#  'Alpha-fetoprotein (AFP)': 'T10828',
#  'Cyclic ADP-ribose hydrolase 1 (CD38)': 'T10877',
#  'Acyl-CoA desaturase (SCD)': 'T10897',
#  'Mdm2 messenger RNA (MDM2 mRNA)': 'T10937',
#  'P-selectin (SELP)': 'T10965',
#  'IL-1 receptor-like 2 (IL1RL2)': 'T10988',
#  'Interferon-omega (IFNW1)': 'T11005',
#  'Corticotropin-releasing factor receptor 2 (CRHR2)': 'T11011',
#  'Lyase unspecific (LYA)': 'T11069',
#  '5-HT 1D receptor (HTR1D)': 'T11072',
#  'Secretory phospholipase A2 (sPLA2)': 'T11164',
#  'Androgen receptor (AR)': 'T11211',
#  'Sphingosine-1-phosphate receptor 3 (S1PR3)': 'T11241',
#  'HSPB1 messenger RNA (HSPB1 mRNA)': 'T11253',
#  'Mitochondrial matrix protein P1 (HSPD1)': 'T11283',
#  'Multidrug resistance-associated protein 1 (ABCC1)': 'T11288',
#  'Monocyte chemotactic and activating factor (CCL2)': 'T11309',
#  'Cathepsin K (CTSK)': 'T11388',
#  'Adrenergic receptor alpha-2A (ADRA2A)': 'T11448',
#  'Toll-like receptor 9 (TLR9)': 'T11451',
#  'Acetoacetyl-CoA thiolase (ACAT1)': 'T11487',
#  'SARS-CoV spike glycoprotein (S)': 'T11562',
#  'SARS-CoV envelope small membrane protein (E)': 'T11566',
#  "SARS-CoV spike glycoprotein S2' HR1 region (S S2'HR1)": 'T11610',
#  'Cystine/glutamate transporter (SLC7A11)': 'T11615',
#  'Interleukin-31 (IL31)': 'T11701',
#  'Fatty acid amide hydrolase (FAAH)': 'T11754',
#  'Retinoic acid receptor (RAR)': 'T11822',
#  'Vitamin K epoxide reductase complex 1 (VKORC1)': 'T11843',
#  'Calcium-activated potassium channel KCa2.1 (KCNN1)': 'T11911',
#  'Coagulation factor XIII (F13B)': 'T11947',
#  'Alpha-mannosidase (MANA)': 'T12059',
#  'Activin receptor-like kinase 2 (ALK-2)': 'T12091',
#  'Melanoma-associated antigen 4 (MAGEA4)': 'T12097',
#  'Cryptochrome circadian clock 1 (CRY1)': 'T12108',
#  'Voltage-gated sodium channel alpha Nav1.7 (SCN9A)': 'T12119',
#  'Mycobacterium D-alanine-D-alanine ligase A (MycB ddl)': 'T12187',
#  'Telomerase messenger RNA (Telomerase mRNA)': 'T12189',
#  'Human papillomavirus E2 transactivator messenger RNA (HPV E2 mRNA)': 'T12279',
#  'G1/S-specific cyclin-D1 (CCND1)': 'T12355',
#  'Sodium pump (NaP)': 'T12427',
#  'Gonadotropin-releasing hormone receptor (GNRHR)': 'T12475',
#  'LCK tyrosine protein kinase (LCK)': 'T12499',
#  'Valosin-containing protein p97 (VCP)': 'T12646',
#  'Cytomegalovirus Replication (CMV replication)': 'T12719',
#  'Protein kinase C alpha (PRKCA)': 'T12808',
#  'E3 ubiquitin-protein ligase COP1 (RFWD2)': 'T12819',
#  'Dystrophin (DMD)': 'T12909',
#  'Troponin C (TN-C)': 'T12966',
#  'Syndecan-1 (SDC1)': 'T13017',
#  'Protein-tyrosine phosphatase SHP-2 (PTPN11)': 'T13057',
#  'Casein kinase I alpha (CSNK1A1)': 'T13075',
#  'Farnesyl protein transferase (Ftase)': 'T13127',
#  'Carbonic anhydrase I (CA-I)': 'T13201',
#  'Activin receptor type II (ACVR2)': 'T13209',
#  'Interleukin-12 alpha (IL12A)': 'T13251',
#  'Succinate-semialdehyde dehydrogenase (ALDH5A1)': 'T13259',
#  'Aromatase (CYP19A1)': 'T13260',
#  'AP endonuclease 1 (APEX1)': 'T13348',
#  'Human immunodeficiency virus Matrix p17 (HIV MA)': 'T13409',
#  'Solute carrier family 29 member 1 (SLC29A1)': 'T13491',
#  'Methamphetamine (Meth)': 'T13568',
#  'Integrin-linked protein kinase 1 (ILK)': 'T13616',
#  'PD-1-PD-L1 interaction (PD-1/PD-L1 PPI)': 'T13629',
#  'Somatostatin receptor type 3 (SSTR3)': 'T13644',
#  'Cholesterol synthesis (Chole synth)': 'T13712',
#  'Oxysterols receptor LXR-beta (NR1H2)': 'T13714',
#  'Retinoic acid receptor RXR-alpha (RXRA)': 'T13726',
#  'Opioid receptor zeta (OGFR)': 'T13741',
#  'Sphingosine-1-phosphate receptor 1 (S1PR1)': 'T13852',
#  'Phosphofructokinase 2 (PFK2)': 'T13910',
#  'RAC serine/threonine-protein kinase (AKT)': 'T14037',
#  'Netrin (NET)': 'T14056',
#  'Integrin beta-7 (ITGB7)': 'T14065',
#  'Beta-klotho (KLB)': 'T14110',
#  'Transforming growth factor beta 2 (TGFB2)': 'T14143',
#  'Leucine-rich repeat-containing GPCR 5 (LGR5)': 'T14231',
#  'Human immunodeficiency virus Reverse transcriptase (HIV RT)': 'T14342',
#  'Sterol O-acyltransferase (SOAT)': 'T14463',
#  'Clostridium difficile Toxin B (CD toxB)': 'T14541',
#  'Interleukin 10 receptor (IL10RB)': 'T14557',
#  'Tryptase alpha/beta-1 (Tryptase)': 'T14558',
#  'Mycobacterium Biosynthetic alanine racemase (MycB alr)': 'T14582',
#  'Apoptosis mediating surface antigen FAS (FAS)': 'T14592',
#  'Erbb2 tyrosine kinase receptor (HER2)': 'T14597',
#  'Coagulation factor VIII (F8)': 'T14602',
#  'A proliferation-inducing ligand (APRIL)': 'T14676',
#  'Bacterial Beta-glucuronidase (Bact uidA)': 'T14705',
#  'NAD-dependent deacetylase sirtuin-1 (SIRT1)': 'T14731',
#  'TNF related activation protein (CD40LG)': 'T14755',
#  'VEGFR2 messenger RNA (VEGFR2 mRNA)': 'T14825',
#  'Cytosolic phospholipase A2 (GIVA cPLA2)': 'T14834',
#  'Fibroblast growth factor-23 (FGF23)': 'T14853',
#  'Ubiquitin carboxyl-terminal hydrolase 14 (USP14)': 'T14875',
#  'Ceramide glucosyltransferase (UGCG)': 'T14908',
#  'Induced myeloid leukemia cell differentiation protein Mcl-1 (MCL1)': 'T14912',
#  'Centromeric protein E (CENPE)': 'T14945',
#  'Cytotoxic T-lymphocyte protein 4 (CTLA-4)': 'T15000',
#  'Neuropilin-1 (NRP1)': 'T15023',
#  'Focal adhesion kinase 1 (FAK)': 'T15068',
#  'Human immunodeficiency virus Nucleocapsid p7 (HIV p7)': 'T15107',
#  'Adrenergic receptor (ADR)': 'T15117',
#  'Collagen I (COL1A2)': 'T15167',
#  'Potential penetration (PP)': 'T15197',
#  'Cholesteryl ester transfer protein (CETP)': 'T15334',
#  'Activation-inducible TNFR family receptor (TNFRSF18)': 'T15344',
#  'Sarcoplasmic/endoplasmic reticulum calcium ATPase 2 (ATP2A2)': 'T15377',
#  'C5a anaphylatoxin chemotactic receptor (C5AR1)': 'T15439',
#  'GHR messenger RNA (GHR mRNA)': 'T15494',
#  'Prostaglandin E2 receptor EP1 (PTGER1)': 'T15497',
#  'Insulin receptor substrate-1 (IRS1)': 'T15510',
#  'Endothelial plasminogen activator inhibitor (SERPINE1)': 'T15556',
#  'Methylmalonyl-CoA mutase (MMUT)': 'T15569',
#  '5-HT 5A receptor (HTR5A)': 'T15571',
#  'Puromycin-sensitive aminopeptidase (NPEPPS)': 'T15610',
#  'Zinc finger protein (ZNF)': 'T15639',
#  'Caspase-8 (CASP8)': 'T15700',
#  'Cellular tumor antigen p53 (TP53)': 'T15739',
#  'Pyruvate dehydrogenase kinase 1 (PDHK1)': 'T15776',
#  'NKG2-A/B-activating NK receptor (NKG2A)': 'T15783',
#  'Lipid peroxidation (LPO)': 'T15784',
#  'TWIK-related acid-sensitive potassium channel 1 (TASK1)': 'T15795',
#  'SET and MYND domain-containing protein 2 (SMYD2)': 'T15797',
#  'Factor XI messenger RNA (F11 mRNA)': 'T15803',
#  'Dipeptidyl peptidase 8 (DPP-8)': 'T15855',
#  'Gastric carcinoma-associated antigen MG7 (MG7)': 'T15867',
#  'Leukocyte proteinase-3 (PRTN3)': 'T15882',
#  'Cerebron E3 ubiquitin ligase complex (CRL4-CRBN E3 ubiquitin ligase)': 'T15894',
#  'C-C chemokine receptor type 1 (CCR1)': 'T16016',
#  'Onchocerca Glutamate-gated chloride channel (Onchoc GluCl)': 'T16047',
#  'TMPRSS6 messenger RNA (TMPRSS6 mRNA)': 'T16087',
#  'Nitric-oxide synthase brain (NOS1)': 'T16117',
#  'Gastrin (GAST)': 'T16128',
#  'B7-related protein 1 (B7RP1)': 'T16144',
#  'Thrombopoietin receptor (MPL)': 'T16156',
#  'T-cell-specific protein RANTES (CCL5)': 'T16263',
#  'Rotamase Pin1 (PIN1)': 'T16308',
#  'Interleukin-1 alpha (IL1A)': 'T16340',
#  'Protein-tyrosine phosphatase 1B (PTP1B)': 'T16347',
#  'Gap junction alpha-8 protein (Cx50)': 'T16353',
#  'Multidrug resistance protein (MDR)': 'T16422',
#  'TNFA messenger RNA (TNF mRNA)': 'T16486',
#  'Fatty acid synthase (FASN)': 'T16514',
#  'Carcinoembryonic antigen CEA (CD66e)': 'T16601',
#  'Marburg virus NP messenger RNA (MV NP mRNA)': 'T16605',
#  'Somatostatin receptor type 1 (SSTR1)': 'T16633',
#  'Diacylglycerol acyltransferase 1 (DGAT1)': 'T16688',
#  '5-HT 6 receptor (HTR6)': 'T16691',
#  'Vacuolar-type proton ATPase catalytic A (v-ATPase-A)': 'T16731',
#  'Protein delta homolog 1 (DLK1)': 'T16738',
#  'Lysine-specific histone demethylase 1 (LSD)': 'T16739',
#  'Pneumocystis carinii Dihydropteroate synthase (PC DHPS)': 'T16761',
#  'X-linked inhibitor of apoptosis protein (XIAP)': 'T16769',
#  'Microtubule polymerization (MicroTu poly)': 'T16784',
#  'Iodothyronine deiodinase type I (DIO1)': 'T16792',
#  'Human immunodeficiency virus Attachment (HIV att)': 'T16802',
#  'Protein arginine methyltransferase 1 (PRMT1)': 'T16808',
#  'Neural cadherin (CDH2)': 'T16868',
#  'Small-inducible cytokine A11 (CCL11)': 'T16888',
#  'Carbonic anhydrase XII (CA-XII)': 'T16987',
#  'DNA-directed RNA polymerase (RNAP)': 'T17003',
#  'DNA topoisomerase II alpha (TOP2A)': 'T17048',
#  'Isopeptidase T (USP5)': 'T17067',
#  'P2X purinoceptor 3 (P2RX3)': 'T17140',
#  'Leptin receptor (LEPR)': 'T17163',
#  'Cytomegalovirus Ganciclovir kinase (CMV UL97)': 'T17234',
#  'Measles virus Fusion glycoprotein (MeV F)': 'T17248',
#  'Dihydrofolate reductase (DHFR)': 'T17345',
#  'Sequestosome-1 p62 (SQSTM1)': 'T17367',
#  'Platelet glycoprotein Ib alpha (CD42b)': 'T17427',
#  'Histamine N-methyltransferase (HNMT)': 'T17448',
#  'Menin-MLL1 interaction (MEN1-KMT2A PPI)': 'T17485',
#  'Retinal pigment epithelium protein (RPE65)': 'T17502',
#  'Activin (ACT)': 'T17514',
#  'Voltage-gated potassium channel Kv1.5 (KCNA5)': 'T17569',
#  'Tumor associated calcium signal transducer 2 (TACSTD2)': 'T17629',
#  'Fibroblast growth factor receptor (FGFR)': 'T17687',
#  'Haptoglobin (HP)': 'T17710',
#  'Urokinase-type plasminogen activator (PLAU)': 'T17758',
#  'Phosphodiesterase 9 (PDE9)': 'T17852',
#  'Pyruvate dehydrogenase kinase 2 (PDHK2)': 'T17967',
#  'Fyn tyrosine protein kinase (FYN)': 'T17980',
#  'Enhancer of zeste homolog 1 (EZH1)': 'T17986',
#  'Complement receptor type 2 (CD21)': 'T18059',
#  'MERS-CoV papain-like proteinase (PL-PRO)': 'T18143',
#  'HUMAN clathrin-mediated endocytosis (RME)': 'T18226',
#  'CaM-kinase II (CAMK2)': 'T18299',
#  'Lassa virus Pre-glycoprotein polyprotein GP complex (LASV GPC)': 'T18356',
#  'Heat shock protein 90 alpha (HSP90A)': 'T18477',
#  'CD80-PD-L1 interaction (CD80/PD-L1 PPI)': 'T18551',
#  'Cholinergic receptor unspecific (CHR)': 'T18632',
#  'Heparin-binding growth factor 1 (FGF1)': 'T18639',
#  'Monoglyceride lipase (MAGL)': 'T18664',
#  'Mucin-1 (MUC1)': 'T18779',
#  'Metastasis-suppressor KiSS-1 (KISS1)': 'T18872',
#  'Prostaglandin E2 receptor EP4 (PTGER4)': 'T18876',
#  'Leutinizing-hormone-releasing hormone (GNRH1)': 'T18950',
#  'T-cell surface glycoprotein CD3 gamma (CD3G)': 'T18972',
#  'M-phase inducer phosphatase 3 (MPIP3)': 'T19011',
#  'Group IIA phospholipase A2 (GIIA sPLA2)': 'T19160',
#  'Proton-coupled folate transporter (SLC46A1)': 'T19229',
#  'S-mephenytoin 4-hydroxylase (CYP2C9)': 'T19244',
#  'Interleukin 21 receptor (IL21R)': 'T19334',
#  'Endothelial lipase (LIPG)': 'T19368',
#  'Fibrin (FG)': 'T19414',
#  'Glutathione-dependent PGD synthase (HPGDS)': 'T19433',
#  'Oncostatin-M (OSM)': 'T19556',
#  'Beta-N-acetylhexosaminidase (OGA)': 'T19567',
#  'Interleukin 2 receptor beta (IL2RB)': 'T19579',
#  'Granulocyte colony-stimulating factor (CSF3)': 'T19615',
#  'Soluble guanylyl cyclase (GUCY2D)': 'T19693',
#  'Mixed lineage kinase 1 (MAP3K9)': 'T19760',
#  'Somatotropin (GH1)': 'T19784',
#  'Keratinocyte growth factor (FGF7)': 'T19852',
#  'CREB-regulated transcription coactivator 1 (TORC1)': 'T20017',
#  'TGF-beta receptor (TGFBR)': 'T20059',
#  'Plasmodium Deoxyribonucleic acid (Malaria DNA)': 'T20089',
#  'Vacuolar-type proton ATPase (v-ATPase)': 'T20103',
#  'Tumor necrosis factor (TNF)': 'T20178',
#  'Fucosyl GM1 (FucGM1)': 'T20185',
#  'Feto-acinar pancreatic protein (FAPP)': 'T20210',
#  'Voltage-gated potassium channel Kv11.1 (KCNH2)': 'T20251',
#  'Major histocompatibility complex (MHC)': 'T20278',
#  'Serine protease unspecific (SP)': 'T20297',
#  'Neuropeptide Y receptor type 5 (NPY5R)': 'T20331',
#  'Macrophage colony-stimulating factor 1 receptor (CSF1R)': 'T20333',
#  'Carbonic anhydrase II (CA-II)': 'T20401',
#  'DNA topoisomerase (TOP)': 'T20474',
#  'Delta-aminolevulinic acid dehydratase (ALAD)': 'T20514',
#  'Pseudomonas Transcriptional activator protein LasR (Pseudo LasR)': 'T20534',
#  'EGFR Exon20ins mutant (EGFR Exon20ins)': 'T20563',
#  'C-C chemokine receptor type 8 (CCR8)': 'T20575',
#  'Phosphodiesterase 7B (PDE7B)': 'T20578',
#  'Tumor-associated glycan antigen (TAGA)': 'T20593',
#  'Muscarinic acetylcholine receptor M4 (CHRM4)': 'T20709',
#  'Interleukin 2 receptor (IL2R)': 'T20710',
#  'Solute carrier family 6 member 8 (SLC6A8)': 'T20741',
#  'Vascular endothelial growth factor A (VEGFA)': 'T20761',
#  'Reactive oxygen species (ROS)': 'T20796',
#  'Isocitrate dehydrogenase (IDH)': 'T20808',
#  'Phosphoinositide dependent protein kinase-1 (PDPK1)': 'T20891',
#  'Cyclin-dependent kinase 5 (CDK5)': 'T20973',
#  'T-cell surface glycoprotein CD8 (CD8)': 'T20978',
#  'DNA replication (DNA repli)': 'T21112',
#  'Hypoxia-inducible factor 2 alpha (HIF-2A)': 'T21123',
#  'Plasmodium Apical membrane protein (Malaria AMA-1)': 'T21291',
#  'MAPK-activated protein kinase 2 (MAPKAPK2)': 'T21307',
#  'Immune checkpoint (ICH)': 'T21312',
#  'Isomerase unspecific (IsoM)': 'T21324',
#  'Osteoclast differentiation factor (ODF)': 'T21334',
#  'Nuclear receptor unspecific (NR)': 'T21351',
#  'Membrane cofactor protein (CD46)': 'T21395',
#  'Neuronal acetylcholine receptor alpha-10 (CHRNA10)': 'T21434',
#  'Glutamine receptor (GluR)': 'T21447',
#  'Signal transduction unspecific (ST)': 'T21617',
#  'Glutathione S-transferase P (GSTP1)': 'T21669',
#  'Alpha-galactosidase A (GLA)': 'T21678',
#  'Huntingtin messenger RNA (HTT mRNA)': 'T21679',
#  'Apolipoprotein E (APOE)': 'T21689',
#  'Transforming protein Rho (RHO)': 'T21701',
#  'Proliferating cell nuclear antigen (PCNA)': 'T21782',
#  'P-selectin glycoprotein ligand 1 (SELPLG)': 'T21865',
#  'Carcinoembryonic antigen CGM1 (CD66d)': 'T21890',
#  'Norepinephrine transporter (NET)': 'T21945',
#  'Angiopoietin-2 (ANGPT2)': 'T21960',
#  'Parathyroid hormone receptor (PTH2R)': 'T22032',
#  'Interleukin-17 (IL17)': 'T22095',
#  'Dopamine D1 receptor (D1R)': 'T22118',
#  'Glutamate decarboxylase 2 (GAD2)': 'T22128',
#  'Immunoglobulin gamma Fc receptor IIA (FCGR2A)': 'T22212',
#  'Histone deacetylase 6 (HDAC6)': 'T22274',
#  'Glutamate receptor ionotropic NMDA 2A (NMDAR2A)': 'T22285',
#  'Staphylococcus Capsular polysaccharide CP5 (Stap-coc CP5)': 'T22295',
#  'Solute carrier family 12 member 5 (SLC12A5)': 'T22302',
#  'Bacterial DNA gyrase (Bact gyrase)': 'T22348',
#  'Endoglin CD105 (ENG)': 'T22350',
#  'Pseudomonas PcrV protein type III (Pseudo pcrV)': 'T22415',
#  'Sodium/glucose cotransporter 2 (SLC5A4)': 'T22583',
#  'TNF alpha production (TNFA produ)': 'T22608',
#  'Mucosal addressin cell adhesion molecule 1 (MADCAM1)': 'T22655',
#  'Interleukin-8 (IL8)': 'T22658',
#  'Intracellular nitroreductase (INR)': 'T22778',
#  'Pancreatic elastase 1 (CELA1)': 'T22839',
#  'Progesterone receptor (PGR)': 'T22939',
#  'Cyclin-dependent kinase 3 (CDK3)': 'T22956',
#  'Thymidine kinase 2 (Mt-TK2)': 'T22976',
#  'Superoxide dismutase Cu-Zn (SOD Cu-Zn)': 'T22977',
#  'Transforming growth factor beta 3 (TGFB3)': 'T22978',
#  'Hepcidin (HAMP)': 'T22995',
#  'MAPK/ERK kinase kinase (MAP3K)': 'T23003',
#  'Staphylococcus Enoyl ACP reductase (Stap-coc fabI)': 'T23036',
#  'Pseudomonas LPS-assembly protein LptD (Pseudo lptD)': 'T23050',
#  'Cholesterol desmolase (CYP11A1)': 'T23145',
#  'Janus kinase 3 (JAK-3)': 'T23172',
#  'Integrin beta-6 (ITGB6)': 'T23178',
#  'Monocyte differentiation antigen CD14 (CD14)': 'T23212',
#  'Extracellular signal-regulated kinase 1 (ERK1)': 'T23276',
#  'N-acetylgalactosamine 6 sulfatase (GALNS)': 'T23292',
#  'Human immunodeficiency virus Capsid p24 (HIV p24)': 'T23343',
#  'Interleukin 1 receptor type 2 (IL1R2)': 'T23347',
#  'von Willebrand factor (VWF)': 'T23348',
#  'ITGB3 messenger RNA (ITGB3 mRNA)': 'T23355',
#  'Transthyretin messenger RNA (TTR mRNA)': 'T23389',
#  'Epstein-Barr virus Envelope glycoprotein gp340 (EBV BLLF1)': 'T23459',
#  'Myeloperoxidase (MPO)': 'T23471',
#  'Endothelin A receptor (EDNRA)': 'T23499',
#  'G-protein coupled receptor C 5D (GPRC5D)': 'T23519',
#  'Opioid receptor (OPR)': 'T23547',
#  'Aryl hydrocarbon receptor (AHR)': 'T23666',
#  'Proto-oncogene c-RAF (c-RAF)': 'T23673',
#  'B2 bradykinin receptor (BDKRB2)': 'T23714',
#  'Sarcoplasmic/endoplasmic reticulum calcium ATPase (ATP2A)': 'T23761',
#  'Renal carcinoma antigen NY-REN-56 (PFKFB3)': 'T23787',
#  'Interleukin-33 (IL33)': 'T23797',
#  'Prostate stem cell antigen (PSCA)': 'T23953',
#  'Protein kinase C theta (PRKCQ)': 'T23995',
#  'Peptide tyrosine tyrosine PYY (PYY)': 'T24127',
#  'C1 esterase inhibitor (SERPING1)': 'T24211',
#  'Lysosomal acid lipase (LIPA)': 'T24373',
#  'ADRB2 messenger RNA (ADRB2 mRNA)': 'T24555',
#  'O-6-methylguanine-DNA-alkyltransferase (MGMT)': 'T24587',
#  'Haemophilus influenzae Acetylglucosamine deacetylase (Hae-influ lpxC)': 'T24626',
#  'Bacterial UDP-N-acetylglucosamine carboxyvinyltransferase (Bact murA)': 'T24634',
#  'Voltage-gated calcium channel alpha Cav1.3 (CACNA1D)': 'T24793',
#  'Mycobacterial lipoarabinomannan (MycB LAM)': 'T24835',
#  'Vitamin K-dependent protein C (PROC)': 'T24836',
#  'Ileal sodium/bile acid cotransporter (SLC10A2)': 'T24982',
#  'Dopamine D4 receptor (D4R)': 'T24983',
#  'Tyrosine-protein kinase BTK (ATK)': 'T25005',
#  'Neisseria gonorrhoeae Enoyl-[acyl-carrier-protein] reductase (Neisseria fabI)': 'T25064',
#  'Endothelin-1 (EDN1)': 'T25076',
#  'Carbamoyl-phosphate synthetase I (CPS1)': 'T25163',
#  'Multidrug resistance protein 1 (ABCB1)': 'T25258',
#  'Enhancer of zeste homolog 2 (EZH2)': 'T25265',
#  'Nuclear receptor ROR-gamma (RORG)': 'T25307',
#  'C-X-C chemokine receptor type 3 (CXCR3)': 'T25315',
#  'Cholestenol delta-isomerase (EBP)': 'T25317',
#  'Tropomyosin receptor kinase (Trk)': 'T25419',
#  'Calcineurin (PPP3CA)': 'T25464',
#  'Mitogen-activated protein kinase (MAPK)': 'T25537',
#  'Free fatty acid receptor 1 (GPR40)': 'T25608',
#  'Lysyl oxidase homolog 2 (LOXL2)': 'T25637',
#  'Adenosine receptor (ADOR)': 'T25663',
#  'Pseudomonas Lipopolysaccharide (Pseudo LPS)': 'T25698',
#  'Heme oxygenase 1 (HMOX1)': 'T25703',
#  'N-formyl peptide receptor 3 (FPR3)': 'T25705',
#  'Glypican-3 (GPC3)': 'T25726',
#  'Solute carrier family 39 member 6 (SLC39A6)': 'T25739',
#  'Rotamase B (PPIB)': 'T25847',
#  'Adenylate cyclase (ADCY)': 'T25889',
#  'Bone metabolism (Bone metab)': 'T25950',
#  'Histone acetyltransferase p300 (EP300)': 'T25956',
#  'Tumor necrosis factor receptor member 25 (TNFRSF25)': 'T26170',
#  'Intercellular adhesion molecule ICAM-1 (ICAM1)': 'T26203',
#  'Somatostatin receptor (SSTR)': 'T26220',
#  'Prolactin receptor (PRLR)': 'T26226',
#  'Estramustine binding protein (EMBP)': 'T26240',
#  'Superoxide anion (SPA)': 'T26327',
#  'GABA(A) receptor alpha-5 (GABRA5)': 'T26368',
#  'Melanin-concentrating hormone receptor (MCHR)': 'T26428',
#  'DNA polymerase alpha catalytic p180 (POLA1)': 'T26463',
#  'B-cell lymphoma/leukemia 11A (BCL11A)': 'T26470',
#  'Histamine H4 receptor (H4R)': 'T26500',
#  'Aldose reductase (AKR1B1)': 'T26623',
#  'Complement C3 (CO3)': 'T26851',
#  'Transferase unspecific (TF)': 'T27021',
#  'FK506-binding protein (FKBP)': 'T27106',
#  'Metabotropic glutamate receptor 1 (mGluR1)': 'T27137',
#  'Streptococcus Methionyl-tRNA synthetase (Stre-coc metG)': 'T27198',
#  'Oxo-5-alpha-steroid 4-dehydrogenase (SRD5A)': 'T27265',
#  'Food intake (FI)': 'T27288',
#  'GABA(A) receptor delta (GABRD)': 'T27376',
#  'Bacterial Isoleucyl-tRNA synthetase (Bact ileS)': 'T27445',
#  'Variola virus Envelope phospholipase F13 (VARV p37)': 'T27495',
#  'Cationic trypsinogen (PRSS1)': 'T27602',
#  'Growth/differentiation factor 2 (GDF2)': 'T27611',
#  'Programmed cell death protein 2 (PD-2)': 'T27736',
#  'Late inward sodium current (LISC)': 'T27770',
#  'Serotonin transporter (SERT)': 'T27812',
#  'Spectrin non-erythroid beta chain 1 (SPTBN1)': 'T27826',
#  'Protein cereblon (CRBN)': 'T27861',
#  'Angiotensin-converting enzyme 2 (ACE2)': 'T27889',
#  'ATP-dependent RNA helicase DDX5 (DDX5)': 'T27918',
#  'Neuropeptide Y receptor type 4 (NPY4R)': 'T27944',
#  'Bacterial Protective antigen (Bact pagA)': 'T27999',
#  'Ribosomal protein S6 kinase alpha-2 (RSK2)': 'T28043',
#  'Fibroblast growth factor-4 (FGF4)': 'T28076',
#  'FAS-associated factor 1 (FAF1)': 'T28093',
#  'Free fatty acid receptor 2 (FFAR2)': 'T28213',
#  'MHC class I NK cell receptor 3DL2 (CD158k)': 'T28217',
#  'GTP cyclohydrolase-I (GCH1)': 'T28226',
#  'Alpha-1-antitrypsin (SERPINA1)': 'T28265',
#  'Cholecystokinin receptor type A (CCKAR)': 'T28330',
#  'Osteoblast cadherin (CDH11)': 'T28385',
#  'Ephrin type-A receptor 3 (EPHA3)': 'T28413',
#  'Lysosphingolipid receptor (LSPR)': 'T28481',
#  'Kinesin-like protein KIF11 (KIF11)': 'T28484',
#  'Ribonuclease P protein (RPP)': 'T28532',
#  'Plasmodium 80S ribosome (Malaria 80S)': 'T28658',
#  'Tubulin beta-2 chain (TUBB2)': 'T28661',
#  'Lipoprotein lipase (LPL)': 'T28692',
#  'Serine/threonine-protein kinase Chk2 (RAD53)': 'T28713',
#  'TNF superfamily receptor 12A (TNFRSF12A)': 'T28717',
#  'GABA(A) receptor gamma-3 (GABRG3)': 'T28722',
#  'Protein kinase unspecific (PK)': 'T28746',
#  'Virus Deoxyribonucleic acid (Viru DNA)': 'T28848',
#  'Bacterial Urease (Bact ureC)': 'T28869',
#  'Histone deacetylase 8 (HDAC8)': 'T28887',
#  'Muscarinic acetylcholine receptor M1 (CHRM1)': 'T28893',
#  "Inosine-5'-monophosphate dehydrogenase (IMPDH)": 'T28925',
#  'Iduronate 2-sulfatase (IDS)': 'T28993',
#  'SOD1 messenger RNA (SOD1 mRNA)': 'T29024',
#  'CCN2 messenger RNA (CCN2 mRNA)': 'T29036',
#  'Angiogenesis/myeloma cell growth (AMCG)': 'T29064',
#  'TNF-alpha signaling pathway (TNFA pathway)': 'T29075',
#  'Signal transducer and activator of transcription 3 (STAT3)': 'T29130',
#  'Interleukin-13 (IL13)': 'T29143',
#  'Arginase (ARG)': 'T29144',
#  'Sodium channel unspecific (NaC)': 'T29303',
#  'Retinoic acid-inducible gene-1 (RIG-1)': 'T29339',
#  'Mucin-17 (MUC17)': 'T29345',
#  'Adrenergic receptor alpha-1B (ADRA1B)': 'T29500',
#  'Human immunodeficiency virus Deoxyribonucleic acid (HIV DNA)': 'T29525',
#  'Leukotriene receptor (LTR)': 'T29649',
#  'Neuromedin-K receptor (TACR3)': 'T29683',
#  'Laminin beta-3 chain (LAMB3)': 'T29736',
#  'NADPH oxidase 4 (NOX4)': 'T29741',
#  'MAPK-activated protein kinase 5 (MAPKAPK5)': 'T29754',
#  'Leukemia inhibitory factor (LIF)': 'T29774',
#  'Neoplasm antigen (NA)': 'T29815',
#  'Integrin alpha-5 (ITGA5)': 'T29879',
#  'Wilms tumor protein (WT1)': 'T29960',
#  'Vasopressin V1 receptor (V1R)': 'T29999',
#  'Immunoglobulin unspecific (Ig)': 'T30014',
#  'Vesicle-associated membrane protein (VAMP)': 'T30028',
#  'Vascular endothelial growth factor B (VEGFB)': 'T30040',
#  'Thymidine kinase 1 (TK1)': 'T30081',
#  'Acetylcholinesterase (AChE)': 'T30082',
#  'Sodium/glucose cotransporter 2 (SGLT2)': 'T30085',
#  'Growth hormone secretion (GH secr)': 'T30208',
#  'Interferon gamma receptor (IFNGR2)': 'T30284',
#  'Blood group Rh(D) polypeptide (RHD)': 'T30356',
#  'Trypanosoma Cruzipain (Trypano CYSP)': 'T30372',
#  'Gamma-aminobutyric acid uptake (GABAU)': 'T30374',
#  'Endogenous gut peptide (EGP)': 'T30383',
#  'DNA synthesis (DNA synth)': 'T30418',
#  'SET domain containing 8 (KMT5A)': 'T30420',
#  'Bacterial RNA polymerase switch region (Bact RNAP-SR)': 'T30520',
#  'Leukotriene B4 receptor 2 (LTB4R2)': 'T30563',
#  'Mycobacterium Arabinosyltransferase C (MycB embC)': 'T30578',
#  'C-X-C motif chemokine 10 (CXCL10)': 'T30635',
#  'Acetyl-CoA:lyso-PAF acetyltransferase (PCAT)': 'T30653',
#  'Glucocorticoid receptor messenger RNA (GCR mRNA)': 'T30687',
#  'Kininogen (KNG1)': 'T30731',
#  'Thrombospondin-1 (THBS1)': 'T30784',
#  'Calcium-release activated calcium channel (CRACM)': 'T30790',
#  'Neuron-specific vesicular protein calcyon (CALY)': 'T30802',
#  'Glutathione reductase (GR)': 'T30803',
#  'Serine palmitoyltransferase (SPTC)': 'T30817',
#  'M-phase inducer phosphatase 1 (MPIP1)': 'T30823',
#  'Platelet factor 4 (PF4)': 'T30827',
#  'Amylin receptor (IAPPR)': 'T30834',
#  'Leukocyte immunoglobulin-like receptor B4 (LILRB4)': 'T30846',
#  'GRB2 messenger RNA (GRB2 mRNA)': 'T30926',
#  'Mycobacterium RNA polymerase (MycB RNAP)': 'T30938',
#  'Mitochondrial 10kDa heat shock protein (HSPE1)': 'T30940',
#  'Bacillus anthracis Protective antigen (Anthrax PA)': 'T30956',
#  'Histamine H2 receptor (H2R)': 'T30985',
#  'Interleukine 12 (IL-12)': 'T31072',
#  'Potassium (K)': 'T31133',
#  '5-HT 2B receptor (HTR2B)': 'T31204',
#  'Bacterial Fumarate reductase flavoprotein (Bact frdA)': 'T31230',
#  'HLA-A02/AFP complex (HLA-A02/AFP)': 'T31299',
#  'Apoptosis regulator Bcl-2 (BCL-2)': 'T31309',
#  'Leishmania DNA topoisomerase I (Leishm TOP1)': 'T31329',
#  'Dipeptidyl peptidase 4 (DPP-4)': 'T31391',
#  'Hematopoietic cell kinase (HCK)': 'T31406',
#  'Adrenergic receptor Alpha-2 (ADRA2)': 'T31424',
#  'Pyruvate kinase (PK)': 'T31458',
#  'Phospholipase A2 (PLA2G1B)': 'T31479',
#  'Lysosomal alpha-glucosidase (GAA)': 'T31514',
#  'Influenza Neuraminidase (Influ NA)': 'T31595',
#  'Protein kinase N3 (PKN3)': 'T31600',
#  'Fibroblast growth factor-2 (FGF2)': 'T31621',
#  'Plasmodium DOXP reductoisomerase (Malaria DXR)': 'T31751',
#  'Integrin alpha-1 (VLA-1)': 'T31818',
#  'Hemoglobin subunit beta (HBB)': 'T31825',
#  'Mammalian disintegrin-metalloprotease (ADAM10)': 'T31902',
#  'Vascular endothelial growth factor receptor (VEGFR)': 'T31946',
#  'Glutamyl aminopeptidase (ENPEP)': 'T31956',
#  'Sphingosine kinase 2 (SPHK2)': 'T31989',
#  'Carbonic anhydrase XIV (CA-XIV)': 'T31992',
#  '5-HT 2A receptor (HTR2A)': 'T32060',
#  'NADPH oxidase (NOX)': 'T32137',
#  'Cyclic nucleotide-gated channel beta-3 (CNGB3)': 'T32227',
#  'Interleukin-15 (IL15)': 'T32240',
#  'Calcitonin receptor (CALCR)': 'T32247',
#  'Calcitonin gene-related peptide receptor (CGRPR)': 'T32262',
#  'Prolactin (PRL)': 'T32282',
#  'Inhibitor of nuclear factor kappa-B kinase (IKK)': 'T32335',
#  'Early growth response protein 1 (EGR-1)': 'T32348',
#  'Influenza Polymerase acidic endonuclease (Influ PA)': 'T32369',
#  'Endothelium of blood vessels (Endothelium)': 'T32387',
#  'Second phase insulin secretion (SPI secr)': 'T32456',
#  'Bacterial Beta-ketoacyl-ACP synthase I (Bact fabB)': 'T32468',
#  'Interleukin-6 (IL6)': 'T32578',
#  'MHC class I NK cell receptor 2DS1 (CD158h)': 'T32720',
#  'Adaptor-associated kinase 1 (AAK1)': 'T32764',
#  'Asialoglycoprotein receptor 1 (ASGR1)': 'T32780',
#  'LDHA messenger RNA (LDHA mRNA)': 'T32790',
#  'Neurotrophin-3 (NTF3)': 'T32855',
#  'Fungal Cell membrane ergosterol (Fung CME)': 'T32862',
#  'HIF-prolyl hydroxylase 2 (HPH-2)': 'T32880',
#  'Solute carrier family 36 member 2 (SLC36A2)': 'T32938',
#  'Lanosterol 14-alpha demethylase (CYP51A1)': 'T32972',
#  'Legumain (LGMN)': 'T32973',
#  'Microtubule (MicroTu)': 'T32984',
#  'D-amino acid oxidase (DAO)': 'T33124',
#  'Bacterial Penicillin binding protein 3 (Bact mrcA)': 'T33193',
#  'Tuftsin receptor (TR)': 'T33275',
#  'Epidermal growth factor (EGF)': 'T33425',
#  'Insulin-like growth factor-binding protein 3 (IGFBP3)': 'T33455',
#  'Steryl-sulfatase (STS)': 'T33489',
#  'Bacterial Sporulation kinase A (Bact kinA)': 'T33491',
#  'Glutamate receptor AMPA 1 (GRIA1)': 'T33584',
#  'Prostate cance cell (PCC)': 'T33629',
#  'Epstein-Barr virus Latent membrane protein 2 (EBV LMP2)': 'T33636',
#  'Cholesterol 24-hydroxylase (CYP46A1)': 'T33641',
#  'Phosphodiesterase 3 (PDE3)': 'T33754',
#  'Mcl-1 messenger RNA (MCL-1 mRNA)': 'T33765',
#  'Interleukin 17 receptor (IL17R)': 'T33846',
#  'Niemann-Pick C1-like protein 1 (NPC1L1)': 'T33901',
#  'Hydroxy radical elimination (HYRE)': 'T33917',
#  'Transferrin receptor protein 1 (TFRC)': 'T33976',
#  'Macrophage colony-stimulating factor 1 (CSF1)': 'T33990',
#  'Voltage-gated sodium channel alpha Nav1.9 (SCN11A)': 'T34123',
#  'Cyclic nucleotide-gated channel alpha-2 (CNGA2)': 'T34204',
#  'Vitamin D3 receptor (VDR)': 'T34234',
#  'Protoporphyrinogen oxidase (PPOX)': 'T34239',
#  'Candida Mannose-6-phosphate isomerase (Candi PMI1)': 'T34287',
#  'Matrix metalloproteinase-13 (MMP-13)': 'T34296',
#  'Cathelicidin antimicrobial peptide (CAMP)': 'T34318',
#  'Neuronal acetylcholine receptor alpha-7 (CHRNA7)': 'T34429',
#  'Haemophilus influenzae DNA gyrase A (Hae-influ gyrA)': 'T34596',
#  'Stress-activated protein kinase (p38)': 'T34624',
#  'Bacterial Penicillin binding protein (Bact PBP)': 'T34743',
#  'Endopeptidase (ENP)': 'T34772',
#  'Glucagon-like peptide 2 receptor (GLP2R)': 'T34843',
#  'Poly [ADP-ribose] polymerase (PARP)': 'T34867',
#  'Voltage-gated calcium channel alpha Cav2.1 (CACNA1A)': 'T34949',
#  'Hepatitis C virus Serine protease NS4A (HCV NS4A)': 'T34997',
#  'Basigin (BSG)': 'T35040',
#  'RAS-like protein KIR (GEM)': 'T35063',
#  'Cellular inhibitor of apoptosis 2 (BIRC3)': 'T35173',
#  'Dual specificity protein phosphatase 1 (DUSP1)': 'T35194',
#  'Interleukin-7 (IL7)': 'T35232',
#  'S100 calcium-binding protein A4 (S100A4)': 'T35265',
#  'NKG2 D activating NK receptor (KLRK1)': 'T35289',
#  'Pancreatic hormone (PH)': 'T35303',
#  'Mothers against decapentaplegic homolog 3 (SMAD3)': 'T35445',
#  'Solute carrier family 19 member 1 (SLC19A1)': 'T35465',
#  'KRAS messenger RNA (KRAS mRNA)': 'T35474',
#  'GTPase NRas (NRAS)': 'T35486',
#  'Nectin cell adhesion molecule 4 (NECTIN4)': 'T35591',
#  'Integrin alpha-L (ITGAL)': 'T35640',
#  'Soluble epoxide hydrolase (EPHX2)': 'T35734',
#  'Histone-lysine N-methyltransferase SMYD3 (SMYD3)': 'T35792',
#  'Melanocortin receptor 1 (MC1R)': 'T35842',
#  'ERK activator kinase 1 (MEK1)': 'T35940',
#  'Organic anion transporter M1 (SLCO4C1)': 'T36053',
#  'Adenosine A3 receptor (ADORA3)': 'T36059',
#  'Glucagon-like peptide 1 receptor (GLP1R)': 'T36075',
#  'Cytosine deaminase (AICDA)': 'T36467',
#  'T-cell surface protein tactile (CD96)': 'T36479',
#  'Proteinase activated receptor 1 (F2R)': 'T36483',
#  'Peroxisome proliferator-activated receptor delta (PPARD)': 'T36557',
#  'Oxidative stress (OS)': 'T36658',
#  'p53-binding protein Mdm4 (MDM4)': 'T36741',
#  'Mitochondrial function (MF)': 'T36846',
#  'Prostate specific antigen (KLK3)': 'T36935',
#  'FOXP3 messenger RNA (FOXP3 mRNA)': 'T36958',
#  'Activin receptor-like kinase-1 (ACVRL1)': 'T36959',
#  'GDNF family receptor alpha-like (GFRAL)': 'T37012',
#  'Biliverdin reductase A (BLVRA)': 'T37046',
#  'Staphylococcus IgG binding protein A  (Stap-coc SpA)': 'T37048',
#  'Cathepsin A (CTSA)': 'T37154',
#  'RTP801 messenger RNA (RTP801 mRNA)': 'T37245',
#  'MYCBP messenger RNA (MYCBP mRNA)': 'T37298',
#  'Immunoglobulin E (IgE)': 'T37308',
#  'Solute carrier family 23 member 1 (SLC23A1)': 'T37382',
#  'Neuropeptide receptor (NPR)': 'T37405',
#  'Prominin-1 (PROM1)': 'T37434',
#  'Coagulation factor Va (F5)': 'T37510',
#  'B-cell receptor CD22 (CD22)': 'T37539',
#  'Cannabinoid receptor 2 (CB2)': 'T37693',
#  'Glutamate decarboxylase (GLUL)': 'T37735',
#  'Serum amyloid P-component (APCS)': 'T37742',
#  'Herpes simplex virus DNA polymerase UL30 (HSV UL30)': 'T37847',
#  'Albendazole monooxygenase (CYP3A4)': 'T37848',
#  'Rhinovirus Capsid protein (HRV VP)': 'T37876',
#  'SYK messenger RNA (SYK mRNA)': 'T37952',
#  'Cryptosporidium Pyruvate:ferredoxin oxidoreductase (Crypto CpPNO)': 'T38052',
#  'Tankyrase-2 (TNKS-2)': 'T38087',
#  'Trefoil factor-1 (TFF1)': 'T38159',
#  'Phospholipase A2 inhibitory protein (PA2IP)': 'T38161',
#  'Staphylococcus Beta-lactamase (Stap-coc blaZ)': 'T38179',
#  'GABA transporter-3 (SLC6A11)': 'T38200',
#  'Protein mono-ADP-ribosyltransferase TIPARP (TIPARP)': 'T38201',
#  'Fusion protein Bcr-Abl (Bcr-Abl)': 'T38284',
#  'Ribonucleoside-diphosphate reductase M2 (RRM2)': 'T38301',
#  'Voltage-gated calcium channel alpha Cav2.2 (CACNA1B)': 'T38338',
#  'Calgranulin B (S100A9)': 'T38431',
#  'Coagulation factor XII (F12)': 'T38509',
#  'AdoHcy hydrolase (SAHase)': 'T38528',
#  'Prostaglandin E2 receptor EP2 (PTGER2)': 'T38529',
#  'Hepatitis C virus Non-structural 5 (HCV NS5)': 'T38763',
#  'Apolipoprotein A messenger RNA (LPA mRNA)': 'T38810',
#  'AMP-activated protein kinase (AMPK)': 'T38875',
#  'Myeloid cell surface antigen CD33 (CD33)': 'T38950',
#  'Tumor antigen NGcGM3 (NGcGM3)': 'T39031',
#  'Leukocyte-associated Ig-like receptor 1 (LAIR1)': 'T39047',
#  'dUTP pyrophosphatase (DUT)': 'T39054',
#  'Calcium-activated potassium channel (KCN)': 'T39078',
#  'Human immunodeficiency virus Integrase (HIV IN)': 'T39087',
#  'G-protein coupled receptor 54 (KISS1R)': 'T39123',
#  'Cytomegalovirus Terminase (CMV TRM)': 'T39147',
#  'Tankyrase-1 (TNKS-1)': 'T39231',
#  'Glyceraldehyde-3-phosphate dehydrogenase (GAPDH)': 'T39321',
#  'Phosphodiesterase 7A (PDE7A)': 'T39523',
#  'MAPK/ERK signaling pathway (MAPK pathway)': 'T39554',
#  'Calmodulin (CALM)': 'T39610',
#  'Estradiol 17 beta-dehydrogenase (17-beta-HSD)': 'T39664',
#  'Solute carrier family 47 member 1 (SLC47A1)': 'T39676',
#  'Bile-salt-activated lipase (CEL)': 'T39677',
#  'Voltage-gated sodium channel alpha Nav1.5 (SCN5A)': 'T39716',
#  'Frizzled-7 receptor (FZD7)': 'T39797',
#  'Heat shock protein 20 (HSP20)': 'T39921',
#  'Macrophage migration inhibitory factor (MIF)': 'T39977',
#  'Euchromatic histone-lysine N-methyltransferase 1 (EHMT1)': 'T39996',
#  'Tissue kallikrein (KLK1)': 'T40000',
#  'Epidermal growth factor-like protein 7 (EGFL7)': 'T40010',
#  'Glucocorticoid receptor (NR3C1)': 'T40016',
#  'RRM1 messenger RNA (RRM1 mRNA)': 'T40045',
#  'Stress-activated protein kinase JNK1 (JNK1)': 'T40097',
#  "Inosine-5'-monophosphate dehydrogenase 1 (IMPDH1)": 'T40111',
#  'Pseudomonas Kynureninase (Pseudo kynU)': 'T40126',
#  'PKC-eta messenger RNA (PRKCH mRNA)': 'T40149',
#  'Aryl hydrocarbon receptor signaling pathway (AhR pathway)': 'T40160',
#  'DNA-binding factor KBF1 (p105)': 'T40192',
#  'Protein kinase C beta (PRKCB)': 'T40276',
#  'Neutrophil elastase (NE)': 'T40332',
#  'Interleukin 13 receptor alpha-2 (IL13RA2)': 'T40459',
#  'Proto-oncogene c-Met (MET)': 'T40474',
#  'Serine/threonine PP2A-alpha (PPP2CA)': 'T40491',
#  'Hepatitis C virus NS3 helicase (HCV NS3)': 'T40492',
#  'Hepatitis C virus Non-structural 5A (HCV NS5A)': 'T40555',
#  'Bromodomain-containing protein 4 (BRD4)': 'T40556',
#  'Hydroxysteroid dehydrogenase 3-beta (HSD3B)': 'T40628',
#  'Regulatory protein unspecific (RGP)': 'T40663',
#  'Polo-like kinase 1 (PLK1)': 'T40694',
#  'Staphylococcus Topoisomerase IV (Stap-coc parC)': 'T40696',
#  'Bacterial Dihydroneopterinaldolase (Bact folB)': 'T40730',
#  'Fungal Papulacandin B resistance protein 1 (Fung FKS1)': 'T40785',
#  "S-methyl-5'-thioadenosine phosphorylase (MTAP)": 'T40787',
#  'Sodium pump subunit alpha-1 (ATP1A1)': 'T40800',
#  'Poly [ADP-ribose] polymerase 2 (PARP2)': 'T40812',
#  'V-set and immunoglobulin domain-containing protein 9 (TIGIT)': 'T40874',
#  'Rhinovirus Protease 3C (HRV P3C)': 'T40909',
#  'Xanthine dehydrogenase/oxidase (XDH)': 'T40954',
#  'HIF2-alpha messenger RNA (EPAS1 mRNA)': 'T41003',
#  'Cathepsin L (CTSL)': 'T41141',
#  'Interleukin-27 (IL27)': 'T41171',
#  'Dehydropeptidase I (DPEP1)': 'T41201',
#  'microRNA hsa-miR-29b (MIR29b)': 'T41202',
#  'Hydroxyapatite (HA)': 'T41239',
#  'Taste receptor (TASR)': 'T41263',
#  'Transforming growth factor beta activator LRRC32 (LRRC32)': 'T41380',
#  'FGFR4 messenger RNA (FGFR4 mRNA)': 'T41515',
#  'EGFR messenger RNA (EGFR mRNA)': 'T41560',
#  'Adrenergic receptor alpha-2B (ADRA2B)': 'T41580',
#  'DGAT2 messenger RNA (DGAT2 mRNA)': 'T41597',
#  'Gastric inhibitory polypeptide receptor (GIPR)': 'T41750',
#  'BV virus Major capsid protein VP1 (BKV VP1)': 'T41756',
#  'Fungal Isoleucyl t-RNA synthetase (Fung ILS1)': 'T41820',
#  'Long transient receptor potential channel 8 (TRPM8)': 'T41955',
#  'Toll-like receptor (TLR)': 'T41963',
#  'Interleukin-1 beta (IL1B)': 'T42000',
#  'Bromodomain-containing protein 3 (BRD3)': 'T42048',
#  'N-acetylmannosamine kinase (GNE)': 'T42065',
#  'SPS1/STE20-related protein kinase YSK4 (YSK4)': 'T42157',
#  'Bacterial RNA polymerase sigma factor SigA (Bact sigA)': 'T42354',
#  'Glutamate receptor AMPA 2 (GRIA2)': 'T42392',
#  'Gamma-aminobutyric acid B receptor (GABBR)': 'T42446',
#  'Bacterial Shiga toxin 2 subunit B (Bact stxII)': 'T42521',
#  'Herpesvirus ubiquitin-specific protease (HAUSP)': 'T42658',
#  'Calcium-activated potassium channel KCa3.1 (KCNN4)': 'T42724',
#  'Serotoninnorepinephrinedopamine reuptake (SNDR)': 'T42748',
#  'Ribosomal protein S6 kinase beta-2 (RPS6KB2)': 'T42760',
#  'Ferrochelatase (FECH)': 'T42822',
#  'Melanoma-associated antigen 1 (MAGEA1)': 'T42854',
#  'Pseudomonas Psl exopolysaccharide (Pseudo pslG)': 'T42882',
#  'Fibroblast growth factor-21 (FGF21)': 'T42928',
#  'AXL receptor tyrosine kinase ligand (GAS6)': 'T42974',
#  'Alpha-crystallin (CRYA)': 'T43025',
#  'Leukocyte common antigen (PTPRC)': 'T43115',
#  'Tubulin (TUB)': 'T43189',
#  'Nuclear receptor ROR-alpha (RORA)': 'T43206',
#  'Coagulation factor VII (F7)': 'T43332',
#  'Tyrosine-protein kinase (PTK)': 'T43415',
#  'HAO1 messenger RNA (HAO1 mRNA)': 'T43658',
#  'Toll-like receptor 5 (TLR5)': 'T43718',
#  'Corticosteroid 11-beta-dehydrogenase 2 (HSD11B2)': 'T43721',
#  'Voltage-gated sodium channel alpha Nav1.8 (SCN10A)': 'T43739',
#  'Thyroid hormone receptor (THR)': 'T43760',
#  'Histamine release (His rele)': 'T43902',
#  'Carbonic anhydrase (CA)': 'T43920',
#  'Ig-like domain-containing receptor 2 (ILDR2)': 'T43980',
#  'cAMP formation (cAMP form)': 'T44008',
#  'Aquaporin-1 (AQP1)': 'T44057',
#  'Adrenergic receptor beta-1 (ADRB1)': 'T44068',
#  'Angiopoietin-1 (ANGPT1)': 'T44141',
#  'Mitochondrial aldehyde dehydrogenase (ALDH2)': 'T44282',
#  'Cannabinoid receptor (CB)': 'T44351',
#  'Cyclin-dependent kinase 9 (CDK9)': 'T44458',
#  'Gap junction alpha-1 protein (GJA1)': 'T44479',
#  'Normal cross-reacting antigen (CD66c)': 'T44513',
#  'Interleukin 3 receptor (CSF2RB)': 'T44589',
#  'Plasmodium Cysteine protease falcipain-2 (Malaria CPF2)': 'T44614',
#  'Interleukin-22 (IL22)': 'T44682',
#  ...}

# %%
disease2genes_ttd
# Out:
# {'Chronic kidney disease  ICD11  GB61 ': {'5-HT 2A receptor (HTR2A)',
#   'Adrenergic receptor alpha-2C (ADRA2C)',
#   'Advanced glycosylation end product receptor (AGER)',
#   'Androgen receptor (AR)',
#   'Angiotensin-converting enzyme (ACE)',
#   'Apoptosis signal-regulating kinase 1 (MAP3K5)',
#   'B2 bradykinin receptor (BDKRB2)',
#   'Beta-secretase (BACE)',
#   'C-C chemokine receptor type 2 (CCR2)',
#   'C-C chemokine receptor type 5 (CCR5)',
#   'Cannabinoid receptor 1 (CB1)',
#   'Coagulation factor XI (F11)',
#   'Connective tissue growth factor (CTGF)',
#   'Dopamine D2 receptor (D2R)',
#   'Endothelin A receptor (EDNRA)',
#   'Epiregulin (EREG)',
#   'Farnesoid X-activated receptor (FXR)',
#   'Galectin (LGALS)',
#   'Immunoglobulin gamma Fc receptor IIA (FCGR2A)',
#   'Insulin-like growth factor I receptor (IGF1R)',
#   'MAP kinase p38 (MAPK12)',
#   'Matrix metalloproteinase-1 (MMP-1)',
#   'Membrane copper amine oxidase (AOC3)',
#   'Mineralocorticoid receptor  (MR)',
#   'Neutral endopeptidase (MME)',
#   'Nitric-oxide synthase inducible (NOS2)',
#   'Prostacyclin receptor (PTGIR)',
#   'Rho-associated protein kinase 1 (ROCK1)',
#   'Sodium/glucose cotransporter 2 (SGLT2)',
#   'Sodium/hydrogen exchanger 3 (SLC9A3)',
#   'Transforming growth factor alpha (TGFA)',
#   'Transforming growth factor beta (TGFB)',
#   'Urotensin II receptor (UTS2R)',
#   'Vitamin D3 receptor (VDR)',
#   'Xanthine dehydrogenase/oxidase (XDH)'},
#  'Fibrosis  ICD11  GA14GC01 ': {'CCN2 messenger RNA (CCN2 mRNA)',
#   'CI Man-6-P receptor (IGF2R)',
#   'CTGF messenger RNA (CTGF mRNA)',
#   'Caspase-1 (CASP1)',
#   'Dopamine D2 receptor (D2R)',
#   'Extracellular lysophospholipase D (E-NPP2)',
#   'Lysophosphatidate-3 receptor (LPAR3)',
#   'Lysophosphatidic acid receptor 1 (LPAR1)',
#   'MAPK-activated protein kinase 2 (MAPKAPK2)',
#   'NADPH oxidase (NOX)',
#   'NADPH oxidase 4 (NOX4)',
#   'Proto-oncogene c-Met (MET)',
#   'TGF-beta receptor type I (TGFBR1)',
#   'Vascular endothelial growth factor A (VEGFA)'},
#  'Rheumatoid arthritis  ICD11  FA20 ': {'5-HT 2 receptor (5HT2R)',
#   'A proliferation-inducing ligand (APRIL)',
#   'ATP-binding cassette transporter G2 (ABCG2)',
#   'Activation B7-1 antigen (CD80)',
#   'Adenosine A3 receptor (ADORA3)',
#   'AdoHcy hydrolase (SAHase)',
#   'Aldose reductase (AKR1B1)',
#   'Amino acid transporter ATB0+ (SLC6A14)',
#   'Angiopoietin 1 receptor (TEK)',
#   'Apoptosis mediating surface antigen FAS (FAS)',
#   'Arachidonate 5-lipoxygenase (5-LOX)',
#   'B-cell-activating factor (TNFSF13B)',
#   'B-cell-activating factor receptor (TNFRSF13C)',
#   'B-lymphocyte surface antigen B4 (CD19)',
#   'B1 bradykinin receptor (BDKRB1)',
#   'B2 bradykinin receptor (BDKRB2)',
#   'Bacterial Penicillin binding protein (Bact PBP)',
#   'Beta-secretase (BACE)',
#   'C-C chemokine receptor type 1 (CCR1)',
#   'C-C chemokine receptor type 2 (CCR2)',
#   'C-C chemokine receptor type 5 (CCR5)',
#   'C5a anaphylatoxin chemotactic receptor (C5AR1)',
#   'CD40L receptor (CD40)',
#   'CaM-kinase II (CAMK2)',
#   'Cannabinoid receptor 2 (CB2)',
#   'Carbonic anhydrase I (CA-I)',
#   'Carbonic anhydrase II (CA-II)',
#   'Caspase-1 (CASP1)',
#   'Cathepsin B (CTSB)',
#   'Cathepsin K (CTSK)',
#   'Cathepsin L (CTSL)',
#   'Cathepsin S (CTSS)',
#   'Cell adhesion molecule (CADM)',
#   'Chemokine receptor (CHR)',
#   'Cholestenol delta-isomerase (EBP)',
#   'Colony stimulating factor-1 receptor (CSF-1R)',
#   'Complement C5 (CO5)',
#   'Cytokine receptor unspecific (CRF)',
#   'Cytoplasmic thioredoxin reductase (TXNRD1)',
#   'Cytotoxic T-lymphocyte protein 4 (CTLA-4)',
#   'Dihydrofolate reductase (DHFR)',
#   'Dihydroorotate dehydrogenase (DHODH)',
#   'Estrogen-related receptor-alpha (ESRRA)',
#   'Extracellular signal-regulated kinase 2 (ERK2)',
#   'GMCSFR-alpha (CSF2RA)',
#   'Glucocorticoid receptor (NR3C1)',
#   'Glucocorticoid receptor messenger RNA (GCR mRNA)',
#   'Glucose-6-phosphate dehydrogenase (G6PD)',
#   'Granulocyte-macrophage colony-stimulating factor (CSF2)',
#   'HMG-CoA reductase (HMGCR)',
#   'HSPB1 messenger RNA (HSPB1 mRNA)',
#   'HUMAN adaptor-associated kinase 1 (AAK1)',
#   'HUMAN colony-stimulating factor (GM-CSF)',
#   'HUMAN cyclin G-associated kinase (GAK)',
#   'HUMAN interleukin 6 (IL6)',
#   'HUMAN interleukin-1 receptor 1 (IL1R1)',
#   'HUMAN interleukin-6 receptor (IL6R)',
#   'Histamine H1 receptor (H1R)',
#   'Histamine H4 receptor (H4R)',
#   'Histone deacetylase (HDAC)',
#   'Human immunodeficiency virus Tat protein (HIV tat)',
#   'Immunoglobulin E (IgE)',
#   'Immunoglobulin gamma Fc receptor IIB (FCGR2B)',
#   'Immunoglobulin gamma-1 heavy NIE (NIE)',
#   'Induced myeloid leukemia cell differentiation protein Mcl-1 (MCL1)',
#   'Inhibitor of nuclear factor kappa-B kinase (IKK)',
#   'Inhibitor of nuclear factor kappa-B kinase beta (IKKB)',
#   'Integrin alpha-1 (VLA-1)',
#   'Integrin alpha-4/beta-1 (ITGA4/B1)',
#   'Integrin alpha-4/beta-7 (ITGA4/B7)',
#   'Integrin alpha-V/beta-3 (ITGAV/B3)',
#   'Interferon-beta (IFNB1)',
#   'Interferon-gamma (IFNG)',
#   'Interleukin 1 receptor type 1 (IL1R1)',
#   'Interleukin 1 receptor type 2 (IL1R2)',
#   'Interleukin 17 receptor (IL17R)',
#   'Interleukin 6 receptor (IL6R)',
#   'Interleukin-1 (IL1)',
#   'Interleukin-1 alpha (IL1A)',
#   'Interleukin-1 beta (IL1B)',
#   'Interleukin-10 (IL10)',
#   'Interleukin-12 alpha (IL12A)',
#   'Interleukin-12 beta (IL12B)',
#   'Interleukin-15 (IL15)',
#   'Interleukin-17 (IL17)',
#   'Interleukin-18 (IL18)',
#   'Interleukin-2 (IL2)',
#   'Interleukin-23 (IL23)',
#   'Interleukin-6 (IL6)',
#   'Ion channel unspecific (IC)',
#   'Janus kinase 1 (JAK-1)',
#   'Janus kinase 2 (JAK-2)',
#   'Janus kinase 3 (JAK-3)',
#   'LOX-5 messenger RNA (ALOX5 mRNA)',
#   'Leukocyte surface antigen Leu-16 (CD20)',
#   'Leukotriene B4 receptor 1 (LTB4R)',
#   'Lipoxygenase (ALOX)',
#   'Lymphotoxin beta receptor (LTBR)',
#   'Lymphotoxin-alpha (LTA)',
#   'MAP kinase p38 (MAPK12)',
#   'MAPK-activated protein kinase 5 (MAPKAPK5)',
#   'Matrix metalloproteinase (MMP)',
#   'Matrix metalloproteinase-1 (MMP-1)',
#   'Matrix metalloproteinase-13 (MMP-13)',
#   'Matrix metalloproteinase-3 (MMP-3)',
#   'Matrix metalloproteinase-8 (MMP-8)',
#   'Matrix metalloproteinase-9 (MMP-9)',
#   'Monocyte chemotactic and activating factor (CCL2)',
#   'NAD-dependent deacetylase sirtuin-1 (SIRT1)',
#   'NADPH oxidase (NOX)',
#   'NF-kappa-B-p38 signaling pathway (NFKB-p38 pathway)',
#   'NKG2 D activating NK receptor (KLRK1)',
#   'NKG2-A/B-activating NK receptor (NKG2A)',
#   'Neutrophil elastase (NE)',
#   'Nicotinic acetylcholine receptor (nAChR)',
#   'Nitric-oxide synthase inducible (NOS2)',
#   'Nuclear factor NF-kappa-B (NFKB)',
#   'Nuclear receptor ROR-gamma (RORG)',
#   'Nuclear receptor unspecific (NR)',
#   'Oncostatin-M (OSM)',
#   'Opioid receptor delta (OPRD1)',
#   'Osteoblast cadherin (CDH11)',
#   'Osteoclast differentiation factor (ODF)',
#   'P2X purinoceptor 7 (P2RX7)',
#   'PI3-kinase alpha (PIK3CA)',
#   'PI3-kinase delta (PIK3CD)',
#   'PI3-kinase gamma (PIK3CG)',
#   'PMN apoptosis and chemotaxis (PMNAC)',
#   'Pancreatic elastase 1 (CELA1)',
#   'Peroxisome proliferator-activated receptor alpha (PPARA)',
#   'Phosphodiesterase 4A (PDE4A)',
#   'Phosphodiesterase 4B (PDE4B)',
#   'Phosphodiesterase 4D (PDE4D)',
#   'Phospholipase A2 (PLA2G1B)',
#   'Plasmodium Dihydroorotate dehydrogenase (Malaria DHOdehase)',
#   'Potassium channel unspecific (KC)',
#   'Prostaglandin D2 receptor (PTGDR)',
#   'Prostaglandin G/H synthase (COX)',
#   'Prostaglandin G/H synthase 1 (COX-1)',
#   'Prostaglandin G/H synthase 2 (COX-2)',
#   'Protease unspecific (PRO)',
#   'Protein kinase C beta (PRKCB)',
#   'Proton-coupled folate transporter (SLC46A1)',
#   'Purine nucleoside phosphorylase (PNP)',
#   'Receptor-interacting protein 1 (RIPK1)',
#   'Rho-associated protein kinase 2 (ROCK2)',
#   'Sarcoplasmic/endoplasmic reticulum calcium ATPase (ATP2A)',
#   'Secretory phospholipase A2 (sPLA2)',
#   'Serum albumin (ALB)',
#   'Solute carrier family 19 member 1 (SLC19A1)',
#   'Solute carrier family 36 member 2 (SLC36A2)',
#   'Sphingosine-1 phosphate receptor (S1PR)',
#   'Sphingosine-1-phosphate lyase 1 (SGPL1)',
#   'Sphingosine-1-phosphate receptor 1 (S1PR1)',
#   'Stress-activated protein kinase (p38)',
#   'Stress-activated protein kinase 2a (p38 alpha)',
#   'Stress-activated protein kinase 2b (p38 beta)',
#   'T-cell surface glycoprotein CD4 (CD4)',
#   'T-lymphocyte activation antigen CD86 (FUN1)',
#   'TNF alpha converting enzyme (ADAM17)',
#   'TNF related activation protein (CD40LG)',
#   'TNF-alpha/IL-1 beta production (TNFA/IL1B produ)',
#   'TNF-related weak inducer of apoptosis (TWEAK)',
#   'TNFA messenger RNA (TNF mRNA)',
#   'Toll-like receptor (TLR)',
#   'Toll-like receptor 8 (TLR8)',
#   'Transcription factor AP-1 (JUN)',
#   'Transferase unspecific (TF)',
#   'Transforming growth factor beta 1 (TGFB1)',
#   'Transient receptor potential cation channel V1 (TRPV1)',
#   'Translocator protein (TSPO)',
#   'Tumor necrosis factor (TNF)',
#   'Tumor necrosis factor receptor type I (TNF-R1)',
#   'Tyrosinase (TYR)',
#   'Tyrosine-protein kinase (PTK)',
#   'Tyrosine-protein kinase BTK (ATK)',
#   'Tyrosine-protein kinase SYK (SYK)',
#   'Vascular endothelial growth factor A (VEGFA)'},
#  'COVID19  ICD11  1D6Y ': {'COVID-19 3C-like protease (3CLpro)',
#   'COVID-19 RNA-directed RNA polymerase (RdRp)',
#   'COVID-19 non-structural protein 14 (nsp14)',
#   'COVID-19 papain-like proteinase (PL-PRO)',
#   'COVID-19 replicase polyprotein 1ab (pp1ab)',
#   'COVID-19 spike glycoprotein (S)',
#   'CREB-regulated transcription coactivator 1 (TORC1)',
#   'Dihydroorotate dehydrogenase (DHODH)',
#   'Granulocyte-macrophage colony-stimulating factor (CSF2)',
#   'HUAMN alpha-1 adrenergic receptor (ADRA1)',
#   'HUAMN eIF4E-eIF4G interaction (eIF4E-eIF4G)',
#   'HUAMN monocyte differentiation antigen CD14 (CD14)',
#   'HUAMN serine protease factor Xa (SERPINA5)',
#   'HUMAN C-C chemokine receptor 5 (CCR5)',
#   'HUMAN C5a receptor (C5aR)',
#   'HUMAN MYD88NF-kappa-B proinflammatory pathway (MYD88-NFKB pathway)',
#   'HUMAN PI3-kinase delta (PIK3CD)',
#   'HUMAN PI3-kinase gamma (PIK3CG)',
#   'HUMAN adaptor-associated kinase 1 (AAK1)',
#   'HUMAN angiopoietin-2 (ANG-2)',
#   'HUMAN angiotensin-converting enzyme (ACE)',
#   'HUMAN angiotensin-converting enzyme 2 (ACE2)',
#   'HUMAN basigin (BSG)',
#   'HUMAN beta adrenergic receptor (BAR)',
#   'HUMAN bromodomain-containing protein 2 (BRD2)',
#   'HUMAN bruton tyrosine kinase (BTK)',
#   'HUMAN calcitonin gene-related peptide type 1 receptor (CALCRL)',
#   'HUMAN calpain-1/calpain small subunit 1 heterodimer (CAPN1/CAPNS1)',
#   'HUMAN calpain-2/calpain small subunit 1 heterodimer (CAPN2/CAPNS1)',
#   'HUMAN casein kinase II (CSK2)',
#   'HUMAN clathrin-mediated endocytosis (RME)',
#   'HUMAN colony-stimulating factor (GM-CSF)',
#   'HUMAN complement C5 alpha (C5A)',
#   'HUMAN complement C5 protein (C5)',
#   'HUMAN cyclin G-associated kinase (GAK)',
#   'HUMAN cysteinyl leukotriene receptor (CysLTR)',
#   'HUMAN dihydroorotate dehydrogenase (DHODH)',
#   'HUMAN dipeptidyl peptidase 1 (CTSC)',
#   'HUMAN dipeptidyl peptidase 4 (DPP-4)',
#   'HUMAN estrogen receptor (ESR1)',
#   'HUMAN fusion protein Bcr-Abl (Bcr-Abl)',
#   'HUMAN glycosylation of host receptor (GHR)',
#   "HUMAN inosine-5'-monophosphate dehydrogenase 1 (IMPDH1)",
#   "HUMAN inosine-5'-monophosphate dehydrogenase 2 (IMPDH2)",
#   'HUMAN interferon gamma (IFNG)',
#   'HUMAN interleukin 6 (IL6)',
#   'HUMAN interleukin 8 (IL8)',
#   'HUMAN interleukin-1 receptor 1 (IL1R1)',
#   'HUMAN interleukin-6 receptor (IL6R)',
#   'HUMAN janus kinase 1 (JAK-1)',
#   'HUMAN janus kinase 2 (JAK-2)',
#   'HUMAN mammalian target of rapamycin (mTOR)',
#   'HUMAN mannose receptor (MRC1)',
#   'HUMAN mineralocorticoid receptor (MR)',
#   'HUMAN opioid receptor sigma 1 (OPRS1)',
#   'HUMAN pH-dependent viral fusion/replication (pH-DVF/R)',
#   'HUMAN phosphatidylinositol 3-phosphate 5-kinase (PIKfyve)',
#   'HUMAN phosphodiesterase type 5 (PDE5)',
#   'HUMAN programmed cell death protein 1 (PD-1)',
#   'HUMAN sigma intracellular receptor 2 (TMEM97)',
#   'HUMAN toll-like receptor 2 (TLR2)',
#   'HUMAN toll-like receptor 3 (TLR3)',
#   'HUMAN toll-like receptor 6 (TLR6)',
#   'HUMAN toll-like receptor 7/9 signalling pathway (TLR7/9 pathway)',
#   'HUMAN toll-like receptor 9 (TLR9)',
#   'HUMAN transmembrane protease serine 2 (TMPRSS2)',
#   'HUMAN two pore channel subtype 2 (TPC2)',
#   'HUMAN type-1 angiotensin II receptor (AGTR1)',
#   'HUMAN valosin-containing protein p97 (VCP)',
#   'HUMAN vascular endothelial growth factor (VEGF)',
#   'Interleukin-8 (IL8)',
#   'MERS-CoV 3C-like proteinase (3CLpro)',
#   'MERS-CoV RNA-directed RNA polymerase (RdRp)',
#   'MERS-CoV papain-like proteinase (PL-PRO)',
#   'MERS-CoV spike glycoprotein (S)',
#   'SARS-CoV 3C-like protease (3CLpro)',
#   'SARS-CoV RNA-directed RNA polymerase (RdRp)',
#   'SARS-CoV papain-like proteinase (PL-PRO)',
#   'TGF beta-2 messenger RNA (TGFB2 mRNA)',
#   'Virus RNA-dependent RNA polymerase (Viru RdRP)'},
#  'Solid tumour  cancer  ICD11  2A002F9Z ': {'A-Raf messenger RNA (ARAF mRNA)',
#   'ALK tyrosine kinase receptor (ALK)',
#   'AMP-activated protein kinase (AMPK)',
#   'AP endonuclease 1 (APEX1)',
#   'ATM serine/threonine kinase (ATM)',
#   'ATP-dependent RNA helicase DDX5 (DDX5)',
#   'Acetylcholinesterase (AChE)',
#   'Activated leukocyte cell adhesionmolecule (ALCAM)',
#   'Activation B7-1 antigen (CD80)',
#   'Activation-inducible TNFR family receptor (TNFRSF18)',
#   'Activin receptor-like kinase 2 (ALK-2)',
#   'Activin receptor-like kinase-1 (ACVRL1)',
#   'Adenosine A2a receptor (ADORA2A)',
#   'Adenosine A2b receptor (ADORA2B)',
#   'Adenosine A3 receptor (ADORA3)',
#   'Adenosine receptor (ADOR)',
#   'Adenylate cyclase (ADCY)',
#   'Adenylate cyclase type 2 (ADCY2)',
#   'Adrenergic receptor alpha-1D (ADRA1D)',
#   'Albendazole monooxygenase (CYP3A4)',
#   'Aldehyde oxidase (AOX1)',
#   'Alpha-glucosidase (GLA)',
#   'Amyloid beta A4 protein (APP)',
#   'Androgen receptor (AR)',
#   'Androgen receptor messenger RNA (AR mRNA)',
#   'Angiogenesis (AGG)',
#   'Angiopoietin 1 receptor (TEK)',
#   'Angiopoietin-1 (ANGPT1)',
#   'Angiopoietin-2 (ANGPT2)',
#   'Antithrombin-III (ATIII)',
#   'Apolipoprotein(a) (LPA)',
#   'Apoptosis inhibitor survivin (BIRC5)',
#   'Apoptosis mediating surface antigen FAS (FAS)',
#   'Apoptosis regulator Bcl-2 (BCL-2)',
#   'Apoptosis regulator Bcl-W (BCL-W)',
#   'Apoptosis regulator Bcl-xL (BCL-xL)',
#   'Arachidonate 5-lipoxygenase (5-LOX)',
#   'Arachidonate 5-lipoxygenase activating protein (FLAP)',
#   'Arginase (ARG)',
#   'Aryl hydrocarbon receptor (AHR)',
#   'Aurora kinase A (AURKA)',
#   'Aurora kinase B (AURKB)',
#   'Aurora kinase C (AURKC)',
#   'B- and T-lymphocyte attenuator (BTLA)',
#   'B-Raf messenger RNA (BRAF mRNA)',
#   'B2 bradykinin receptor (BDKRB2)',
#   'B7 homolog 3 (CD276)',
#   'BCL-2 messenger RNA (BCL2 mRNA)',
#   'BDNF/NT-3 growth factors receptor (TrkB)',
#   'Beta-catenin (CTNNB1)',
#   'Beta-secretase (BACE)',
#   'Biliary glycoprotein 1 (CEACAM1)',
#   'Bombesin receptor (BS)',
#   'Bromodomain and extraterminal domain protein (BET)',
#   'Bromodomain-containing protein 2 (BRD2)',
#   'Bromodomain-containing protein 4 (BRD4)',
#   'C-C chemokine receptor type 2 (CCR2)',
#   'C-C chemokine receptor type 4 (CCR4)',
#   'C-C chemokine receptor type 5 (CCR5)',
#   'C-X-C chemokine receptor type 1 (CXCR1)',
#   'C-X-C chemokine receptor type 2 (CXCR2)',
#   'C-X-C chemokine receptor type 3 (CXCR3)',
#   'C-X-C chemokine receptor type 4 (CXCR4)',
#   'C-X-C chemokine receptor type 5 (CXCR5)',
#   'C-X-C chemokine receptor type 7 (ACKR3)',
#   'C-X-C motif chemokine 10 (CXCL10)',
#   'C-X-C motif chemokine 9 (CXCL9)',
#   'CAAX farnesyltransferase beta (FNTB)',
#   'CBLB messenger RNA (CBLB mRNA)',
#   'CD40L receptor (CD40)',
#   'CD70 antigen (CD27-L)',
#   'CD80-PD-L1 interaction (CD80/PD-L1 PPI)',
#   'CDC7-related kinase (CDC7)',
#   'CI Man-6-P receptor (IGF2R)',
#   'CREB-binding protein (CREBBP)',
#   'CTP synthase (CTPS1)',
#   'Cancer stemness kinase (CSK)',
#   'Cancer/testis antigen 1 (NY-ESO-1)',
#   'Candida Cytochrome P450 51 (Candi ERG11)',
#   'Candida Thymidylate synthase (Candi TMP1)',
#   'Carbohydrate antigen Lewis-Y (Lewis-Y)',
#   'Carbonic anhydrase (CA)',
#   'Carbonic anhydrase I (CA-I)',
#   'Carbonic anhydrase II (CA-II)',
#   'Carbonic anhydrase IV (CA-IV)',
#   'Carbonic anhydrase IX (CA-IX)',
#   'Carbonic anhydrase VI (CA-VI)',
#   'Carbonic anhydrase XII (CA-XII)',
#   'Carbonic anhydrase XIV (CA-XIV)',
#   'Carcinoembryonic antigen CEA (CD66e)',
#   'Casein kinase I alpha (CSNK1A1)',
#   'Casein kinase II (CSNK2)',
#   'Casein kinase II alpha (CSNK2A1)',
#   'Caspase (CASP)',
#   'Caspase-3 (CASP3)',
#   'Caspase-8 (CASP8)',
#   'Caspase-9 (CASP9)',
#   'Caterpiller protein 1.1 (NLRP3)',
#   'Cathepsin L (CTSL)',
#   'Cathepsin S (CTSS)',
#   'Cationic trypsinogen (PRSS1)',
#   'Cell division cycle protein 20 homolog (CDC20)',
#   'Cellular disintegrin-related protein (ADAM9)',
#   'Cellular inhibitor of apoptosis 1 (BIRC2)',
#   'Cellular inhibitor of apoptosis 2 (BIRC3)',
#   'Cellular tumor antigen p53 (TP53)',
#   'Centromeric protein E (CENPE)',
#   'Checkpoint kinase-1 (CHK1)',
#   'Chloride channel unspecific (ClC)',
#   'Cholesterol 24-monooxygenase (CYP46A1)',
#   'Choline kinase (CHKA)',
#   'Cholinephosphate cytidylyltransferase (PCYT1B)',
#   'Chymotrypsin (CTR)',
#   'Claudin-18 (CLDN18)',
#   'Co-stimulatory molecule 4-1BB (CD137)',
#   'Coagulation factor IIa (F2)',
#   'Coagulation factor Xa (F10)',
#   'Colony stimulating factor-1 receptor (CSF-1R)',
#   'Cyclic ADP-ribose hydrolase 1 (CD38)',
#   'Cyclin-dependent kinase (CDK)',
#   'Cyclin-dependent kinase 1 (CDK1)',
#   'Cyclin-dependent kinase 12 (CDK12)',
#   'Cyclin-dependent kinase 13 (CDK13)',
#   'Cyclin-dependent kinase 2 (CDK2)',
#   'Cyclin-dependent kinase 4 (CDK4)',
#   'Cyclin-dependent kinase 6 (CDK6)',
#   'Cyclin-dependent kinase 7 (CDK7)',
#   'Cyclin-dependent kinase 9 (CDK9)',
#   'Cytidine deaminase (CDA)',
#   'Cytokine receptor unspecific (CRF)',
#   'Cytoplasmic thioredoxin reductase (TXNRD1)',
#   'Cytosine deaminase (AICDA)',
#   'Cytotoxic T-lymphocyte protein 4 (CTLA-4)',
#   'DNA [cytosine-5]-methyltransferase (DNMT)',
#   'DNA [cytosine-5]-methyltransferase 1 (DNMT1)',
#   'DNA [cytosine-5]-methyltransferase 3B (DNMT3B)',
#   'DNA polymerase beta (POLB)',
#   'DNA repair protein RAD51 homolog 1 (RAD51)',
#   'DNA replication (DNA repli)',
#   'DNA synthesis (DNA synth)',
#   'DNA topoisomerase I (TOP1)',
#   'DNA topoisomerase II (TOP2)',
#   'DNA topoisomerase II alpha (TOP2A)',
#   'DNA topoisomerase II beta (TOP2B)',
#   'DNA-binding factor KBF1 (p105)',
#   'DNA-dependent DNA polymerase (DPOL)',
#   'DNA-dependent protein kinase catalytic (PRKDC)',
#   'Delta-like protein 4 (DLL4)',
#   'Deubiquitinating enzyme 1 (USP1)',
#   'Dihydrofolate reductase (DHFR)',
#   'Dihydrothymine dehydrogenase (DPYD)',
#   'Dipeptidyl peptidase 8 (DPP-8)',
#   'Dipeptidyl peptidase 9 (DPP-9)',
#   'Dopamine D2 receptor (D2R)',
#   'Dopamine D3 receptor (D3R)',
#   'Dopamine receptor (DR)',
#   'Dual specificity protein kinase TTK (MPS1)',
#   'E-selectin (SELE)',
#   'E2F transcription factor 1 (E2F1)',
#   'EGFR messenger RNA (EGFR mRNA)',
#   'ERBB2 messenger RNA (HER2 mRNA)',
#   'ERBB3 messenger RNA (ERBB3 mRNA)',
#   'ERK activator kinase (MEK)',
#   'ERK activator kinase 1 (MEK1)',
#   'ERK activator kinase 2 (MEK2)',
#   "Ecto-5'-nucleotidase (CD73)",
#   'Ectonucleoside triphosphate diphosphohydrolase 1 (CD39)',
#   'Endoplasmic reticulum chaperone BiP (HSPA5)',
#   'Endoplasmic reticulum to nucleus signaling 1 (ERN1)',
#   'Endothelial plasminogen activator inhibitor (SERPINE1)',
#   'Endothelin A receptor (EDNRA)',
#   'Endothelin B receptor (EDNRB)',
#   'Enhancer of zeste homolog 1 (EZH1)',
#   'Enhancer of zeste homolog 2 (EZH2)',
#   'Ephrin type-A receptor 2 (EPHA2)',
#   'Ephrin type-A receptor 4 (EPHA4)',
#   'Ephrin type-B receptor 2 (EPHB2)',
#   'Ephrin type-B receptor 4 (EPHB4)',
#   'Epidermal growth factor receptor (EGFR)',
#   'Erbb2 tyrosine kinase receptor (HER2)',
#   'Erbb3 tyrosine kinase receptor (Erbb-3)',
#   'Erbb4 tyrosine kinase receptor (Erbb-4)',
#   'Erythropoietin Receptor (EPOR)',
#   'Estrogen receptor (ESR)',
#   'Estrogen receptor beta (ESR2)',
#   'Euchromatic histone-lysine N-methyltransferase 1 (EHMT1)',
#   'Exportin-1 (XPO1)',
#   'Extracellular lysophospholipase D (E-NPP2)',
#   'Extracellular matrix receptor III (CD44)',
#   'Extracellular signal-regulated kinase 1 (ERK1)',
#   'Extracellular signal-regulated kinase 2 (ERK2)',
#   'FGFR4 messenger RNA (FGFR4 mRNA)',
#   'FK506-binding protein (FKBP)',
#   'FOXP3 messenger RNA (FOXP3 mRNA)',
#   'Facilitates chromatin transcription complex (FACT)',
#   'Farnesyl protein transferase (Ftase)',
#   'Fascin (FSCN1)',
#   'Fatty acid synthase (FASN)',
#   'Fibroblast growth factor (FGF)',
#   'Fibroblast growth factor receptor (FGFR)',
#   'Fibroblast growth factor receptor 1 (FGFR1)',
#   'Fibroblast growth factor receptor 2 (FGFR2)',
#   'Fibroblast growth factor receptor 3 (FGFR3)',
#   'Fibroblast growth factor receptor 4 (FGFR4)',
#   'Fibroblast growth factor-2 (FGF2)',
#   'Fms-like tyrosine kinase 3 (FLT-3)',
#   'Focal adhesion kinase 1 (FAK)',
#   'Folate receptor alpha (FOLR1)',
#   'Free radical (FRD)',
#   'Frizzled-7 receptor (FZD7)',
#   'Fucosyl GM1 (FucGM1)',
#   'Fusion protein Bcr-Abl T315I mutant (Bcr-Abl T315I)',
#   'Fyn tyrosine protein kinase (FYN)',
#   'G-protein coupled estrogen receptor 1 (GPER1)',
#   'G-protein coupled receptor 48 (LGR4)',
#   'G1/S-specific cyclin-D1 (CCND1)',
#   'GAR transformylase (GART)',
#   'GDNF family receptor alpha-like (GFRAL)',
#   'GMCSFR-alpha (CSF2RA)',
#   'GTPase KRas (KRAS)',
#   'GTPase NRas (NRAS)',
#   'Gamma-aminobutyric acid B receptor (GABBR)',
#   'Gamma-secretase (GS)',
#   'Ganglioside GD2 (GD2)',
#   'Gap junction alpha-8 protein (Cx50)',
#   'Gastric H(+)/K(+) ATPase alpha (ATP4A)',
#   'Gastrin-releasing peptide receptor (GRPR)',
#   'Gastrin/cholecystokinin type B receptor (CCKBR)',
#   'Geranylgeranyl transferase (GGTase)',
#   'Geranylgeranyl transferase I (GGTase-I)',
#   'Geranyltranstransferase (FDPS)',
#   'Globohexaosylceramide (Globo H)',
#   'Glucocorticoid receptor (NR3C1)',
#   'Glucocorticoid receptor messenger RNA (GCR mRNA)',
#   'Glutamate carboxypeptidase II (GCPII)',
#   'Glutamate--cysteine ligase modifier (GCLM)',
#   'Glutaminase (GLS)',
#   'Glutathione S-transferase P (GSTP1)',
#   'Glutathione S-transferase omega-1 (GSTO-1)',
#   'Glycinamide ribonucleotide formyltransferase (GART)',
#   'Glycogen synthase kinase-3 beta (GSK-3B)',
#   'Glypican-3 (GPC3)',
#   'Golgi alpha-mannosidase II (MAN2A1)',
#   'Gonadotropin-releasing hormone receptor (GNRHR)',
#   'Granulocyte colony-stimulating factor receptor (G-CSF-R)',
#   'Granulocyte-macrophage colony-stimulating factor (CSF2)',
#   'Growth hormone secretagogue receptor 1 (GHSR)',
#   'Guanylate cyclase (GC)',
#   'Guanylyl cyclase C (GUCY2C)',
#   'H-ras messenger RNA (HRAS mRNA)',
#   'HIF-prolyl hydroxylase 2 (HPH-2)',
#   'HUMAN eukaryotic initiation factor-4A (eIF4A)',
#   'Heat shock protein 70 (HSP70)',
#   'Heat shock protein 90 alpha (HSP90A)',
#   'Heat shock protein 90 beta (HSP90B)',
#   'Hedgehog signaling pathway (HS pathway)',
#   'Hepatitis A virus cellular receptor 2 (TIM3)',
#   'Hepatocyte growth factor (HGF)',
#   'Herpes simplex virus DNA polymerase UL30 (HSV UL30)',
#   'Herpesvirus ubiquitin-specific protease (HAUSP)',
#   'Histamine N-methyltransferase (HNMT)',
#   'Histone acetyltransferase p300 (EP300)',
#   'Histone deacetylase (HDAC)',
#   'Histone deacetylase 1 (HDAC1)',
#   'Histone deacetylase 10 (HDAC10)',
#   'Histone deacetylase 2 (HDAC2)',
#   'Histone deacetylase 3 (HDAC3)',
#   'Histone deacetylase 4 (HDAC4)',
#   'Histone deacetylase 6 (HDAC6)',
#   'Histone deacetylase 8 (HDAC8)',
#   'Histone synthesis (Histone synth)',
#   'Histone-lysine N-methyltransferase EHMT2 (EHMT2)',
#   'Histone-lysine N-methyltransferase SMYD3 (SMYD3)',
#   'Human Deoxyribonucleic acid (hDNA)',
#   'Human Deoxyribonucleic acid major groove (hDNA maj)',
#   'Human Deoxyribonucleic acid minor groove (hDNA min)',
#   'Human immunodeficiency virus Reverse transcriptase (HIV RT)',
#   'Human papillomavirus E1 region messenger RNA (HPV E1 mRNA)',
#   'Human papillomavirus protein E7 (HPV E7)',
#   'Hyaluronic acid (HA)',
#   'Hypoxia-inducible factor 1 alpha (HIF-1A)',
#   'Hypoxia-inducible factor 2 alpha (HIF-2A)',
#   'Ig-like domain-containing receptor 2 (ILDR2)',
#   'Immune checkpoint (ICH)',
#   'Immunoglobulin gamma Fc receptor IIIA (FCGR3A)',
#   'Inactive rhomboid protein 2 (RHBDF2)',
#   'Inactive tyrosine-protein kinase 7 (PTK7)',
#   'Indoleamine 2,3-dioxygenase 1 (IDO1)',
#   'Induced myeloid leukemia cell differentiation protein Mcl-1 (MCL1)',
#   'Inducible T-cell costimulator (ICOS)',
#   'Inhibitor of apoptosis protein (hIAP)',
#   'Inhibitor of nuclear factor kappa-B kinase alpha (IKKA)',
#   'Inhibitory receptor SHPS-1 (SIRPA)',
#   "Inosine-5'-monophosphate dehydrogenase (IMPDH)",
#   "Inosine-5'-monophosphate dehydrogenase 1 (IMPDH1)",
#   'Insulin receptor substrate 2 (IRS2)',
#   'Insulin receptor substrate-1 (IRS1)',
#   'Insulin-like growth factor I receptor (IGF1R)',
#   'Insulin-like growth factor-I (IGF1)',
#   'Integrin alpha-2 (ITGA2)',
#   'Integrin alpha-2/beta-1 (ITGA2/B1)',
#   'Integrin alpha-V (ITGAV)',
#   'Integrin alpha-V/beta-3 (ITGAV/B3)',
#   'Integrin alpha-V/beta-8 (ITGAV/B8)',
#   'Integrin beta-6 (ITGB6)',
#   'Integrin-linked protein kinase 1 (ILK)',
#   'Interferon alpha (IFNA)',
#   'Interferon receptor (IFNR)',
#   'Interleukin 15 receptor alpha (IL15RA)',
#   'Interleukin 2 receptor (IL2R)',
#   'Interleukin 2 receptor alpha (IL2RA)',
#   'Interleukin 2 receptor beta (IL2RB)',
#   'Interleukin 21 receptor (IL21R)',
#   'Interleukin 23 receptor (IL23R)',
#   'Interleukin 4 receptor alpha (IL4R)',
#   'Interleukin-1 beta (IL1B)',
#   'Interleukin-1 receptor (IL1R)',
#   'Interleukin-10 (IL10)',
#   'Interleukin-12 beta (IL12B)',
#   'Interleukin-17 (IL17)',
#   'Interleukin-2 (IL2)',
#   'Interleukin-23 (IL23)',
#   'Interleukin-24 (IL24)',
#   'Interleukin-27 (IL27)',
#   'Interleukin-36 gamma (IL36G)',
#   'Interleukin-7 (IL7)',
#   'Interleukin-8 (IL8)',
#   'Interleukine 12 (IL-12)',
#   'Iron (Fe)',
#   'Isopeptidase T (USP5)',
#   'JAK-STAT signaling pathway (JAK-STAT pathway)',
#   'JNK2 messenger RNA (JNK2 mRNA)',
#   'Janus kinase 1 (JAK-1)',
#   'Janus kinase 2 (JAK-2)',
#   'Jun N terminal kinase (JNK)',
#   'KRAS G12C mutant (KRAS G12C)',
#   'KRAS messenger RNA (KRAS mRNA)',
#   'Keratinocyte growth factor (FGF7)',
#   'Kinesin-like protein KIF11 (KIF11)',
#   'Kruppel like factor 4 (KLF4)',
#   'LCK tyrosine protein kinase (LCK)',
#   'LDL receptor related protein-6 (LRP-6)',
#   'Laminin gamma-2 subunit (LAMC2)',
#   'Legumain (LGMN)',
#   'Leishmania DNA topoisomerase I (Leishm TOP1)',
#   'Leptin receptor (LEPR)',
#   'Leucine-rich repeat-containing GPCR 5 (LGR5)',
#   'Leukemia inhibitory factor (LIF)',
#   'Leukocyte antigen CD37 (CD37)',
#   'Leukocyte immunoglobulin-like receptor B2 (LILRB2)',
#   'Leukocyte surface antigen CD47 (CD47)',
#   'Leukocyte surface antigen Leu-16 (CD20)',
#   'Leukocyte-associated Ig-like receptor 1 (LAIR1)',
#   'Leutinizing-hormone-releasing hormone (GNRH1)',
#   'Long transient receptor potential channel 8 (TRPM8)',
#   'Low-density lipoprotein receptor-related protein 5 (LRP5)',
#   'Luteinizing hormone receptor (LHCGR)',
#   'Lyase unspecific (LYA)',
#   'Lymphocyte activation antigen CD30 (TNFRSF8)',
#   'Lymphocyte activation gene 3 protein (LAG3)',
#   'Lymphotoxin beta receptor (LTBR)',
#   'Lysine-specific histone demethylase 1 (LSD)',
#   'M-phase inducer phosphatase 1 (MPIP1)',
#   'M-phase inducer phosphatase 2 (MPIP2)',
#   'M-phase inducer phosphatase 3 (MPIP3)',
#   'MAP kinase signal-integrating kinase 2 (MKNK2)',
#   'MAPK signal-integrating kinase 1 (MKNK1)',
#   'MAPK-activated protein kinase 2 (MAPKAPK2)',
#   'MAPK/ERK kinase kinase (MAP3K)',
#   'MEK kinase kinase 1 (MAP4K1)',
#   'MHC class I antigen G (HLA-G)',
#   'MHC class II antigen DR (HLA-DR)',
#   'MIF messenger RNA (MIF mRNA)',
#   'Macrophage colony-stimulating factor 1 (CSF1)',
#   'Macrophage colony-stimulating factor 1 receptor (CSF1R)',
#   'Macrophage-stimulating protein receptor (RON)',
#   'Mammalian disintegrin-metalloprotease (ADAM10)',
#   'Mammalian target of rapamycin complex 1 (mTORC1)',
#   'Matrix metalloproteinase (MMP)',
#   'Matrix metalloproteinase-1 (MMP-1)',
#   'Matrix metalloproteinase-13 (MMP-13)',
#   'Matrix metalloproteinase-14 (MMP-14)',
#   'Matrix metalloproteinase-2 (MMP-2)',
#   'Matrix metalloproteinase-7 (MMP-7)',
#   'Matrix metalloproteinase-9 (MMP-9)',
#   'Mdm2 messenger RNA (MDM2 mRNA)',
#   'Melanoma-associated antigen 3 (MAGEA3)',
#   'Melanoma-associated antigen 4 (MAGEA4)',
#   'Melanoma-associated antigen 6 (MAGEA6)',
#   'Melanotransferrin (MELTF)',
#   'Membrane glycoprotein OX2 (CD200)',
#   'Mesothelin (MSLN)',
#   'Methionine aminopeptidase 2 (METAP2)',
#   'Microtubule affinity regulating kinase 3 (MARK3)',
#   'Microtubule polymerization (MicroTu poly)',
#   'Microtubule-associated protein (MAP)',
#   'Mineralocorticoid receptor  (MR)',
#   'Mitochondrial gene transcription (MGT)',
#   'Mitogen-activated protein kinase (MAPK)',
#   'Monocyte chemotactic and activating factor (CCL2)',
#   'Mortalin (HSPA9)',
#   'Mucin-1 (MUC1)',
#   'Mucosal addressin cell adhesion molecule 1 (MADCAM1)',
#   'Multidrug resistance protein (MDR)',
#   'Multidrug resistance protein 1 (ABCB1)',
#   'Multidrug resistance protein 3 (ABCB4)',
#   'Muscarinic acetylcholine receptor M1 (CHRM1)',
#   'Muscarinic acetylcholine receptor M5 (CHRM5)',
#   'Mutated oxalosuccinate decarboxylase (mIDH1)',
#   'Myc messenger RNA (MYC mRNA)',
#   'NAD-dependent deacetylase sirtuin-1 (SIRT1)',
#   'NEDD8-activating enzyme (NAE)',
#   'NKG2-A/B-activating NK receptor (NKG2A)',
#   'NT-3 growth factor receptor (TrkC)',
#   'Nectin cell adhesion molecule 4 (NECTIN4)',
#   'Neural cadherin (CDH2)',
#   'Neural cell adhesion molecule (NCAM)',
#   'Neuropilin-1 (NRP1)',
#   'Neurotrophic tyrosine kinase ROR1 (ROR1)',
#   'Nicotinamide phosphoribosyltransferase (NAMPT)',
#   'Nitric-oxide synthase inducible (NOS2)',
#   'Normal cross-reacting antigen (CD66c)',
#   'Notch-1 receptor (NOTCH1)',
#   'Notch-4 receptor (NOTCH4)',
#   'Nuclear factor NF-kappa-B (NFKB)',
#   'Nuclear receptor ROR-gamma (RORG)',
#   'Nucleolin (NCL)',
#   'Nucleophosmin (NPM1)',
#   'OX40L receptor (CD134)',
#   'Oncotrophoblast glycoprotein 5T4 (TPBG)',
#   'Opioid receptor zeta (OGFR)',
#   'Oxalosuccinate decarboxylase (IDH1)',
#   'Oxysterols receptor LXR (NR1H)',
#   'P-glycoprotein (P-GP)',
#   'P-selectin (SELP)',
#   'P2X purinoceptor 7 (P2RX7)',
#   'P53 Y220C mutant (TP53 Y220C)',
#   'PAK-4 protein kinase (PAK4)',
#   'PD-1-PD-L1 interaction (PD-1/PD-L1 PPI)',
#   'PI3-kinase alpha (PIK3CA)',
#   'PI3-kinase beta (PIK3CB)',
#   'PI3-kinase delta (PIK3CD)',
#   'PI3-kinase gamma (PIK3CG)',
#   'PLK1 messenger RNA (PLK1 mRNA)',
#   'Peroxisome proliferator-activated receptor alpha (PPARA)',
#   'Peroxisome proliferator-activated receptor gamma (PPAR-gamma)',
#   'Phosphodiesterase 1 (PDE1)',
#   'Phosphodiesterase 10A (PDE10)',
#   'Phosphoinositide dependent protein kinase-1 (PDPK1)',
#   'Phospholipase C (PLC)',
#   'Phosphoribosylaminoimidazolecarboxamide formyltransferase (ATIC)',
#   'Phosphoric monoester hydrolase (PMH)',
#   'Phosphorylated p68 RNA helicase (pDDX5)',
#   'Phosphorylated protein kinase B (pAKT)',
#   'Placenta growth factor (PlGF)',
#   'Placental cadherin (CDH3)',
#   'Plasminogen (PLG)',
#   'Platelet-activating factor receptor (PTAFR)',
#   'Platelet-derived growth factor A (PDGFA)',
#   'Platelet-derived growth factor receptor (PDGFR)',
#   'Platelet-derived growth factor receptor alpha (PDGFRA)',
#   'Platelet-derived growth factor receptor beta (PDGFRB)',
#   'Polo-like kinase 1 (PLK1)',
#   'Polo-like kinase 2 (PLK2)',
#   'Poly [ADP-ribose] polymerase (PARP)',
#   'Poly [ADP-ribose] polymerase 1 (PARP1)',
#   'Poly [ADP-ribose] polymerase 2 (PARP2)',
#   'Polyadenylate-binding protein 1 (PABPC1)',
#   'Polyamine transport (Poly trans)',
#   'Polyamine unspecific (PLA)',
#   'Polymerase unspecific (POL)',
#   'Polypeptide deformylase (PDF)',
#   'Positive transcription elongation factor b (P-TEFb)',
#   'Potassium channel unspecific (KC)',
#   'Progesterone receptor (PGR)',
#   'Programmed cell death 1 ligand 1 (PD-L1)',
#   'Programmed cell death protein 1 (PD-1)',
#   'Programmed cell death protein 2 (PD-2)',
#   'Proheparin-binding EGF-like growth factor (HBEGF)',
#   'Prolactin receptor (PRLR)',
#   'Prolyl endopeptidase FAP (FAP)',
#   'Prominin-1 (PROM1)',
#   'Prostacyclin receptor (PTGIR)',
#   'Prostaglandin D2 receptor (PTGDR)',
#   'Prostaglandin D2 receptor 2 (PTGDR2)',
#   'Prostaglandin E synthase (PTGES)',
#   'Prostaglandin E2 receptor EP1 (PTGER1)',
#   'Prostaglandin E2 receptor EP2 (PTGER2)',
#   'Prostaglandin E2 receptor EP3 (PTGER3)',
#   'Prostaglandin E2 receptor EP4 (PTGER4)',
#   'Prostaglandin F2-alpha receptor (PTGFR)',
#   'Prostaglandin G/H synthase 1 (COX-1)',
#   'Prostaglandin G/H synthase 2 (COX-2)',
#   'Prostaglandin receptor (PTGR)',
#   'Prostate stem cell antigen (PSCA)',
#   'Protease unspecific (PRO)',
#   'Proteasome (PS)',
#   'Protein arginine methyltransferase 1 (PRMT1)',
#   'Protein arginine methyltransferase 5 (PRMT5)',
#   'Protein cereblon (CRBN)',
#   'Protein kinase (PK)',
#   'Protein kinase C (PRKC)',
#   'Protein kinase C beta (PRKCB)',
#   'Protein kinase C iota (PRKCI)',
#   'Protein kinase C zeta (PRKCZ)',
#   'Protein kinase D (PRKD1)',
#   'Protein kinase N3 (PKN3)',
#   'Protein mono-ADP-ribosyltransferase TIPARP (TIPARP)',
#   'Protein prenyl transferase (PPTF)',
#   'Protein synthesis (hPRO synth)',
#   'Protein-serine O-palmitoleoyltransferase porcupine (PORCN)',
#   'Protein-tyrosine phosphatase SHP-2 (PTPN11)',
#   'Proteinase activated receptor 2 (PAR2)',
#   'Proto-oncogene c-Met (MET)',
#   'Proto-oncogene c-RAF (c-RAF)',
#   'Proto-oncogene c-Ret (RET)',
#   'Proto-oncogene c-Ros (ROS1)',
#   'Proto-oncogene c-Src (SRC)',
#   'Proton-coupled folate transporter (SLC46A1)',
#   'Pyruvate dehydrogenase kinase 1 (PDHK1)',
#   'Pyruvate kinase M2 (PKM)',
#   'Quinone reductase 1 (NQO1)',
#   'Quinone reductase 2 (NQO2)',
#   'R-spondin-3 (RSPO3)',
#   'RAC serine/threonine-protein kinase (AKT)',
#   'RAC-alpha serine/threonine-protein kinase (AKT1)',
#   'RAC-gamma serine/threonine-protein kinase (AKT3)',
#   'RAS-like protein KIR (GEM)',
#   'RNA synthesis (hRNA synth)',
#   'RRM1 messenger RNA (RRM1 mRNA)',
#   'Raf messenger RNA (Raf mRNA)',
#   'Receptor unspecific (Rec)',
#   'Renal carcinoma antigen NY-REN-56 (PFKFB3)',
#   'Retinoic acid receptor (RAR)',
#   'Retinoic acid receptor RXR (RXR)',
#   'Retinoic acid receptor RXR-gamma (RXRG)',
#   'Retinoic acid receptor alpha (RARA)',
#   'Retinoic acid-inducible gene-1 (RIG-1)',
#   'Rho-associated protein kinase (ROCK)',
#   'Rho-associated protein kinase 1 (ROCK1)',
#   'Rho-associated protein kinase 2 (ROCK2)',
#   'Rhodopsin (RHO)',
#   'Ribonuclease (RNase)',
#   'Ribonucleoside-diphosphate reductase M2 (RRM2)',
#   'Ribonucleotide reductase (RIR)',
#   'Ribosomal protein S6 kinase (S6K)',
#   'Ribosomal protein S6 kinase beta-1 (S6K1)',
#   'Ribosome (hRBS)',
#   'S-adenosylmethionine decarboxylase proenzyme (AMD1)',
#   'S-adenosylmethionine synthase type-2 (MAT2A)',
#   'SET and MYND domain-containing protein 2 (SMYD2)',
#   'SET domain containing 8 (KMT5A)',
#   'SLAM family member 7 SLAMF7 (CS1)',
#   'STAT3 messenger RNA (STAT3 mRNA)',
#   'STMN1 messenger RNA (STMN1 mRNA)',
#   'SYK messenger RNA (SYK mRNA)',
#   'Serine protease unspecific (SP)',
#   'Serine/threonine PP2A (PP2A)',
#   'Serine/threonine PP2A-alpha (PPP2CA)',
#   'Serine/threonine-protein kinase (STK)',
#   'Serine/threonine-protein kinase ATR (FRP1)',
#   'Serine/threonine-protein kinase B-raf (BRAF)',
#   'Serine/threonine-protein kinase Chk2 (RAD53)',
#   'Serine/threonine-protein kinase Raf (RAF)',
#   'Serine/threonine-protein kinase mTOR (mTOR)',
#   'Serine/threonine-protein kinase pim (PIM)',
#   'Serine/threonine-protein kinase pim-1 (PIM1)',
#   'Serine/threonine-protein kinase pim-2 (PIM2)',
#   'Serotonin transporter (SERT)',
#   'Signal transducer and activator of transcription 3 (STAT3)',
#   'Signal transduction unspecific (ST)',
#   'Smoothened homolog (SMO)',
#   'Sodium pump subunit alpha-1 (ATP1A1)',
#   'Sodium/potassium-transporting ATPase (SPT ATPase)',
#   'Soluble guanylate cyclase (GCS)',
#   'Solute carrier family 19 member 1 (SLC19A1)',
#   'Spectrin non-erythroid beta chain 1 (SPTBN1)',
#   'Sphingosine kinase 2 (SPHK2)',
#   'Sphingosine-1-phosphate receptor 1 (S1PR1)',
#   'Steroid hormone receptor ERR (ESRR)',
#   'Stimulator of interferon genes protein (TMEM173)',
#   'Stress-activated protein kinase (p38)',
#   'Stress-activated protein kinase 2a (p38 alpha)',
#   'Stress-activated protein kinase JNK1 (JNK1)',
#   'Substance-P receptor (TACR1)',
#   'Superoxide dismutase Cu-Zn (SOD Cu-Zn)',
#   'T-box transcription factor T (TBXT)',
#   'T-cell activation antigen CD27 (CD27)',
#   'T-cell surface glycoprotein CD3 (CD3)',
#   'T-cell surface glycoprotein CD3 epsilon (CD3E)',
#   'T-cell surface glycoprotein CD3 gamma (CD3G)',
#   'T-cell surface glycoprotein CD4 (CD4)',
#   'T-cell surface glycoprotein CD8 (CD8)',
#   'T-cell surface protein tactile (CD96)',
#   'T-cell-specific surface glycoprotein CD28 (CD28)',
#   'T-cells (T-cells)',
#   'TAX transcriptionally-activated glycoprotein 1 (OX40)',
#   'TERT messenger RNA (TERT mRNA)',
#   'TGF-beta receptor type I (TGFBR1)',
#   'TGF-beta receptor type II (TGFBR2)',
#   'TNF related activation protein (CD40LG)',
#   'TNF related apoptosis inducing ligand (TNFSF10)',
#   'TNF superfamily receptor 12A (TNFRSF12A)',
#   'TNF-related weak inducer of apoptosis (TWEAK)',
#   'TRAIL receptor 1 (TRAIL-R1)',
#   'TRAIL receptor 2 (TRAIL-R2)',
#   'TYRO3 tyrosine kinase receptor (TYRO3)',
#   'Tankyrase (TNKS)',
#   'Target of rapamycin complex 2 MAPKAP1 (MTORC2)',
#   'Telomerase reverse transcriptase (TERT)',
#   'Tenascin (TNC)',
#   'Teratocarcinoma-derived growth factor 1 (TDGF1)',
#   'Thioredoxin (TXN)',
#   'Thrombospondin-1 (THBS1)',
#   'Thromboxane A2 receptor (TBXA2R)',
#   'Thymidine kinase 1 (TK1)',
#   'Thymidylate synthase (TYMS)',
#   'Thymidylate synthase messenger RNA (TYMS mRNA)',
#   'Thyroid hormone receptor (THR)',
#   'Tissue factor (F3)',
#   'Toll-like receptor (TLR)',
#   'Toll-like receptor 2 (TLR2)',
#   'Toll-like receptor 3 (TLR3)',
#   'Toll-like receptor 4 (TLR4)',
#   'Toll-like receptor 5 (TLR5)',
#   'Toll-like receptor 7 (TLR7)',
#   'Toll-like receptor 8 (TLR8)',
#   'Toll-like receptor 9 (TLR9)',
#   'Transcription factor Sp1 (SP1)',
#   'Transferase unspecific (TF)',
#   'Transferrin (TF)',
#   'Transforming growth factor beta (TGFB)',
#   'Transforming growth factor beta 1 (TGFB1)',
#   'Transforming growth factor beta activator LRRC32 (LRRC32)',
#   'Transforming protein RhoA (RHOA)',
#   'Transient receptor potential cation channel V6 (TRPV6)',
#   'Translocator protein (TSPO)',
#   'Transmembrane protein PVRIG (PVRIG)',
#   'Tropomyosin-related kinase A (TrkA)',
#   'Tryptase alpha/beta-1 (Tryptase)',
#   'Tryptophan 2,3-dioxygenase (TDO)',
#   'Tubulin (TUB)',
#   'Tubulin beta (TUBB)',
#   'Tubulin beta-1 chain (TUBB1)',
#   'Tubulin beta-2 chain (TUBB2)',
#   'Tumor associated calcium signal transducer 2 (TACSTD2)',
#   'Tumor expressed melanoma antigen (PRAME)',
#   'Tumor necrosis factor (TNF)',
#   'Tumor necrosis factor receptor member 25 (TNFRSF25)',
#   'Tumor-associated calcium signal transducer 1 (EPCAM)',
#   'Tumor-associated glycan antigen (TAGA)',
#   'Tyrosine-protein kinase ABL1 (ABL)',
#   'Tyrosine-protein kinase BTK (ATK)',
#   'Tyrosine-protein kinase Kit (KIT)',
#   'Tyrosine-protein kinase Lyn (JTK8)',
#   'Tyrosine-protein kinase Mer (MERTK)',
#   'Tyrosine-protein kinase SYK (SYK)',
#   'Tyrosine-protein kinase UFO (AXL)',
#   'Tyrosine-protein phosphatase non-receptor type 2 (PTPN2)',
#   'Ubiquitin carboxyl-terminal hydrolase 14 (USP14)',
#   'Ubiquitin carboxyl-terminal hydrolase 20 (USP20)',
#   'Ubiquitin isopeptidase Y (USP8)',
#   'Ubiquitin thioesterase L1 (UCHL1)',
#   'Ubiquitin-activating enzyme (UBA)',
#   'Ubiquitin-like protein Nedd8 (NEDD8)',
#   'Ubiquitin-protein ligase E3 Mdm2 (MDM2)',
#   'Urokinase-type plasminogen activator (PLAU)',
#   'V-erbA-related protein 1 (NR1D1)',
#   'V-set and immunoglobulin domain-containing protein 9 (TIGIT)',
#   'V-set immunoregulatory receptor (VSIR)',
#   'VEGFR1 messenger RNA (VEGFR1 mRNA)',
#   'Vacuolar-type proton ATPase (v-ATPase)',
#   'Valosin-containing protein p97 (VCP)',
#   'Vascular endothelial growth factor (VEGF)',
#   'Vascular endothelial growth factor A (VEGFA)',
#   'Vascular endothelial growth factor C (VEGFC)',
#   'Vascular endothelial growth factor receptor (VEGFR)',
#   'Vascular endothelial growth factor receptor 1 (FLT-1)',
#   'Vascular endothelial growth factor receptor 2 (KDR)',
#   'Vascular endothelial growth factor receptor 3 (FLT-4)',
#   'Vitamin D3 receptor (VDR)',
#   'Voltage-dependent anion-selective channel 3 (VDAC3)',
#   'Voltage-gated calcium channel alpha Cav3.1 (CACNA1G)',
#   'Voltage-gated calcium channel alpha Cav3.2 (CACNA1H)',
#   'Voltage-gated sodium channel alpha Nav1.5 (SCN5A)',
#   'Wee1-like protein kinase (WEE1)',
#   'Wnt signaling pathway (Wnt pathway)',
#   'X-linked inhibitor of apoptosis protein (XIAP)',
#   'XIAP messenger RNA (XIAP mRNA)',
#   'Xanthine dehydrogenase/oxidase (XDH)',
#   'Yes tyrosine kinase (YES)',
#   'Zinc finger protein Helios (IKZF2)',
#   'dUTP pyrophosphatase (DUT)',
#   'eIF4E-BP2 messenger RNA (eIF4E-BP2 mRNA)',
#   'p53-binding protein Mdm4 (MDM4)',
#   'von Willebrand factor (VWF)'},
#  'Cardiovascular disease  ICD11  BA00BE2Z ': {'5-HT 2A receptor (HTR2A)',
#   'ATP-citrate synthase (ACLY)',
#   'Adenosine A1 receptor (ADORA1)',
#   'Adrenergic receptor (ADR)',
#   'Adrenergic receptor Alpha-1 (ADRA1)',
#   'Adrenergic receptor beta-2 (ADRB2)',
#   'Androgen receptor (AR)',
#   'Angiopoietin-related protein 3 (ANGPTL3)',
#   'Angiotensin-converting enzyme (ACE)',
#   'Angiotensinogenase renin (REN)',
#   'Apolipoprotein A-I (APOA1)',
#   'Arachidonate 5-lipoxygenase (5-LOX)',
#   'Arachidonate 5-lipoxygenase activating protein (FLAP)',
#   'Asialoglycoprotein receptor 1 (ASGR1)',
#   'Beta-secretase (BACE)',
#   'CRP messenger RNA (CRP mRNA)',
#   'Calcium channel unspecific (CaC)',
#   'Caspase (CASP)',
#   'Cathepsin S (CTSS)',
#   'Cholesterol synthesis (Chole synth)',
#   'Cholesteryl ester transfer protein (CETP)',
#   'Chymase (CYM)',
#   'Coagulation factor IIa (F2)',
#   'Complement C5 (CO5)',
#   'Diacylglycerol O-acyltransferase 2 (DGAT2)',
#   'Dopamine D2 receptor (D2R)',
#   'Endothelin A receptor (EDNRA)',
#   'Endothelin B receptor (EDNRB)',
#   'Endothelin-converting enzyme (ECE)',
#   'Fatty acid-binding protein 1 (FABP1)',
#   'Fibrin (FG)',
#   'Gastric H(+)/K(+) ATPase alpha (ATP4A)',
#   'Glucagon-like peptide 1 receptor (GLP1R)',
#   'Glucose-6-phosphate dehydrogenase (G6PD)',
#   'Glycoprotein IIb/IIIa receptor (GPIIb/IIIa)',
#   'Granulocyte colony-stimulating factor receptor (G-CSF-R)',
#   'HMG-CoA reductase (HMGCR)',
#   'Hemoglobin (HB)',
#   'Hormone unspecific (HOM)',
#   'Hydroxycarboxylic acid receptor 3 (HCAR3)',
#   'ITGB3 messenger RNA (ITGB3 mRNA)',
#   'Interleukin-1 beta (IL1B)',
#   'Intestinal maltase-glucoamylase (MGAM)',
#   'Iron (Fe)',
#   'LCK tyrosine protein kinase (LCK)',
#   'Leukotriene receptor (LTR)',
#   'MAP kinase p38 (MAPK12)',
#   'Mineralocorticoid receptor  (MR)',
#   'Mitochondrial aldehyde dehydrogenase (ALDH2)',
#   'Muscarinic acetylcholine receptor M2 (CHRM2)',
#   'Neuropeptide Y receptor type 1 (NPY1R)',
#   'Neutral endopeptidase (MME)',
#   'Nicotinic acid receptor (HCAR2)',
#   'Nitric-oxide synthase inducible (NOS2)',
#   'Oxysterols receptor LXR (NR1H)',
#   'P2Y purinoceptor 12 (P2RY12)',
#   'PCSK9 messenger RNA (PCSK9 mRNA)',
#   'PI3-kinase gamma (PIK3CG)',
#   'Peroxisome proliferator-activated receptor alpha (PPARA)',
#   'Phosphodiesterase (PDE)',
#   'Phosphodiesterase 3 (PDE3)',
#   'Phosphodiesterase 3A (PDE3A)',
#   'Phosphodiesterase 5A (PDE5A)',
#   'Phospholipase A2 (PLA2G1B)',
#   'Platelet-activating factor acetylhydrolase (PLA2G7)',
#   'Proprotein convertase subtilisin/kexin type 9 (PCSK9)',
#   'Prostaglandin G/H synthase (COX)',
#   'Proto-oncogene c-Met (MET)',
#   'Proto-oncogene c-Src (SRC)',
#   'RAC-alpha serine/threonine-protein kinase (AKT1)',
#   'RIP2 messenger RNA (RIP2 mRNA)',
#   'Sodium channel unspecific (NaC)',
#   'Sodium pump (NaP)',
#   'Sodium/calcium exchanger (SLC)',
#   'Sodium/glucose cotransporter 1 (SGLT1)',
#   'Sodium/glucose cotransporter 2 (SGLT2)',
#   'Sodium/potassium-transporting ATPase (SPT ATPase)',
#   'Sphingosine-1-phosphate receptor 1 (S1PR1)',
#   'Thromboxane A2 receptor (TBXA2R)',
#   'Thymidine kinase 1 (TK1)',
#   'Tyrosine-protein kinase ABL1 (ABL)',
#   'Tyrosine-protein kinase BRK (PTK6)',
#   'Vascular endothelial growth factor receptor 2 (KDR)',
#   'Vasopressin V1 receptor (V1R)',
#   'Vasopressin V1a receptor (V1AR)',
#   'Vitamin K-dependent protein C (PROC)',
#   'Voltage-gated L-type calcium channel (L-CaC)',
#   'Voltage-gated calcium channel alpha-2/delta-1 (CACNA2D1)'},
#  'Lung cancer  ICD11  2C25 ': {'ALK tyrosine kinase receptor (ALK)',
#   'ATM serine/threonine kinase (ATM)',
#   'Activation B7-1 antigen (CD80)',
#   'Adenosine A2a receptor (ADORA2A)',
#   'Adenosine A2b receptor (ADORA2B)',
#   'Apoptosis inhibitor survivin (BIRC5)',
#   'Apoptosis regulator Bcl-2 (BCL-2)',
#   'Apoptosis regulator Bcl-xL (BCL-xL)',
#   'Arachidonate 5-lipoxygenase (5-LOX)',
#   'Aurora kinase (AURK)',
#   'Aurora kinase A (AURKA)',
#   'BCL-2 messenger RNA (BCL2 mRNA)',
#   'CAAX farnesyltransferase beta (FNTB)',
#   'Cancer/testis antigen 1 (NY-ESO-1)',
#   'Cancer/testis antigen MAGE-C1/CT7 (MAGEC1)',
#   'Carcinoembryonic antigen CEA (CD66e)',
#   'Checkpoint kinase-1 (CHK1)',
#   'Clusterin messenger RNA (Clusterin mRNA)',
#   'Complement decay-accelerating factor (CD55)',
#   'Complement factor H (CFH)',
#   'Cyclin-dependent kinase (CDK)',
#   'Cyclin-dependent kinase 1 (CDK1)',
#   'Cyclin-dependent kinase 2 (CDK2)',
#   'Cyclin-dependent kinase 4 (CDK4)',
#   'Cyclin-dependent kinase 6 (CDK6)',
#   'Cyclin-dependent kinase 7 (CDK7)',
#   'Cyclin-dependent kinase 9 (CDK9)',
#   'Cytotoxic T-lymphocyte protein 4 (CTLA-4)',
#   'DNA [cytosine-5]-methyltransferase 1 (DNMT1)',
#   'DNA topoisomerase (TOP)',
#   'DNA topoisomerase I (TOP1)',
#   'DNA topoisomerase II (TOP2)',
#   'Delta-like protein 3 (DLL3)',
#   'Dipeptidyl peptidase 4 (DPP-4)',
#   'Dopamine D2 receptor (D2R)',
#   'Dual specificity protein phosphatase 1 (DUSP1)',
#   'EGFR messenger RNA (EGFR mRNA)',
#   'ERK activator kinase 1 (MEK1)',
#   'ERK activator kinase 2 (MEK2)',
#   'Endoglin CD105 (ENG)',
#   'Endoplasmin (HSP90B1)',
#   'Enhancer of zeste homolog 1 (EZH1)',
#   'Enhancer of zeste homolog 2 (EZH2)',
#   'Ephrin type-B receptor 4 (EPHB4)',
#   'Epidermal growth factor receptor (EGFR)',
#   'Epidermal growth factor receptor variant III (EGFR vIII)',
#   'Epidermal growth factor-like protein 7 (EGFL7)',
#   'Erbb2 tyrosine kinase receptor (HER2)',
#   'Erbb3 tyrosine kinase receptor (Erbb-3)',
#   'Erbb4 tyrosine kinase receptor (Erbb-4)',
#   'Farnesyl protein transferase (Ftase)',
#   'Fibroblast growth factor receptor 1 (FGFR1)',
#   'Fms-like tyrosine kinase 3 (FLT-3)',
#   'Folate receptor alpha (FOLR1)',
#   'Free radical (FRD)',
#   'Fucosyl GM1 (FucGM1)',
#   'Fusion protein Bcr-Abl (Bcr-Abl)',
#   'GSTP1 messenger RNA (GSTP1 mRNA)',
#   'GTPase NRas (NRAS)',
#   'Ganglioside GD2 (GD2)',
#   'Glypican-3 (GPC3)',
#   'Guanine nucleotide exchange factor (GNEF)',
#   'HGF/Met signaling pathway (HGF/Met pathway)',
#   'HSPB1 messenger RNA (HSPB1 mRNA)',
#   'Heat shock protein 27 (HSP27)',
#   'Heat shock protein 90 alpha (HSP90A)',
#   'Heat shock protein 90 beta (HSP90B)',
#   'Hemoglobin (HB)',
#   'Hepatocyte growth factor (HGF)',
#   'Histone deacetylase (HDAC)',
#   'Histone deacetylase 1 (HDAC1)',
#   'Human Deoxyribonucleic acid (hDNA)',
#   'Human Deoxyribonucleic acid minor groove (hDNA min)',
#   'Hyaluronidase (HYAL)',
#   'Indoleamine 2,3-dioxygenase 1 (IDO1)',
#   'Insulin-like growth factor I receptor (IGF1R)',
#   'Integrin alpha-5/beta-1 (ITGA5/B1)',
#   'Integrin beta-1 (ITGB1)',
#   'Interleukin 1 receptor accessory protein (IL1RAP)',
#   'Interleukin 15 receptor alpha (IL15RA)',
#   'Interleukin 2 receptor (IL2R)',
#   'Interleukin-1 alpha (IL1A)',
#   'Interleukin-10 (IL10)',
#   'Interleukin-2 (IL2)',
#   'Janus kinase 1 (JAK-1)',
#   'Janus kinase 2 (JAK-2)',
#   'KRAS G12C mutant (KRAS G12C)',
#   'Lactotransferrin (LTF)',
#   'Low-density lipoprotein receptor (LDL-R)',
#   'Lymphocyte activation gene 3 protein (LAG3)',
#   'Lysine-specific histone demethylase 1 (LSD)',
#   'M-phase inducer phosphatase 2 (MPIP2)',
#   'MAPK/ERK kinase kinase (MAP3K)',
#   'Matrix metalloproteinase-1 (MMP-1)',
#   'Matrix metalloproteinase-12 (MMP-12)',
#   'Matrix metalloproteinase-2 (MMP-2)',
#   'Matrix metalloproteinase-7 (MMP-7)',
#   'Matrix metalloproteinase-9 (MMP-9)',
#   'Mcl-1 messenger RNA (MCL-1 mRNA)',
#   'Melanoma-associated antigen 1 (MAGEA1)',
#   'Melanoma-associated antigen 3 (MAGEA3)',
#   'Melanoma-associated antigen 4 (MAGEA4)',
# ...
#   'Solute carrier family 12 member 1 (SLC12A1)',
#   'Solute carrier family 12 member 3 (SLC12A3)'},
#  'Endocarditis  ICD11  BB40BA42 ': {'Candida Thymidylate synthase (Candi TMP1)',
#   'DNA topoisomerase II (TOP2)'},
#  'CNS anomalies syndrome  ICD11  LD20 ': {'Quinone reductase 1 (NQO1)'},
#  'Sleeprelated breathing disorder  ICD11  7A4Z ': {'Adrenergic receptor beta-2 (ADRB2)'},
#  'Infants  toddlers  children functional digestive disorder  ICD11  DD93 ': {'Substance-K receptor (TACR2)'},
#  'Postoperative ileus  ICD11  DA91DB30 ': {'Growth hormone secretagogue receptor 1 (GHSR)',
#   'Substance-K receptor (TACR2)'},
#  'Stress  ICD11  6B406B45 ': {'Nociceptin receptor (OPRL1)'},
#  'Endocrine gland neoplasm  ICD11  2F37 ': {'Dopamine D2 receptor (D2R)',
#   'Somatostatin receptor type 2 (SSTR2)'},
#  'Blood  bloodforming organ sympton  ICD11  MA14 ': {'Angiopoietin-related protein 3 (ANGPTL3)',
#   'HMG-CoA reductase (HMGCR)'},
#  'Vaginal discharge  ICD11  MF3A ': {'Bacterial 50S ribosomal RNA (Bact 50S rRNA)'},
#  'Syphilis  ICD11  1A611A6Z ': {'Bacterial 50S ribosomal RNA (Bact 50S rRNA)',
#   'DNA topoisomerase II (TOP2)'},
#  'Trypanosomiasis  ICD11  1D511F53 ': {'Cysteine protease (CYP)',
#   'Ornithine decarboxylase (ODC1)',
#   'Plasmodium Enoyl-ACP reductase (Malaria fabI)'},
#  'Dysplasia  ICD11  LB30LD2F ': {'Human papillomavirus protein E6 (HPV E6)',
#   'Human papillomavirus protein E7 (HPV E7)'},
#  'Genital organ in situ carcinoma  ICD11  2E67 ': {'Human papillomavirus protein E6 (HPV E6)',
#   'Human papillomavirus protein E7 (HPV E7)'},
#  'Cervical intraepithelial neoplasia  ICD11  2E66 ': {'Human papillomavirus protein E6 (HPV E6)',
#   'Human papillomavirus protein E7 (HPV E7)',
#   'Mycobacterium Heat shock protein 65 (MycB groL2)'},
#  'Retinal detachment  ICD11  9B73 ': {'Retinoschisin (RS1)'},
#  'Joint lubricant  ICD11  FA30FA38 ': {'Hyaluronic acid receptor (LYVE1)'},
#  'Enthesopathy  ICD11  FB53FB55 ': {'Hyaluronic acid receptor (LYVE1)'},
#  'Monitored anaesthesia care  ICD11  NA  ': {'Glutamate receptor AMPA (GRIA)'},
#  'Appearance  behaviour symptom  ICD11  MB23 ': {'Glutamate receptor AMPA (GRIA)',
#   'Muscarinic acetylcholine receptor M5 (CHRM5)'},
#  'Pervasive developmental disorder  ICD11  6A006A0Z ': {'Glutamate receptor AMPA (GRIA)'},
#  'Burn and burn infection  ICD11  ND90NE2Z ': {'Bacterial Cell membrane (Bact CM)',
#   'Ornithine decarboxylase (ODC1)',
#   'S-adenosylmethionine decarboxylase proenzyme (AMD1)'},
#  'Precursor Blymphoblastic neoplasm  ICD11  2A70 ': {'B-lymphocyte surface antigen B4 (CD19)'},
#  'Neuromyelitis optica  ICD11  8A43 ': {'B-lymphocyte surface antigen B4 (CD19)',
#   'Complement C1s component (C1S)',
#   'Endothelin B receptor (EDNRB)',
#   'HUMAN complement C5 protein (C5)',
#   'Interleukin 6 receptor (IL6R)'},
#  'Nervous system paraneoplastic  autoimmune disorder  ICD11  8E4A ': {'Activin receptor type IIB (ACVR2B)',
#   'B-lymphocyte surface antigen B4 (CD19)',
#   'Receptor-interacting protein 1 (RIPK1)'},
#  'Lipidaemia  ICD11  5C8Z ': {'Apolipoprotein A-I (APOA1)'},
#  'Aortic valve stenosis  ICD11  BB70 ': {'Apolipoprotein A-I (APOA1)'},
#  'Dermatophytosis  ICD11  1F28 ': {'Candida Cytochrome P450 51 (Candi ERG11)',
#   'Candida Squalene epoxidase (Candi ERG1)',
#   'Fungal Cell membrane (Fung CM)',
#   'Fungal Microtubule (Fung MicroTU)',
#   'Guanylate cyclase (GC)',
#   'Soluble guanylate cyclase (GCS)',
#   'Squalene monooxygenase (SQLE)'},
#  'Respiratory failure  ICD11  CB41 ': {'Guanylate cyclase (GC)',
#   'Soluble guanylate cyclase (GCS)'},
#  'Periodontal disease  ICD11  DA0C ': {'Bacterial 30S ribosomal RNA (Bact 30S rRNA)',
#   'Beta-glucuronidase (GUSB)',
#   'Fibroblast growth factor receptor 2 (FGFR2)',
#   'Growth/differentiation factor 5 (GDF-5)'},
#  'Urethral cancer  ICD11  2C93 ': {'Epidermal growth factor receptor (EGFR)'},
#  'Cryptosporidiosis  ICD11  1A32 ': {'Epidermal growth factor receptor (EGFR)'},
#  'Small intestine motility disorder  ICD11  DA93 ': {'Growth hormone secretagogue receptor 1 (GHSR)'},
#  'Anorexia nervosa  ICD11  6B80 ': {'Cannabinoid receptor 1 (CB1)',
#   'Growth hormone secretagogue receptor 1 (GHSR)',
#   'Melanocortin receptor 4 (MC4R)'},
#  'Old age  ICD11  MG2A ': {'Growth hormone secretagogue receptor 1 (GHSR)'},
#  'Penile cancer  ICD11  2C81 ': {'Programmed cell death protein 1 (PD-1)'},
#  'Uterine ligament  parametrium  uterine adnexa neoplasm  ICD11  2C72 ': {'Programmed cell death protein 1 (PD-1)',
#   'Wee1-like protein kinase (WEE1)'},
#  'Childbirth associated breast  lactation disorder  ICD11  JB46 ': {'Oxytocin receptor (OTR)',
#   'Vasopressin V1a receptor (V1AR)',
#   'Vasopressin V1b receptor (V1BR)',
#   'Vasopressin V2 receptor (V2R)'},
#  'Joint derangement  ICD11  FA34 ': {'Bone morphogenetic protein receptor (BMPR2)'},
#  'Urinary  pelvic organs injury  ICD11  NB92 ': {'Bone morphogenetic protein receptor (BMPR2)'},
#  'Fever  ICD11  MG26 ': {'Prostaglandin G/H synthase 1 (COX-1)',
#   'Prostaglandin G/H synthase 2 (COX-2)',
#   'Ryanodine receptor (RYR)'},
#  'Shoulder lesion  ICD11  FB53 ': {'Beta-secretase (BACE)',
#   'Gamma-secretase (GS)',
#   'Presenilin 1 (PSEN1)',
#   'Presenilin 2 (PSEN2)',
#   'Prostaglandin G/H synthase 1 (COX-1)',
#   'Prostaglandin G/H synthase 2 (COX-2)'},
#  'Hypothyroidism  ICD11  5A00 ': {'Thyroid hormone receptor alpha (THRA)',
#   'Thyroid hormone receptor beta (THRB)',
#   'Thyrotropin receptor (TSHR)'},
#  'Osteopathy  chondropathy  ICD11  FB8Y ': {'Sclerostin (SOST)'},
#  'Whooping cough  ICD11  1C12 ': {'Cell mediated immunity response (CMIR)'},
#  'Acute viral hepatitis  ICD11  1E50 ': {'Cell mediated immunity response (CMIR)'},
#  'Meningioma  ICD11  2A01 ': {'Cathepsin B (CTSB)'},
#  'Gingival  edentulous alveolar ridge disorder  ICD11  DA0D ': {'Bacterial 30S ribosomal RNA (Bact 30S rRNA)'},
#  'Acquired methaemoglobinaemia  ICD11  3A93 ': {'Guanylate cyclase (GC)',
#   'Monoamine oxidase (MAO)'},
#  'Neurotransmitter metabolic error  ICD11  5C59 ': {'Aromatic-L-amino-acid decarboxylase (DDC)'},
#  'Anal cancer  ICD11  2C00 ': {'Checkpoint kinase-1 (CHK1)'},
#  'Delayed methotrexate clearance  ICD11  NA  ': {'Toxic methotrexate (TM)'},
#  'Preprocedural examination  ICD11  QA0B ': {'Serum albumin (ALB)'},
#  'CNS nonviral infection  ICD11  1D0Y ': {'P2X purinoceptor 7 (P2RX7)'},
#  'Heart beat abnormality  ICD11  MC81 ': {'Tyrosine-protein kinase ABL1 (ABL)'},
#  'Osteosarcoma  ICD11  2B51 ': {'Ganglioside GD2 (GD2)',
#   'Glycogen synthase kinase-3 beta (GSK-3B)',
#   'Human Deoxyribonucleic acid (hDNA)',
#   'Proto-oncogene c-Src (SRC)',
#   'T-cell-specific surface glycoprotein CD28 (CD28)',
#   'Tyrosine-protein kinase ABL1 (ABL)'},
#  'Ascariasis  ICD11  1F62 ': {'Gamma-aminobutyric acid receptor (GAR)'},
#  'Enterobiasis  ICD11  1F65 ': {'Gamma-aminobutyric acid receptor (GAR)'},
#  'Eexposure to noxious substances harmful effect  ICD11  NE61 ': {'Alcohol dehydrogenase 1A (ADH1A)',
#   'Cholinesterase (BCHE)',
#   'Histamine H3 receptor (H3R)'},
#  'Vaginitis  ICD11  GA02 ': {'Actin (ACT)', 'Estrogen receptor (ESR)'},
#  'Adenocarcinoma  ICD11  2D40 ': {'Claudin-18 (CLDN18)',
#   'Glutamate carboxypeptidase II (GCPII)'},
#  'Schistosomiasis  ICD11  1F86 ': {'Schistosoma Deoxyribonucleic acid (Schist DNA)'},
#  'Enuresis  ICD11  6C00 ': {'Vasopressin V2 receptor (V2R)'},
#  'Polyuria  ICD11  MF55 ': {'Muscarinic acetylcholine receptor M5 (CHRM5)',
#   'Vasopressin V2 receptor (V2R)'},
#  'Knee osteoarthritis  ICD11  FA01 ': {'Prostaglandin G/H synthase 2 (COX-2)',
#   'Transient receptor potential cation channel V1 (TRPV1)'},
#  'Large intestine polyp  ICD11  DB35 ': {'Prostaglandin G/H synthase 2 (COX-2)'},
#  'Hyperaemia  ICD11  9A619B7Y ': {'Dopamine D2 receptor (D2R)'},
#  'Faecal incontinence  ICD11  ME07 ': {'Dopamine D2 receptor (D2R)'},
#  'Gangrene  ICD11  MC85 ': {'Dopamine D2 receptor (D2R)'},
#  'Overgrowth syndrome  ICD11  LD2C ': {'RAC-alpha serine/threonine-protein kinase (AKT1)',
#   'RAC-gamma serine/threonine-protein kinase (AKT3)'},
#  'LambertEaton syndrome  ICD11  8C62 ': {'Potassium channel unspecific (KC)'},
#  'Deep vein thrombosis  ICD11  BD71 ': {'Antithrombin-III (ATIII)',
#   'Cell adhesion molecule (CADM)',
#   'Coagulation factor Xa (F10)'},
#  'Myotonic disorder  ICD11  8C71 ': {'DMPK messenger RNA (DMPK mRNA)',
#   'Glycogen synthase kinase-3 beta (GSK-3B)'},
#  'Chondrosarcoma  ICD11  2B50 ': {'Hedgehog signaling pathway (HS pathway)'},
#  'Nervous system disease  ICD11  8A008E7Z ': {'N-methyl-D-aspartate receptor (NMDAR)',
#   'Nuclear factor NF-kappa-B (NFKB)'},
#  'Thought content symptom  ICD11  MB26 ': {'N-methyl-D-aspartate receptor (NMDAR)'},
#  'Dizziness and giddiness  ICD11  MB48 ': {'Orphan nuclear receptor NR1I3 (NR1I3)'},
#  'Lipoatrophy  lipodystrophy  ICD11  EF01 ': {'Growth hormone-releasing hormone receptor (GHRHR)'},
#  'Hypertensive crisis  ICD11  BA03 ': {'Neuronal acetylcholine receptor alpha-4 (CHRNA4)'},
#  'Eyelid inflammatory  movement disorder  ICD11  9A05 ': {'Synaptosomal-associated protein 25 (SNAP25)'},
#  'Anal fissure  fistula  ICD11  DB50 ': {'Guanylate cyclase (GC)'},
#  'Acute  subacute hepatic failure  ICD11  DB91 ': {'Bacterial 16S ribosomal RNA (Bact 16S rRNA)',
#   'Cardiotrophin-1 (CTF1)',
#   'Nuclear factor NF-kappa-B (NFKB)',
#   'Staphylococcus 30S ribosomal subunit (Stap-coc pbp2)',
#   'Tumor necrosis factor receptor type I (TNF-R1)'},
#  'Gramnegative bacterial infection  ICD11  1F411G40 ': {'Bacterial 16S ribosomal RNA (Bact 16S rRNA)',
#   'Pseudomonas UDP-3-O-acyl-GlcNAc deacetylase (Pseudo lpxC)'},
#  'Pituitary hypofunction  ICD11  5A61 ': {'Melanocortin receptor 4 (MC4R)'},
#  'Infancy  childhood primary interstitial lung disease  ICD11  CB04 ': {'GMCSFR-alpha (CSF2RA)'},
#  'Aspergillosis  ICD11  1F20 ': {'Candida Cytochrome P450 51 (Candi ERG11)',
#   'Fungal 1,3-beta-glucan synthase (Fung GSC2)'},
#  'Coronary thrombosis  ICD11  BA43 ': {'Antithrombin-III (ATIII)',
#   'Coagulation factor IIa (F2)',
#   'Coagulation factor Xa (F10)'},
#  'Tinnitus  ICD11  MC41 ': {'Antithrombin-III (ATIII)'},
#  'kidney  ureter disorder  ICD11  GB90 ': {'Antithrombin-III (ATIII)'},
#  'Nondermatophyte superficial dermatomycose  ICD11  1F2D ': {'Candida Cytochrome P450 51 (Candi ERG11)'},
#  'Abnormal urine serum electrolytes level  ICD11  MF98 ': {'Calcium (Ca)'},
#  'Lymphangioleiomyomatosis  ICD11  CB07 ': {'HUMAN mammalian target of rapamycin (mTOR)',
#   'Serine/threonine-protein kinase mTOR (mTOR)'},
#  'Brain disease  ICD11  8C708E61 ': {'Muscarinic acetylcholine receptor M5 (CHRM5)',
#   'Translocator protein (TSPO)'},
#  'Cannabis use disorder  ICD11  6C41 ': {'Cannabinoid receptor 1 (CB1)'},
#  'Radionuclide imaging  ICD11  NA  ': {'Adenosine A2a receptor (ADORA2A)'},
#  'Morning sickness disorder  ICD11  SC00 ': {'Histamine H1 receptor (H1R)'},
#  'Insecticide  ICD11  NA  ': {'Nicotinic acetylcholine receptor (nAChR)'},
#  'Pulmonary eosinophilia  ICD11  CB02 ': {'Interleukin-5 (IL5)'},
#  'Juvenile idiopathic arthritis  ICD11  FA24 ': {'5-HT 1A receptor (HTR1A)',
#   'Interleukin 6 receptor (IL6R)'},
#  'Skin  mucosal anomaly  ICD11  LD27 ': {'5-HT 1A receptor (HTR1A)'},
#  'Episode  ICD11  NA  ': {'5-HT 1A receptor (HTR1A)'},
#  'Localisation  ICD11  NA  ': {'Vasopressin V1a receptor (V1AR)'},
#  'Intermittent explosive disorder  ICD11  6C73 ': {'Vasopressin V1a receptor (V1AR)'},
#  'Nystagmus  ICD11  9C84 ': {'Muscarinic acetylcholine receptor M5 (CHRM5)'},
#  'Gastritis  ICD11  DA42 ': {'Muscarinic acetylcholine receptor M5 (CHRM5)'},
#  'Urgency  ICD11  NA  ': {'Muscarinic acetylcholine receptor M5 (CHRM5)'},
#  'General examination  ICD11  QA00 ': {'Muscarinic acetylcholine receptor M5 (CHRM5)'},
#  'Irregularities  ICD11  NA  ': {'Estrogen receptor (ESR)',
#   'Estrogen receptor beta (ESR2)'},
#  'Hearing disorder  ICD11  AB50AB57 ': {'P53 messenger RNA (TP53 mRNA)'},
#  'Muscle calcification  ossification  ICD11  FB31 ': {'Retinoic acid receptor gamma (RARG)'},
#  'Kidney malfunction  ICD11  MG02 ': {'Insulin (INS)'},
#  'Autosomal dominant polycystic kidney disease  ICD11  GB81 ': {'microRNA hsa-miR-17 (MIR17)'},
#  'Primary psychotic disorder manifestation  ICD11  6A25 ': {'Monoamine oxidase type B (MAO-B)'},
#  'Lower limb mononeuropathy  ICD11  8C11 ': {'Transient receptor potential cation channel V1 (TRPV1)'},
#  'Esophagus sensitivity  ICD11  DA2YDA2Z ': {'Transient receptor potential cation channel V1 (TRPV1)'},
#  'Hyperaldosteronism  ICD11  5A72 ': {'Steroid 11-beta-hydroxylase (CYP11B1)'},
#  'Bloodforming organ disease  ICD11  3C0Z ': {'Coagulation factor Xa (F10)'},
#  'Necrotising fasciitis  ICD11  1B71 ': {'T-cell-specific surface glycoprotein CD28 (CD28)'},
#  'Chemoprotection  ICD11  NA  ': {'DNA topoisomerase II (TOP2)',
#   'DNA topoisomerase II beta (TOP2B)'},
#  'Leiomyosarcoma  ICD11  2B58 ': {'Proto-oncogene c-Src (SRC)'},
#  'Myelofibrosis  ICD11  2A22 ': {'HUMAN janus kinase 1 (JAK-1)',
#   'HUMAN janus kinase 2 (JAK-2)'},
#  'Focal  segmental autonomic disorder  ICD11  8D8A ': {'Geranyltranstransferase (FDPS)',
#   'Trace amine-associated receptor-1 (TAAR1)'},
#  'Hyperlipidemia  ICD11  5C80 ': {'HUMAN MYD88NF-kappa-B proinflammatory pathway (MYD88-NFKB pathway)',
#   'Peroxisome proliferator-activated receptor alpha (PPARA)'},
#  'Antiphospholipid syndrome  ICD11  4A45 ': {'Beta-2-glycoprotein 1 (APOH)'},
#  'Desmoid tumour  ICD11  2F7C ': {'Amyloid beta A4 protein (APP)',
#   'Gamma-secretase (GS)'},
#  'Dystrophic epidermolysis bullosa  ICD11  EC32 ': {'Amyloid beta A4 protein (APP)'},
#  'Mesothelin positive tumour  ICD11  2C512F10 ': {'Mesothelin (MSLN)'},
#  'Metastatic pleura neoplasm  ICD11  2D72 ': {'Mesothelin (MSLN)'},
#  'Mesothelial tumour  ICD11  2F10 ': {'Mesothelin (MSLN)'},
#  'Rheumatic fever  ICD11  1B40 ': {'Bacterial Dihydropteroate synthetase (Bact folP)'},
#  'Subarachnoid haemorrhage  ICD11  8B01 ': {'Nuclear factor erythroid 2-related factor 2 (Nrf2)'},
#  'Ophthalmic devices  implants  grafts injury  ICD11  PK97 ': {'PTPN1 messenger RNA (PTPN1 mRNA)'},
#  'Eye disorder  ICD11  9A019A0Z ': {'Estrogen receptor (ESR)'},
#  'Atrophy  ICD11  9A2Y9C40 ': {'Estrogen receptor (ESR)'},
#  'Acquired prion disease  ICD11  8E01 ': {'Estrogen receptor (ESR)'},
#  'Dyspareunia  ICD11  GA12 ': {'Estrogen receptor (ESR)'},
#  'Female genital tract noninflammatory disorder  ICD11  GA1Y ': {'Estrogen receptor (ESR)'},
#  'Breast in situ carcinoma  ICD11  2E65 ': {'Estrogen receptor (ESR)'},
#  'Choroidal dystrophy  ICD11  9B61 ': {'Rab proteins geranylgeranyltransferase component A 1 (CHM)'},
#  'Vitreous body disorder  ICD11  9B8Z ': {'Fibronectin (FN1)'},
#  'Blood chemistry clinical sympton  ICD11  MA18 ': {'Intestinal maltase-glucoamylase (MGAM)'},
#  'Hypokalaemia  ICD11  5C77 ': {'Solute carrier family 12 member 1 (SLC12A1)'},
#  'Paroxysmal nocturnal haemoglobinuria  ICD11  3A21 ': {'HUMAN complement C5 protein (C5)'},
#  'Amino acid absorption  transport disorder  ICD11  5C60 ': {'Somatostatin (SST)'},
#  'Nail plate acquired deformity  ICD11  EE10 ': {'Keratin 6A messenger RNA (KRT6A mRNA)'},
#  'Metastatic lung neoplasm  ICD11  2D70 ': {'DNA topoisomerase II (TOP2)'},
#  'Anogenital warts  ICD11  1A95 ': {'DNA topoisomerase II (TOP2)'},
#  'Pneumococcal infection  ICD11  CA00CA40 ': {'Haemophilus influenzae CRM197 (Hae-influ CRM197)'},
#  'Skin pigmentation genetic disorder  ICD11  EC23 ': {'Tyrosinase (TYR)'},
#  'Acquired melanotic macule  lentigine  ICD11  ED61 ': {'Tyrosinase (TYR)'},
#  'Lesion  ICD11  8A008C12 ': {'Transforming growth factor beta 1 (TGFB1)'},
#  'Fragrance  cosmetics phototoxic reaction  ICD11  EK20 ': {'Caspase-1 (CASP1)'},
#  'Irritant contact dermatitis  ICD11  EK02 ': {'Caspase-1 (CASP1)'},
#  'Parathyroid disease  ICD11  5A505A5Z ': {'Parathyroid hormone (PTH)'},
#  'Idiopathic multicentric Castlemans disease  ICD11  2A81 ': {'HUMAN interleukin 6 (IL6)'},
#  'Advanced  metastatic breast cancer  ICD11  2C60 ': {'HUMAN mammalian target of rapamycin (mTOR)'},
#  'Arthropathy  ICD11  FA11FA5Z ': {'Fibroblast growth factor-18 (FGF18)'},
#  'Postviral fatigue syndrome  ICD11  8E49 ': {'HUMAN toll-like receptor 3 (TLR3)'},
#  'Pleomorphic sarcoma  ICD11  2B54 ': {'Programmed cell death 1 ligand 1 (PD-L1)'},
#  '': {'HUMAN vascular endothelial growth factor (VEGF)'}}

# %%
len(disease2genes_ttd)
# Out:
# 748

# %% [markdown]
# ### 3. Find mapping of a disease from test.json to TTD data
#
# Scince the disease labels in test.json are generally shorter, the mapping rule will be the following:
# if all the words are found in labels from TTD.
#
# Intersection of the sets of disease words is the criterion => we need to prepare disease to its words dictionary.
#
# **Itwould be much better to use the comparison of the embedding of disease names to match them but I didn't found suitable opensource model.**
#
# As concerns genes match, the logic is similar.

# %%
disease_word_sets = dict(map(lambda x: (x, set([y.lower() for y in x.split()])), disease2genes.keys()))

# %%
disease_word_sets_ttd = dict(map(lambda x: (x, set([y.lower() for y in x.split()])), disease2genes_ttd.keys()))

# %%
disease_word_sets
# Out:
# {'Bacterial pneumonia': {'bacterial', 'pneumonia'},
#  'Cutaneous leishmaniasis': {'cutaneous', 'leishmaniasis'},
#  'Dedifferentiated liposarcoma': {'dedifferentiated', 'liposarcoma'},
#  'Methylmalonic acidemia': {'acidemia', 'methylmalonic'},
#  'Conjunctival melanoma': {'conjunctival', 'melanoma'},
#  'Acute myocardial infarction': {'acute', 'infarction', 'myocardial'},
#  'Psoriatic arthritis': {'arthritis', 'psoriatic'},
#  'Ataxia-telangiectasia': {'ataxia-telangiectasia'},
#  'Chronic kidney disease': {'chronic', 'disease', 'kidney'},
#  'Cholangio carcinoma': {'carcinoma', 'cholangio'},
#  'Werner syndrome': {'syndrome', 'werner'},
#  'Osteoarthritis': {'osteoarthritis'},
#  'Interstitial cystitis': {'cystitis', 'interstitial'},
#  'Optic neuritis': {'neuritis', 'optic'},
#  'Eosinophilic esophagitis': {'eosinophilic', 'esophagitis'},
#  'Dermatomyositis': {'dermatomyositis'},
#  'Hermansky-Pudlak syndrome': {'hermansky-pudlak', 'syndrome'},
#  'IGA glomerulonephritis': {'glomerulonephritis', 'iga'},
#  'Cirrhosis of liver': {'cirrhosis', 'liver', 'of'},
#  'Seckel syndrome': {'seckel', 'syndrome'},
#  'Sickle cell anemia': {'anemia', 'cell', 'sickle'},
#  'Type II diabetes mellitus': {'diabetes', 'ii', 'mellitus', 'type'},
#  'Mucocutaneous lymph node syndrome': {'lymph',
#   'mucocutaneous',
#   'node',
#   'syndrome'},
#  'Basal-like breast carcinoma': {'basal-like', 'breast', 'carcinoma'},
#  'Facioscapulohumeral muscular dystrophy': {'dystrophy',
#   'facioscapulohumeral',
#   'muscular'},
#  "Alzheimer's disease": {"alzheimer's", 'disease'},
#  'Rett syndrome': {'rett', 'syndrome'},
#  'Obesity': {'obesity'},
#  'Ichthyosis': {'ichthyosis'},
#  'Familial adenomatous polyposis': {'adenomatous', 'familial', 'polyposis'},
#  'Hypertension': {'hypertension'},
#  'Inflammatory bowel disease': {'bowel', 'disease', 'inflammatory'},
#  'Vitiligo': {'vitiligo'},
#  'Esophageal carcinoma, adenocarcinoma': {'adenocarcinoma',
#   'carcinoma,',
#   'esophageal'},
#  'Graves disease': {'disease', 'graves'},
#  'endometriosis': {'endometriosis'},
#  'Alveolar rhabdomyosarcoma': {'alveolar', 'rhabdomyosarcoma'},
#  'Lung adenocarcinoma': {'adenocarcinoma', 'lung'},
#  'X-linked cerebral adrenoleukodystrophy': {'adrenoleukodystrophy',
#   'cerebral',
#   'x-linked'},
#  'head and neck squamous cell carcinoma, larynx': {'and',
#   'carcinoma,',
#   'cell',
#   'head',
#   'larynx',
#   'neck',
#   'squamous'},
#  'Dyskeratosis congenita': {'congenita', 'dyskeratosis'},
#  'Spinocerebellar ataxia with axonal neuropathy type 2': {'2',
#   'ataxia',
#   'axonal',
#   'neuropathy',
#   'spinocerebellar',
#   'type',
#   'with'},
#  'Urticaria': {'urticaria'},
#  'Hurler syndrome': {'hurler', 'syndrome'},
#  'Testicular Germ Cell Tumors; seminoma': {'cell',
#   'germ',
#   'seminoma',
#   'testicular',
#   'tumors;'},
#  'Acne': {'acne'},
#  'Heart failure': {'failure', 'heart'},
#  'Metabolic syndrome': {'metabolic', 'syndrome'},
#  'Celiac disease': {'celiac', 'disease'},
#  'Viral pneumonia': {'pneumonia', 'viral'},
#  'Diffuse scleroderma': {'diffuse', 'scleroderma'},
#  'Well-differentiated liposarcoma': {'liposarcoma', 'well-differentiated'},
#  'astrocytoma': {'astrocytoma'},
#  'Fanconi anemia': {'anemia', 'fanconi'},
#  'Metachromatic leukodystrophy': {'leukodystrophy', 'metachromatic'},
#  'Niemann-Pick disease type C': {'c', 'disease', 'niemann-pick', 'type'},
#  'Thalassemia': {'thalassemia'},
#  'Juvenile neuronal ceroid lipofuscinosis': {'ceroid',
#   'juvenile',
#   'lipofuscinosis',
#   'neuronal'},
#  'Sarcoidosis': {'sarcoidosis'},
#  'Myocardial infarction': {'infarction', 'myocardial'},
#  'Colorectal adenocarcinoma': {'adenocarcinoma', 'colorectal'},
#  'Osteoporosis': {'osteoporosis'},
#  'Metabolically healthy obesity': {'healthy', 'metabolically', 'obesity'},
#  'Pleomorphic liposarcoma': {'liposarcoma', 'pleomorphic'},
#  'Becker muscular dystrophy': {'becker', 'dystrophy', 'muscular'},
#  'Autosomal recessive limb-girdle muscular dystrophy type 2A': {'2a',
#   'autosomal',
#   'dystrophy',
#   'limb-girdle',
#   'muscular',
#   'recessive',
#   'type'},
#  'Cystic fibrosis': {'cystic', 'fibrosis'},
#  'Multiple myeloma': {'multiple', 'myeloma'},
#  'Friedreich ataxia': {'ataxia', 'friedreich'},
#  'clear cell renal carcinoma': {'carcinoma', 'cell', 'clear', 'renal'},
#  'Liposarcoma': {'liposarcoma'},
#  'Morbid obesity': {'morbid', 'obesity'},
#  'ovarian serous cystadenocarcinoma': {'cystadenocarcinoma',
#   'ovarian',
#   'serous'},
#  'Rectum adenocarcinoma': {'adenocarcinoma', 'rectum'},
#  'Non-alcoholic steatohepatitis': {'non-alcoholic', 'steatohepatitis'},
#  'Urinary bladder cancer': {'bladder', 'cancer', 'urinary'},
#  'Thrombotic thrombocytopenic purpura': {'purpura',
#   'thrombocytopenic',
#   'thrombotic'},
#  'Idiopathic interstitial pneumonia': {'idiopathic',
#   'interstitial',
#   'pneumonia'},
#  'Sjogren syndrome': {'sjogren', 'syndrome'},
#  'Graves Ophthalmopathy': {'graves', 'ophthalmopathy'},
#  'Limited scleroderma': {'limited', 'scleroderma'},
#  'Glioblastoma multiforme': {'glioblastoma', 'multiforme'},
#  '140122_PD1responce_melanoma': {'140122_pd1responce_melanoma'},
#  'Estrogen-receptor positive breast cancer': {'breast',
#   'cancer',
#   'estrogen-receptor',
#   'positive'},
#  'Nijmegen breakage syndrome': {'breakage', 'nijmegen', 'syndrome'},
#  'Asthma': {'asthma'},
#  'Familial amyotrophic lateral sclerosis': {'amyotrophic',
#   'familial',
#   'lateral',
#   'sclerosis'},
#  'Pulmonary arterial hypertension': {'arterial', 'hypertension', 'pulmonary'},
#  'Multiple sclerosis': {'multiple', 'sclerosis'},
#  'Rheumatoid arthritis': {'arthritis', 'rheumatoid'},
#  'HER2-receptor positive breast cancer': {'breast',
#   'cancer',
#   'her2-receptor',
#   'positive'},
#  'Renal fibrosis': {'fibrosis', 'renal'},
#  'Polyarticular juvenile idiopathic arthritis': {'arthritis',
#   'idiopathic',
#   'juvenile',
#   'polyarticular'},
#  'Bladder transitional cell carcinoma': {'bladder',
#   'carcinoma',
#   'cell',
#   'transitional'},
#  'Autosomal recessive limb-girdle muscular dystrophy type 2B': {'2b',
#   'autosomal',
#   'dystrophy',
#   'limb-girdle',
#   'muscular',
#   'recessive',
#   'type'},
#  'Type I diabetes mellitus': {'diabetes', 'i', 'mellitus', 'type'},
#  'Mesothelioma, biphasic': {'biphasic', 'mesothelioma,'},
#  'Juvenile idiopathic arthritis': {'arthritis', 'idiopathic', 'juvenile'},
#  'Preeclampsia': {'preeclampsia'},
#  'Actinic keratosis': {'actinic', 'keratosis'},
#  'Allergic rhinitis': {'allergic', 'rhinitis'},
#  'Fatal familial insomnia': {'familial', 'fatal', 'insomnia'},
#  'Psoriasis': {'psoriasis'},
#  'Lung squamous cell carcinoma': {'carcinoma', 'cell', 'lung', 'squamous'},
#  'Estrogen-receptor negative breast cancer': {'breast',
#   'cancer',
#   'estrogen-receptor',
#   'negative'},
#  'Focal segmental glomerulosclerosis': {'focal',
#   'glomerulosclerosis',
#   'segmental'},
#  'Chronic obstructive pulmonary disease': {'chronic',
#   'disease',
#   'obstructive',
#   'pulmonary'},
#  'Granulomatosis with polyangiitis': {'granulomatosis',
#   'polyangiitis',
#   'with'},
#  'Polymyositis': {'polymyositis'},
#  'primary biliary cirrhosis': {'biliary', 'cirrhosis', 'primary'},
#  'Systemic scleroderma': {'scleroderma', 'systemic'},
#  'oligodendroglioma': {'oligodendroglioma'},
#  'Rapidly progressive glomerulonephritis': {'glomerulonephritis',
#   'progressive',
#   'rapidly'},
#  'cervical squamous cell carcinoma': {'carcinoma',
#   'cell',
#   'cervical',
#   'squamous'},
#  'Kidney renal papillary cell carcinoma': {'carcinoma',
#   'cell',
#   'kidney',
#   'papillary',
#   'renal'},
#  'adrenocortical carcinoma': {'adrenocortical', 'carcinoma'},
#  'Angiosarcoma': {'angiosarcoma'},
#  'Esophageal carcinoma, squamous cell carcinoma': {'carcinoma',
#   'carcinoma,',
#   'cell',
#   'esophageal',
#   'squamous'},
#  'Clear cell renal carcinoma': {'carcinoma', 'cell', 'clear', 'renal'},
#  'Coronary artery disease': {'artery', 'coronary', 'disease'},
#  'Familial hypercholesterolemia': {'familial', 'hypercholesterolemia'},
#  'Ankylosing spondylitis': {'ankylosing', 'spondylitis'},
#  'Systemic lupus erythematosus': {'erythematosus', 'lupus', 'systemic'},
#  'Melanoma': {'melanoma'},
#  'Cockayne syndrome': {'cockayne', 'syndrome'},
#  'Cutaneous lupus erythematosus': {'cutaneous', 'erythematosus', 'lupus'},
#  'Sporadic amyotrophic lateral sclerosis': {'amyotrophic',
#   'lateral',
#   'sclerosis',
#   'sporadic'},
#  'Smith-Lemli-Opitz syndrome': {'smith-lemli-opitz', 'syndrome'},
#  'Postmenopausal osteoporosis': {'osteoporosis', 'postmenopausal'},
#  'Triple-negative breast cancer': {'breast', 'cancer', 'triple-negative'},
#  'Huntington disease': {'disease', 'huntington'},
#  'Colorectal cancer': {'cancer', 'colorectal'},
#  'Autoimmune thrombocytopenic purpura': {'autoimmune',
#   'purpura',
#   'thrombocytopenic'},
#  'Xeroderma pigmentosum A': {'a', 'pigmentosum', 'xeroderma'},
#  'Lung large cell carcinoma': {'carcinoma', 'cell', 'large', 'lung'},
#  'Ocular hypertension': {'hypertension', 'ocular'},
#  'Glycogen storage disease type II': {'disease',
#   'glycogen',
#   'ii',
#   'storage',
#   'type'},
#  'Lung small cell carcinoma': {'carcinoma', 'cell', 'lung', 'small'},
#  'Spondyloarthropathy': {'spondyloarthropathy'},
#  'Latent autoimmune diabetes in adults': {'adults',
#   'autoimmune',
#   'diabetes',
#   'in',
#   'latent'},
#  'Alopecia areata': {'alopecia', 'areata'},
#  'Atherosclerosis': {'atherosclerosis'},
#  'Amyloidosis': {'amyloidosis'},
#  'graft versus host disease': {'disease', 'graft', 'host', 'versus'},
#  'Oligoarticular juvenile idiopathic arthritis': {'arthritis',
#   'idiopathic',
#   'juvenile',
#   'oligoarticular'},
#  'Rhabdomyosarcoma': {'rhabdomyosarcoma'},
#  'Pancreatic adenocarcinoma': {'adenocarcinoma', 'pancreatic'},
#  'Duchenne muscular dystrophy': {'duchenne', 'dystrophy', 'muscular'},
#  "Crohn's disease": {"crohn's", 'disease'},
#  'Pancreatic ductal adenocarcinoma': {'adenocarcinoma',
#   'ductal',
#   'pancreatic'},
#  'Gastric cancer': {'cancer', 'gastric'},
#  'Stage 5 chronic kidney disease': {'5',
#   'chronic',
#   'disease',
#   'kidney',
#   'stage'},
#  'Xeroderma pigmentosum C': {'c', 'pigmentosum', 'xeroderma'},
#  'Alveolar soft part sarcoma': {'alveolar', 'part', 'sarcoma', 'soft'},
#  'Spinocerebellar ataxia type 2': {'2', 'ataxia', 'spinocerebellar', 'type'},
#  'Idiopathic pulmonary fibrosis': {'fibrosis', 'idiopathic', 'pulmonary'},
#  'Autosomal recessive limb-girdle muscular dystrophy type 2I': {'2i',
#   'autosomal',
#   'dystrophy',
#   'limb-girdle',
#   'muscular',
#   'recessive',
#   'type'},
#  'Hidradenitis suppurativa': {'hidradenitis', 'suppurativa'},
#  'Myxoid liposarcoma': {'liposarcoma', 'myxoid'},
#  "Behcet's syndrome": {"behcet's", 'syndrome'},
#  'Diabetic nephropathy': {'diabetic', 'nephropathy'},
#  'Thyroid carcinoma; follicular': {'carcinoma;', 'follicular', 'thyroid'},
#  'Systemic juvenile idiopathic arthritis': {'arthritis',
#   'idiopathic',
#   'juvenile',
#   'systemic'},
#  'Citrullinemia type I': {'citrullinemia', 'i', 'type'},
#  'MELAS': {'melas'},
#  'papillary thyroid carcinoma': {'carcinoma', 'papillary', 'thyroid'},
#  'Hepatocellular carcinoma': {'carcinoma', 'hepatocellular'},
#  'Ulcerative colitis': {'colitis', 'ulcerative'},
#  'Lung non-small cell carcinoma': {'carcinoma', 'cell', 'lung', 'non-small'},
#  'Osteosarcoma': {'osteosarcoma'},
#  'endometrial adenocarcinoma': {'adenocarcinoma', 'endometrial'},
#  'Complex regional pain syndrome': {'complex', 'pain', 'regional', 'syndrome'},
#  'Stevens-Johnson syndrome': {'stevens-johnson', 'syndrome'},
#  'Head and neck squamous cell carcinoma': {'and',
#   'carcinoma',
#   'cell',
#   'head',
#   'neck',
#   'squamous'},
#  'Autosomal recessive limb-girdle muscular dystrophy ': {'autosomal',
#   'dystrophy',
#   'limb-girdle',
#   'muscular',
#   'recessive'},
#  'Chronic granulomatous disease': {'chronic', 'disease', 'granulomatous'},
#  'Myasthenia gravis': {'gravis', 'myasthenia'},
#  'Autosomal recessive limb-girdle muscular dystrophy type 2D': {'2d',
#   'autosomal',
#   'dystrophy',
#   'limb-girdle',
#   'muscular',
#   'recessive',
#   'type'},
#  'Ewing sarcoma': {'ewing', 'sarcoma'},
#  'Fabry disease': {'disease', 'fabry'},
#  'Gaucher disease': {'disease', 'gaucher'},
#  'Atopic dermatitis': {'atopic', 'dermatitis'},
#  'Pancreatic carcinoma': {'carcinoma', 'pancreatic'},
#  'Vasculitis': {'vasculitis'},
#  'Propionic acidemia': {'acidemia', 'propionic'},
#  'Spinocerebellar ataxia type 6': {'6', 'ataxia', 'spinocerebellar', 'type'},
#  'Non-alcoholic fatty liver disease': {'disease',
#   'fatty',
#   'liver',
#   'non-alcoholic'},
#  'Extramammary paget disease': {'disease', 'extramammary', 'paget'},
#  'Amyotrophic lateral sclerosis': {'amyotrophic', 'lateral', 'sclerosis'},
#  'Bloom syndrome': {'bloom', 'syndrome'},
#  'Hepatitis, alcoholic': {'alcoholic', 'hepatitis,'},
#  'Uterine leiomyosarcoma': {'leiomyosarcoma', 'uterine'},
#  'Machado-Joseph disease': {'disease', 'machado-joseph'},
#  'head and neck squamous cell carcinoma, tongue': {'and',
#   'carcinoma,',
#   'cell',
#   'head',
#   'neck',
#   'squamous',
#   'tongue'},
#  'Leigh syndrome': {'leigh', 'syndrome'},
#  'Hutchinson-Gilford progeria syndrome': {'hutchinson-gilford',
#   'progeria',
#   'syndrome'},
#  'Ullrich congenital muscular dystrophy': {'congenital',
#   'dystrophy',
#   'muscular',
#   'ullrich'},
#  'Epidermolysis bullosa simplex': {'bullosa', 'epidermolysis', 'simplex'},
#  'Stroke': {'stroke'},
#  'chromophobe renal cell carcinoma': {'carcinoma',
#   'cell',
#   'chromophobe',
#   'renal'},
#  'Guillain-Barre syndrome': {'guillain-barre', 'syndrome'},
#  'Embryonal rhabdomyosarcoma': {'embryonal', 'rhabdomyosarcoma'},
#  'Primary biliary cirrhosis': {'biliary', 'cirrhosis', 'primary'},
#  'Hyperglycemia': {'hyperglycemia'},
#  'Kidney renal clear cell carcinoma': {'carcinoma',
#   'cell',
#   'clear',
#   'kidney',
#   'renal'},
#  'Melanocytic nevus': {'melanocytic', 'nevus'},
#  'Prostate adenocarcinoma': {'adenocarcinoma', 'prostate'}}

# %%
disease_word_sets_ttd
# Out:
# {'Chronic kidney disease  ICD11  GB61 ': {'chronic',
#   'disease',
#   'gb61',
#   'icd11',
#   'kidney'},
#  'Fibrosis  ICD11  GA14GC01 ': {'fibrosis', 'ga14gc01', 'icd11'},
#  'Rheumatoid arthritis  ICD11  FA20 ': {'arthritis',
#   'fa20',
#   'icd11',
#   'rheumatoid'},
#  'COVID19  ICD11  1D6Y ': {'1d6y', 'covid19', 'icd11'},
#  'Solid tumour  cancer  ICD11  2A002F9Z ': {'2a002f9z',
#   'cancer',
#   'icd11',
#   'solid',
#   'tumour'},
#  'Cardiovascular disease  ICD11  BA00BE2Z ': {'ba00be2z',
#   'cardiovascular',
#   'disease',
#   'icd11'},
#  'Lung cancer  ICD11  2C25 ': {'2c25', 'cancer', 'icd11', 'lung'},
#  'Thrombocytopenia  ICD11  3B64 ': {'3b64', 'icd11', 'thrombocytopenia'},
#  'Filariasis  ICD11  1F66 ': {'1f66', 'filariasis', 'icd11'},
#  'Chronic obstructive pulmonary disease  ICD11  CA22 ': {'ca22',
#   'chronic',
#   'disease',
#   'icd11',
#   'obstructive',
#   'pulmonary'},
#  'Asthma  ICD11  CA23 ': {'asthma', 'ca23', 'icd11'},
#  'Pituitary gland disorder  ICD11  5A605A61 ': {'5a605a61',
#   'disorder',
#   'gland',
#   'icd11',
#   'pituitary'},
#  'Fungal infection  ICD11  1F291F2F ': {'1f291f2f',
#   'fungal',
#   'icd11',
#   'infection'},
#  'Atopic eczema  ICD11  EA80 ': {'atopic', 'ea80', 'eczema', 'icd11'},
#  'Thrombosis  ICD11  DB61GB90 ': {'db61gb90', 'icd11', 'thrombosis'},
#  'Osteoarthritis  ICD11  FA00FA05 ': {'fa00fa05', 'icd11', 'osteoarthritis'},
#  'Eczema  ICD11  EA80EA89 ': {'ea80ea89', 'eczema', 'icd11'},
#  'Idiopathic interstitial pneumonitis  ICD11  CB03 ': {'cb03',
#   'icd11',
#   'idiopathic',
#   'interstitial',
#   'pneumonitis'},
#  'Malaria  ICD11  1F401F45 ': {'1f401f45', 'icd11', 'malaria'},
#  'Nasopharyngeal cancer  ICD11  2B6B ': {'2b6b',
#   'cancer',
#   'icd11',
#   'nasopharyngeal'},
#  'Postoperative inflammation  ICD11  1A00CA43 ': {'1a00ca43',
#   'icd11',
#   'inflammation',
#   'postoperative'},
#  'Carcinoid syndrome  ICD11  5B10 ': {'5b10',
#   'carcinoid',
#   'icd11',
#   'syndrome'},
#  'Psoriasis  ICD11  EA90 ': {'ea90', 'icd11', 'psoriasis'},
#  'Pain  ICD11  MG30MG3Z ': {'icd11', 'mg30mg3z', 'pain'},
#  'Respiratory system disease  ICD11  CB40CB7Z ': {'cb40cb7z',
#   'disease',
#   'icd11',
#   'respiratory',
#   'system'},
#  'Arterial occlusive disease  ICD11  BD40 ': {'arterial',
#   'bd40',
#   'disease',
#   'icd11',
#   'occlusive'},
#  'Influenza  ICD11  1E301E32 ': {'1e301e32', 'icd11', 'influenza'},
#  'Allergic  hypersensitivity disorder  ICD11  4A804A8Z ': {'4a804a8z',
#   'allergic',
#   'disorder',
#   'hypersensitivity',
#   'icd11'},
#  'Pruritus  ICD11  EC90 ': {'ec90', 'icd11', 'pruritus'},
#  'Severe acute respiratory syndrome  ICD11  1D65 ': {'1d65',
#   'acute',
#   'icd11',
#   'respiratory',
#   'severe',
#   'syndrome'},
#  'Middle East Respiratory Syndrome  ICD11  1D64 ': {'1d64',
#   'east',
#   'icd11',
#   'middle',
#   'respiratory',
#   'syndrome'},
#  'Depression  ICD11  6A706A7Z ': {'6a706a7z', 'depression', 'icd11'},
#  'Breast cancer  ICD11  2C602C6Y ': {'2c602c6y', 'breast', 'cancer', 'icd11'},
#  'Liposarcoma  ICD11  2B59 ': {'2b59', 'icd11', 'liposarcoma'},
#  'Myeloproliferative neoplasm  ICD11  2A20 ': {'2a20',
#   'icd11',
#   'myeloproliferative',
#   'neoplasm'},
#  'Prostate cancer  ICD11  2C82 ': {'2c82', 'cancer', 'icd11', 'prostate'},
#  'Acute myeloid leukaemia  ICD11  2A60 ': {'2a60',
#   'acute',
#   'icd11',
#   'leukaemia',
#   'myeloid'},
#  'Mature Bcell leukaemia  ICD11  2A82 ': {'2a82',
#   'bcell',
#   'icd11',
#   'leukaemia',
#   'mature'},
#  'Neuroendocrine carcinoma  ICD11  2C34 ': {'2c34',
#   'carcinoma',
#   'icd11',
#   'neuroendocrine'},
#  'Malignant haematopoietic neoplasm  ICD11  2B33 ': {'2b33',
#   'haematopoietic',
#   'icd11',
#   'malignant',
#   'neoplasm'},
#  'Myelodysplastic syndrome  ICD11  2A37 ': {'2a37',
#   'icd11',
#   'myelodysplastic',
#   'syndrome'},
#  'Heart failure  ICD11  BD10BD1Z ': {'bd10bd1z', 'failure', 'heart', 'icd11'},
#  'Ulcerative colitis  ICD11  DD71 ': {'colitis',
#   'dd71',
#   'icd11',
#   'ulcerative'},
#  'Systemic sclerosis  ICD11  4A42 ': {'4a42',
#   'icd11',
#   'sclerosis',
#   'systemic'},
#  'Cardiomyopathy  ICD11  BC43 ': {'bc43', 'cardiomyopathy', 'icd11'},
#  'Muscle disorder  ICD11  FB32FB3Z ': {'disorder',
#   'fb32fb3z',
#   'icd11',
#   'muscle'},
#  'Muscular atrophy  ICD11  8B61 ': {'8b61', 'atrophy', 'icd11', 'muscular'},
#  'Motor neuron disease  ICD11  8B60 ': {'8b60',
#   'disease',
#   'icd11',
#   'motor',
#   'neuron'},
#  'Human immunodeficiency virus disease  ICD11  1C601C62 ': {'1c601c62',
#   'disease',
#   'human',
#   'icd11',
#   'immunodeficiency',
#   'virus'},
#  'Neurodegenerative disorder  ICD11  8A208A23 ': {'8a208a23',
#   'disorder',
#   'icd11',
#   'neurodegenerative'},
#  'Diabetes mellitus  ICD11  5A10 ': {'5a10', 'diabetes', 'icd11', 'mellitus'},
#  'Indeterminate colitis  ICD11  DD72 ': {'colitis',
#   'dd72',
#   'icd11',
#   'indeterminate'},
#  'Coronary atherosclerosis  ICD11  BA80 ': {'atherosclerosis',
#   'ba80',
#   'coronary',
#   'icd11'},
#  'Dyslipidemia  ICD11  5C805C81 ': {'5c805c81', 'dyslipidemia', 'icd11'},
#  'Inborn lipid metabolism error  ICD11  5C52 ': {'5c52',
#   'error',
#   'icd11',
#   'inborn',
#   'lipid',
#   'metabolism'},
#  'Inborn purine  pyrimidine  nucleotide metabolism error  ICD11  5C55 ': {'5c55',
#   'error',
#   'icd11',
#   'inborn',
#   'metabolism',
#   'nucleotide',
#   'purine',
#   'pyrimidine'},
#  'CNS birth injury  ICD11  KA40 ': {'birth', 'cns', 'icd11', 'injury', 'ka40'},
#  'Fallopian tube cancer  ICD11  2C74 ': {'2c74',
#   'cancer',
#   'fallopian',
#   'icd11',
#   'tube'},
#  'Liver vascular disorder  ICD11  DB98 ': {'db98',
#   'disorder',
#   'icd11',
#   'liver',
#   'vascular'},
#  'Medical  surgical procedure injury  ICD11  PK80PK81 ': {'icd11',
#   'injury',
#   'medical',
#   'pk80pk81',
#   'procedure',
#   'surgical'},
#  'Melanoma  ICD11  2C30 ': {'2c30', 'icd11', 'melanoma'},
#  'Gout  ICD11  FA25 ': {'fa25', 'gout', 'icd11'},
#  'Transplant rejection  ICD11  NE84 ': {'icd11',
#   'ne84',
#   'rejection',
#   'transplant'},
#  'Hyperlipoproteinaemia  ICD11  5C80 ': {'5c80',
#   'hyperlipoproteinaemia',
#   'icd11'},
#  'Anxiety disorder  ICD11  6B006B0Z ': {'6b006b0z',
#   'anxiety',
#   'disorder',
#   'icd11'},
#  'Alzheimer disease  ICD11  8A20 ': {'8a20', 'alzheimer', 'disease', 'icd11'},
#  'Central nervous system disease  ICD11  8A048D87 ': {'8a048d87',
#   'central',
#   'disease',
#   'icd11',
#   'nervous',
#   'system'},
#  'Multiple sclerosis  ICD11  8A40 ': {'8a40',
#   'icd11',
#   'multiple',
#   'sclerosis'},
#  'Tonus and reflex abnormality  ICD11  MB47 ': {'abnormality',
#   'and',
#   'icd11',
#   'mb47',
#   'reflex',
#   'tonus'},
#  'Inflammatory arthropathy  ICD11  FA2Z ': {'arthropathy',
#   'fa2z',
#   'icd11',
#   'inflammatory'},
#  'Hodgkin lymphoma  ICD11  2B30 ': {'2b30', 'hodgkin', 'icd11', 'lymphoma'},
#  'Bone  articular cartilage neoplasm  ICD11  2F7B ': {'2f7b',
#   'articular',
#   'bone',
#   'cartilage',
#   'icd11',
#   'neoplasm'},
#  'Metastatic tumour  ICD11  2D502E2Z ': {'2d502e2z',
#   'icd11',
#   'metastatic',
#   'tumour'},
#  'Liver cancer  ICD11  2C12 ': {'2c12', 'cancer', 'icd11', 'liver'},
#  'Immunoproliferative disorder  ICD11  2B32 ': {'2b32',
#   'disorder',
#   'icd11',
#   'immunoproliferative'},
#  'Lymphoma  ICD11  2A802A86 ': {'2a802a86', 'icd11', 'lymphoma'},
#  'Transplanted organ  tissue  ICD11  QB63 ': {'icd11',
#   'organ',
#   'qb63',
#   'tissue',
#   'transplanted'},
#  'Low bone mass disorder  ICD11  FB83 ': {'bone',
#   'disorder',
#   'fb83',
#   'icd11',
#   'low',
#   'mass'},
#  'Diffuse large Bcell lymphoma  ICD11  2A81 ': {'2a81',
#   'bcell',
#   'diffuse',
#   'icd11',
#   'large',
#   'lymphoma'},
#  'Immunodeficiency  ICD11  4A004A85 ': {'4a004a85',
#   'icd11',
#   'immunodeficiency'},
#  'Renal cell carcinoma  ICD11  2C90 ': {'2c90',
#   'carcinoma',
#   'cell',
#   'icd11',
#   'renal'},
#  'Mature Bcell lymphoma  ICD11  2A85 ': {'2a85',
#   'bcell',
#   'icd11',
#   'lymphoma',
#   'mature'},
#  'Urinary system clinical sympton  ICD11  MF8Y ': {'clinical',
#   'icd11',
#   'mf8y',
#   'sympton',
#   'system',
#   'urinary'},
#  'Hepatitis virus infection  ICD11  1E501E51 ': {'1e501e51',
#   'hepatitis',
#   'icd11',
#   'infection',
#   'virus'},
#  'BCRABL1negative chronic myeloid leukaemia  ICD11  2A41 ': {'2a41',
#   'bcrabl1negative',
#   'chronic',
#   'icd11',
#   'leukaemia',
#   'myeloid'},
#  'Congenital ichthyosis  ICD11  EC20 ': {'congenital',
#   'ec20',
#   'icd11',
#   'ichthyosis'},
#  'Skin sensation disturbance  ICD11  ME65 ': {'disturbance',
#   'icd11',
#   'me65',
#   'sensation',
#   'skin'},
#  'Inherited retinal dystrophy  ICD11  9B70 ': {'9b70',
#   'dystrophy',
#   'icd11',
#   'inherited',
#   'retinal'},
#  'Acute diabete complication  ICD11  5A2Y ': {'5a2y',
#   'acute',
#   'complication',
#   'diabete',
#   'icd11'},
#  'Unspecific body region injury  ICD11  ND56 ': {'body',
#   'icd11',
#   'injury',
#   'nd56',
#   'region',
#   'unspecific'},
#  'Chronic arterial occlusive disease  ICD11  BD4Z ': {'arterial',
#   'bd4z',
#   'chronic',
#   'disease',
#   'icd11',
#   'occlusive'},
#  'Chronic pain  ICD11  MG30 ': {'chronic', 'icd11', 'mg30', 'pain'},
#  'Vasomotor  allergic rhinitis  ICD11  CA08 ': {'allergic',
#   'ca08',
#   'icd11',
#   'rhinitis',
#   'vasomotor'},
#  'Substance abuse  ICD11  6C40 ': {'6c40', 'abuse', 'icd11', 'substance'},
#  'Unspecific substance harmful effect  ICD11  NE6Z ': {'effect',
#   'harmful',
#   'icd11',
#   'ne6z',
#   'substance',
#   'unspecific'},
#  'General pain disorder  ICD11  8E43 ': {'8e43',
#   'disorder',
#   'general',
#   'icd11',
#   'pain'},
#  'Peptic ulcer  ICD11  DA61 ': {'da61', 'icd11', 'peptic', 'ulcer'},
#  'Sexual dysfunction  ICD11  HA00HA01 ': {'dysfunction',
#   'ha00ha01',
#   'icd11',
#   'sexual'},
#  'Hypotension  ICD11  BA20BA21 ': {'ba20ba21', 'hypotension', 'icd11'},
#  'Hypertension  ICD11  BA00BA04 ': {'ba00ba04', 'hypertension', 'icd11'},
#  'Herpes simplex infection  ICD11  1F00 ': {'1f00',
#   'herpes',
#   'icd11',
#   'infection',
#   'simplex'},
#  'Nonspecific cutaneous vascular sympton  ICD11  ME64 ': {'cutaneous',
#   'icd11',
#   'me64',
#   'nonspecific',
#   'sympton',
#   'vascular'},
#  'Prostate disease  ICD11  GA91 ': {'disease', 'ga91', 'icd11', 'prostate'},
#  'Posttraumatic stress disorder  ICD11  6B40 ': {'6b40',
#   'disorder',
#   'icd11',
#   'posttraumatic',
#   'stress'},
#  'Obesity  ICD11  5B805B81 ': {'5b805b81', 'icd11', 'obesity'},
#  'Glaucoma  ICD11  9C61 ': {'9c61', 'glaucoma', 'icd11'},
#  'Dissociative neurological symptom disorder  ICD11  6B60 ': {'6b60',
#   'disorder',
#   'dissociative',
#   'icd11',
#   'neurological',
#   'symptom'},
#  'Orgasmic dysfunction  ICD11  HA02 ': {'dysfunction',
#   'ha02',
#   'icd11',
#   'orgasmic'},
#  'Genetic cardiac arrhythmia  ICD11  BC65 ': {'arrhythmia',
#   'bc65',
#   'cardiac',
#   'genetic',
#   'icd11'},
#  'Dementia  ICD11  6D806D8Z ': {'6d806d8z', 'dementia', 'icd11'},
#  'Coronavirus infection  ICD11  1D92 ': {'1d92',
#   'coronavirus',
#   'icd11',
#   'infection'},
#  'Coagulation defect  ICD11  3B10 ': {'3b10',
#   'coagulation',
#   'defect',
#   'icd11'},
#  'Alpha1antitrypsin deficiency  ICD11  5C5A ': {'5c5a',
#   'alpha1antitrypsin',
#   'deficiency',
#   'icd11'},
#  'Cystic fibrosis  ICD11  CA25 ': {'ca25', 'cystic', 'fibrosis', 'icd11'},
#  'Retinopathy  ICD11  9B71 ': {'9b71', 'icd11', 'retinopathy'},
#  'Brain cancer  ICD11  2A00 ': {'2a00', 'brain', 'cancer', 'icd11'},
#  'Innate  adaptive immunodeficiency  ICD11  4A00 ': {'4a00',
#   'adaptive',
#   'icd11',
#   'immunodeficiency',
#   'innate'},
#  'Epidermal dysplasias  ICD11  EK90 ': {'dysplasias',
#   'ek90',
#   'epidermal',
#   'icd11'},
#  'Hepatic fibrosis  cirrhosis  ICD11  DB93 ': {'cirrhosis',
#   'db93',
#   'fibrosis',
#   'hepatic',
#   'icd11'},
#  'Acute upper respiratory infection  ICD11  CA07 ': {'acute',
#   'ca07',
#   'icd11',
#   'infection',
#   'respiratory',
#   'upper'},
#  'Choreiform disorder  ICD11  8A01 ': {'8a01',
#   'choreiform',
#   'disorder',
#   'icd11'},
#  'Parkinsonism  ICD11  8A00 ': {'8a00', 'icd11', 'parkinsonism'},
#  'Mood disorder  ICD11  6A606E23 ': {'6a606e23', 'disorder', 'icd11', 'mood'},
#  'Amyloidosis  ICD11  5D00 ': {'5d00', 'amyloidosis', 'icd11'},
#  'Pneumonia  ICD11  CA40 ': {'ca40', 'icd11', 'pneumonia'},
#  'Vitamin deficiency  ICD11  5B555B5F ': {'5b555b5f',
#   'deficiency',
#   'icd11',
#   'vitamin'},
#  'Crohn disease  ICD11  DD70 ': {'crohn', 'dd70', 'disease', 'icd11'},
#  'Mycosis fungoides  ICD11  2B01 ': {'2b01', 'fungoides', 'icd11', 'mycosis'},
#  'Mild neurocognitive disorder  ICD11  6D71 ': {'6d71',
#   'disorder',
#   'icd11',
#   'mild',
#   'neurocognitive'},
#  'Lysosomal disease  ICD11  5C56 ': {'5c56', 'disease', 'icd11', 'lysosomal'},
#  'Otitis externa  ICD11  AA00AA13 ': {'aa00aa13',
#   'externa',
#   'icd11',
#   'otitis'},
#  'Bacterial infection  ICD11  1A001C4Z ': {'1a001c4z',
#   'bacterial',
#   'icd11',
#   'infection'},
#  'Iron deficiency anaemia  ICD11  3A00 ': {'3a00',
#   'anaemia',
#   'deficiency',
#   'icd11',
#   'iron'},
#  'Mineral absorption  transport disorder  ICD11  5C64 ': {'5c64',
#   'absorption',
#   'disorder',
#   'icd11',
#   'mineral',
#   'transport'},
#  'Thalassaemia  ICD11  3A50 ': {'3a50', 'icd11', 'thalassaemia'},
#  'Anemia  ICD11  3A003A9Z ': {'3a003a9z', 'anemia', 'icd11'},
#  'Multiple myeloma  ICD11  2A83 ': {'2a83', 'icd11', 'multiple', 'myeloma'},
#  'Lupus erythematosus  ICD11  4A40 ': {'4a40',
#   'erythematosus',
#   'icd11',
#   'lupus'},
#  'Binge eating disorder  ICD11  6B82 ': {'6b82',
#   'binge',
#   'disorder',
#   'eating',
#   'icd11'},
#  'Short stature  ICD11  5B11 ': {'5b11', 'icd11', 'short', 'stature'},
#  'Musculoskeletal disorder  ICD11  FA00FC0Z ': {'disorder',
#   'fa00fc0z',
#   'icd11',
#   'musculoskeletal'},
#  'Nausea  vomiting  ICD11  MD90 ': {'icd11', 'md90', 'nausea', 'vomiting'},
#  'Nicotine use disorder  ICD11  6C4A ': {'6c4a',
#   'disorder',
#   'icd11',
#   'nicotine',
#   'use'},
#  'Endometrial cancer  ICD11  2C76 ': {'2c76',
#   'cancer',
#   'endometrial',
#   'icd11'},
#  'Cocaine use disorder  ICD11  6C45 ': {'6c45',
#   'cocaine',
#   'disorder',
#   'icd11',
#   'use'},
#  'Gastroduodenal motor  secretory disorder  ICD11  DA41 ': {'da41',
#   'disorder',
#   'gastroduodenal',
#   'icd11',
#   'motor',
#   'secretory'},
#  'Bipolar disorder  ICD11  6A60 ': {'6a60', 'bipolar', 'disorder', 'icd11'},
#  'Unspecific substance use disorder  ICD11  6C4Z ': {'6c4z',
#   'disorder',
#   'icd11',
#   'substance',
#   'unspecific',
#   'use'},
#  'Leukaemia  ICD11  2A602B33 ': {'2a602b33', 'icd11', 'leukaemia'},
#  'Respiratory infection  ICD11  CA07CA4Z ': {'ca07ca4z',
#   'icd11',
#   'infection',
#   'respiratory'},
#  'Schizophrenia  ICD11  6A20 ': {'6a20', 'icd11', 'schizophrenia'},
#  'Psychoactive substances use disorder  ICD11  6C4G ': {'6c4g',
#   'disorder',
#   'icd11',
#   'psychoactive',
#   'substances',
#   'use'},
#  'Attention deficit hyperactivity disorder  ICD11  6A05 ': {'6a05',
#   'attention',
#   'deficit',
#   'disorder',
#   'hyperactivity',
#   'icd11'},
#  'Stomach cancer  ICD11  2B72 ': {'2b72', 'cancer', 'icd11', 'stomach'},
#  'Psychotic disorder  ICD11  6A206A25 ': {'6a206a25',
#   'disorder',
#   'icd11',
#   'psychotic'},
#  'Oesophagus motility disorder  ICD11  DA21 ': {'da21',
#   'disorder',
#   'icd11',
#   'motility',
#   'oesophagus'},
#  'Circulatory system disease  ICD11  BE2Z ': {'be2z',
#   'circulatory',
#   'disease',
#   'icd11',
#   'system'},
#  'Joint pain  ICD11  ME82 ': {'icd11', 'joint', 'me82', 'pain'},
#  'HIVinfected patients with tuberculosis  ICD11  1B101B14 ': {'1b101b14',
#   'hivinfected',
#   'icd11',
#   'patients',
#   'tuberculosis',
#   'with'},
#  'Bowel habit change  ICD11  ME05 ': {'bowel',
#   'change',
#   'habit',
#   'icd11',
#   'me05'},
#  'Sepsis  ICD11  1G401G41 ': {'1g401g41', 'icd11', 'sepsis'},
#  'Arteries  arterioles disorder  ICD11  BD52 ': {'arteries',
#   'arterioles',
#   'bd52',
#   'disorder',
#   'icd11'},
#  'Insulinresistance syndrome  ICD11  5A44 ': {'5a44',
#   'icd11',
#   'insulinresistance',
#   'syndrome'},
#  'Acute  chronic pain  ICD11  MG30MG31 ': {'acute',
#   'chronic',
#   'icd11',
#   'mg30mg31',
#   'pain'},
#  'Angina pectoris  ICD11  BA40 ': {'angina', 'ba40', 'icd11', 'pectoris'},
#  'Type 2 diabetes mellitus  ICD11  5A11 ': {'2',
#   '5a11',
#   'diabetes',
#   'icd11',
#   'mellitus',
#   'type'},
#  'Muscular dystrophy  ICD11  8C70 ': {'8c70',
#   'dystrophy',
#   'icd11',
#   'muscular'},
#  'Eye anterior segment structural developmental anomaly  ICD11  LA11 ': {'anomaly',
#   'anterior',
#   'developmental',
#   'eye',
#   'icd11',
#   'la11',
#   'segment',
#   'structural'},
#  'Epilepsy  seizure  ICD11  8A618A6Z ': {'8a618a6z',
#   'epilepsy',
#   'icd11',
#   'seizure'},
#  'Skin fungal infection disorder  ICD11  EA60 ': {'disorder',
#   'ea60',
#   'fungal',
#   'icd11',
#   'infection',
#   'skin'},
#  'Intrathoracic organs injury  ICD11  NB32 ': {'icd11',
#   'injury',
#   'intrathoracic',
#   'nb32',
#   'organs'},
#  'Cervical cancer  ICD11  2C77 ': {'2c77', 'cancer', 'cervical', 'icd11'},
#  'Pancreatic cancer  ICD11  2C10 ': {'2c10', 'cancer', 'icd11', 'pancreatic'},
#  'Immune system disease  ICD11  4A014B41 ': {'4a014b41',
#   'disease',
#   'icd11',
#   'immune',
#   'system'},
#  'Qualitative platelet defect  ICD11  3B62 ': {'3b62',
#   'defect',
#   'icd11',
#   'platelet',
#   'qualitative'},
#  'Inflammatory spondyloarthritis  ICD11  FA92 ': {'fa92',
#   'icd11',
#   'inflammatory',
#   'spondyloarthritis'},
#  'Inherited coagulation factor deficiency  ICD11  3B14 ': {'3b14',
#   'coagulation',
#   'deficiency',
#   'factor',
#   'icd11',
#   'inherited'},
#  'Spinal pain  ICD11  ME84 ': {'icd11', 'me84', 'pain', 'spinal'},
#  'Migraine  ICD11  8A80 ': {'8a80', 'icd11', 'migraine'},
#  'Myocardial infarction  ICD11  BA41BA43 ': {'ba41ba43',
#   'icd11',
#   'infarction',
#   'myocardial'},
#  'Urinary system disease  ICD11  GC2Z ': {'disease',
#   'gc2z',
#   'icd11',
#   'system',
#   'urinary'},
#  'Otitis media  ICD11  AA80AB0Z ': {'aa80ab0z', 'icd11', 'media', 'otitis'},
#  'Chemotherapy  radiotherapyinduced mucositis  ICD11  DA42DA60 ': {'chemotherapy',
#   'da42da60',
#   'icd11',
#   'mucositis',
#   'radiotherapyinduced'},
#  'Cerebral ischaemia  ICD11  8B1Z ': {'8b1z',
#   'cerebral',
#   'icd11',
#   'ischaemia'},
#  'Female pelvic pain  ICD11  GA34 ': {'female',
#   'ga34',
#   'icd11',
#   'pain',
#   'pelvic'},
#  'Reactive arthropathy  ICD11  FA11 ': {'arthropathy',
#   'fa11',
#   'icd11',
#   'reactive'},
#  'Aneurysm  dissection  ICD11  BD50 ': {'aneurysm',
#   'bd50',
#   'dissection',
#   'icd11'},
#  'Corneal disease  ICD11  9A769A78 ': {'9a769a78',
#   'corneal',
#   'disease',
#   'icd11'},
#  'Restless legs syndrome  ICD11  7A80 ': {'7a80',
#   'icd11',
#   'legs',
#   'restless',
#   'syndrome'},
#  'Autoimmune disease  ICD11  4A404A45 ': {'4a404a45',
#   'autoimmune',
#   'disease',
#   'icd11'},
#  'Bcell lymphoma  ICD11  2A86 ': {'2a86', 'bcell', 'icd11', 'lymphoma'},
#  'Sjogren syndrome  ICD11  4A43 ': {'4a43', 'icd11', 'sjogren', 'syndrome'},
#  'Autonomic nervous system disorder  ICD11  8D87 ': {'8d87',
#   'autonomic',
#   'disorder',
#   'icd11',
#   'nervous',
#   'system'},
#  'Adaptive immunity immunodeficiency  ICD11  4A01 ': {'4a01',
#   'adaptive',
#   'icd11',
#   'immunity',
#   'immunodeficiency'},
#  'Chronic skin disorder  ICD11  ME63 ': {'chronic',
#   'disorder',
#   'icd11',
#   'me63',
#   'skin'},
#  'Pulmonary hypertension  ICD11  BB01 ': {'bb01',
#   'hypertension',
#   'icd11',
#   'pulmonary'},
#  'Cardiac arrhythmia  ICD11  BC9Z ': {'arrhythmia',
#   'bc9z',
#   'cardiac',
#   'icd11'},
#  'Dental disease  ICD11  DA08 ': {'da08', 'dental', 'disease', 'icd11'},
#  'Neuropathy  ICD11  8C0Z ': {'8c0z', 'icd11', 'neuropathy'},
#  'Phlegmy cough  ICD11  SA80SA8Z ': {'cough', 'icd11', 'phlegmy', 'sa80sa8z'},
#  'Myelopathy  ICD11  8B42 ': {'8b42', 'icd11', 'myelopathy'},
#  'Essential hypertension  ICD11  BA00 ': {'ba00',
#   'essential',
#   'hypertension',
#   'icd11'},
#  'Abnormal micturition  ICD11  MF50 ': {'abnormal',
#   'icd11',
#   'mf50',
#   'micturition'},
#  'Ischaemic  haemorrhagic stroke  ICD11  8B20 ': {'8b20',
#   'haemorrhagic',
#   'icd11',
#   'ischaemic',
#   'stroke'},
#  'Psoriatic arthritis  ICD11  FA21 ': {'arthritis',
#   'fa21',
#   'icd11',
#   'psoriatic'},
#  'Trematode disease  ICD11  1F8Y ': {'1f8y', 'disease', 'icd11', 'trematode'},
#  'Cerebral ischaemic stroke  ICD11  8B11 ': {'8b11',
#   'cerebral',
#   'icd11',
#   'ischaemic',
#   'stroke'},
#  'Inborn carbohydrate metabolism error  ICD11  5C51 ': {'5c51',
#   'carbohydrate',
#   'error',
#   'icd11',
#   'inborn',
#   'metabolism'},
#  'Colorectal cancer  ICD11  2B91 ': {'2b91', 'cancer', 'colorectal', 'icd11'},
#  'Metastatic lymph node neoplasm  ICD11  2D60 ': {'2d60',
#   'icd11',
#   'lymph',
#   'metastatic',
#   'neoplasm',
#   'node'},
#  'Viral intestinal infection  ICD11  1A2Z ': {'1a2z',
#   'icd11',
#   'infection',
#   'intestinal',
#   'viral'},
#  'Grampositive bacterial infection  ICD11  1B741F40 ': {'1b741f40',
#   'bacterial',
#   'grampositive',
#   'icd11',
#   'infection'},
#  'Left ventricular failure  ICD11  BD11 ': {'bd11',
#   'failure',
#   'icd11',
#   'left',
#   'ventricular'},
#  'Virus infection  ICD11  1A241D9Z ': {'1a241d9z',
#   'icd11',
#   'infection',
#   'virus'},
#  'Kidney fibrosis  ICD11  GC01 ': {'fibrosis', 'gc01', 'icd11', 'kidney'},
#  'Heart disease  ICD11  BA41BA42 ': {'ba41ba42', 'disease', 'heart', 'icd11'},
#  'Intracranial injury  ICD11  NA07 ': {'icd11',
#   'injury',
#   'intracranial',
#   'na07'},
#  'Kidney failure  ICD11  GB60GB6Z ': {'failure',
#   'gb60gb6z',
#   'icd11',
#   'kidney'},
#  'Digestive system disease  ICD11  DE2Z ': {'de2z',
#   'digestive',
#   'disease',
#   'icd11',
#   'system'},
#  'Duodenal ulcer  ICD11  DA63 ': {'da63', 'duodenal', 'icd11', 'ulcer'},
#  'Pancreatic internal secretion disorder  ICD11  5A4Y ': {'5a4y',
#   'disorder',
#   'icd11',
#   'internal',
#   'pancreatic',
#   'secretion'},
#  'Diagnostic imaging  ICD11  NA  ': {'diagnostic', 'icd11', 'imaging', 'na'},
#  'Gastric ulcer  ICD11  DA60 ': {'da60', 'gastric', 'icd11', 'ulcer'},
#  'Thyroid cancer  ICD11  2D10 ': {'2d10', 'cancer', 'icd11', 'thyroid'},
#  'Gastrooesophageal reflux disease  ICD11  DA22 ': {'da22',
#   'disease',
#   'gastrooesophageal',
#   'icd11',
#   'reflux'},
#  'Pancreatic malfunction  ICD11  DC30DC3Z ': {'dc30dc3z',
#   'icd11',
#   'malfunction',
#   'pancreatic'},
#  'Stomach disease  ICD11  DA43DA4Y ': {'da43da4y',
#   'disease',
#   'icd11',
#   'stomach'},
#  'Dyspepsia  ICD11  MD92 ': {'dyspepsia', 'icd11', 'md92'},
#  'Malignant intestine neoplasm  ICD11  2C0Z ': {'2c0z',
#   'icd11',
#   'intestine',
#   'malignant',
#   'neoplasm'},
#  'Filovirus disease  ICD11  1D60 ': {'1d60', 'disease', 'filovirus', 'icd11'},
#  'Itching  ICD11  1F281G07 ': {'1f281g07', 'icd11', 'itching'},
#  'Ovarian cancer  ICD11  2C73 ': {'2c73', 'cancer', 'icd11', 'ovarian'},
#  'Malignant mesenchymal neoplasm  ICD11  2B5D2B5Y ': {'2b5d2b5y',
#   'icd11',
#   'malignant',
#   'mesenchymal',
#   'neoplasm'},
#  'Peritoneal cancer  ICD11  2C51 ': {'2c51', 'cancer', 'icd11', 'peritoneal'},
#  'Ureteral cancer  ICD11  2C92 ': {'2c92', 'cancer', 'icd11', 'ureteral'},
#  'Cardiac arrest  ICD11  MC82 ': {'arrest', 'cardiac', 'icd11', 'mc82'},
#  'Nonsmall cell lung cancer  ICD11  2C25 ': {'2c25',
#   'cancer',
#   'cell',
#   'icd11',
#   'lung',
#   'nonsmall'},
#  'Myasthenia gravis  ICD11  8C6Y ': {'8c6y', 'gravis', 'icd11', 'myasthenia'},
#  'Acquired cutaneous blood vessel malformation  ICD11  EF20 ': {'acquired',
#   'blood',
#   'cutaneous',
#   'ef20',
#   'icd11',
#   'malformation',
#   'vessel'},
#  'Cerebrovascular disease  ICD11  8B228B2Z ': {'8b228b2z',
#   'cerebrovascular',
#   'disease',
#   'icd11'},
#  'Endometriosis  ICD11  GA10 ': {'endometriosis', 'ga10', 'icd11'},
#  'Ataxic disorder  ICD11  8A03 ': {'8a03', 'ataxic', 'disorder', 'icd11'},
#  'Seborrhoeic dermatitis  ICD11  EA81 ': {'dermatitis',
#   'ea81',
#   'icd11',
#   'seborrhoeic'},
#  'Bladder cancer  ICD11  2C94 ': {'2c94', 'bladder', 'cancer', 'icd11'},
#  'Supraventricular tachyarrhythmia  ICD11  BC81 ': {'bc81',
#   'icd11',
#   'supraventricular',
#   'tachyarrhythmia'},
#  'Follicular lymphoma  ICD11  2A80 ': {'2a80',
#   'follicular',
#   'icd11',
#   'lymphoma'},
#  'Sezary syndrome  ICD11  2B02 ': {'2b02', 'icd11', 'sezary', 'syndrome'},
#  'Mature Tcell lymphoma  ICD11  2A90 ': {'2a90',
#   'icd11',
#   'lymphoma',
#   'mature',
#   'tcell'},
#  'Lymphatic vessel  lymph nodes disorder  ICD11  BD9Z ': {'bd9z',
#   'disorder',
#   'icd11',
#   'lymph',
#   'lymphatic',
#   'nodes',
#   'vessel'},
#  'Retinal inflammation  ICD11  9B72 ': {'9b72',
#   'icd11',
#   'inflammation',
#   'retinal'},
#  'Metabolism inborn error  ICD11  5C50 ': {'5c50',
#   'error',
#   'icd11',
#   'inborn',
#   'metabolism'},
#  'Viral encephalitis  ICD11  1C80 ': {'1c80',
#   'encephalitis',
#   'icd11',
#   'viral'},
#  'Thymoma  ICD11  2C27 ': {'2c27', 'icd11', 'thymoma'},
#  'Adrenal cancer  ICD11  2D11 ': {'2d11', 'adrenal', 'cancer', 'icd11'},
#  'Reversal of the anticoagulant effects of dabigatran  ICD11  NA  ': {'anticoagulant',
#   'dabigatran',
#   'effects',
#   'icd11',
#   'na',
#   'of',
#   'reversal',
#   'the'},
#  'Thrombotic microangiopathy  ICD11  3B65 ': {'3b65',
#   'icd11',
#   'microangiopathy',
#   'thrombotic'},
#  'Hereditary haemolytic anaemia  ICD11  3A10 ': {'3a10',
#   'anaemia',
#   'haemolytic',
#   'hereditary',
#   'icd11'},
#  'Deafness  ICD11  AB52 ': {'ab52', 'deafness', 'icd11'},
#  'Raynaud phenomenon  ICD11  BD42 ': {'bd42',
#   'icd11',
#   'phenomenon',
#   'raynaud'},
#  'Leishmaniasis  ICD11  1F54 ': {'1f54', 'icd11', 'leishmaniasis'},
#  'Aplastic anaemia  ICD11  3A70 ': {'3a70', 'anaemia', 'aplastic', 'icd11'},
#  'Autoimmune liver disease  ICD11  DB96 ': {'autoimmune',
#   'db96',
#   'disease',
#   'icd11',
#   'liver'},
#  'Urinary tract infection  ICD11  GC08 ': {'gc08',
#   'icd11',
#   'infection',
#   'tract',
#   'urinary'},
#  'Cognition symptoms  signs  clinical sympton  ICD11  MB21 ': {'clinical',
#   'cognition',
#   'icd11',
#   'mb21',
#   'signs',
#   'symptoms',
#   'sympton'},
#  'Alopecia  ICD11  ED70 ': {'alopecia', 'ed70', 'icd11'},
#  'Thrombocytosis  ICD11  3B63 ': {'3b63', 'icd11', 'thrombocytosis'},
#  'Acquired hypomelanotic disorder  ICD11  ED63 ': {'acquired',
#   'disorder',
#   'ed63',
#   'hypomelanotic',
#   'icd11'},
#  'Disseminated intravascular coagulation  ICD11  3B20 ': {'3b20',
#   'coagulation',
#   'disseminated',
#   'icd11',
#   'intravascular'},
#  'Bronchiectasis  ICD11  CA24 ': {'bronchiectasis', 'ca24', 'icd11'},
#  'Adrenocortical insufficiency  ICD11  5A74 ': {'5a74',
#   'adrenocortical',
#   'icd11',
#   'insufficiency'},
#  'Status epilepticus  ICD11  8A66 ': {'8a66',
#   'epilepticus',
#   'icd11',
#   'status'},
#  'Tremorrelated disorder  ICD11  8A04 ': {'8a04',
#   'disorder',
#   'icd11',
#   'tremorrelated'},
#  'Mental  behavioural  neurodevelopmental disorder  ICD11  6E206E8Z ': {'6e206e8z',
#   'behavioural',
#   'disorder',
#   'icd11',
#   'mental',
#   'neurodevelopmental'},
#  'Skin disease  ICD11  EA00EM0Z ': {'disease', 'ea00em0z', 'icd11', 'skin'},
#  'Infectious meningitis  ICD11  1D01 ': {'1d01',
#   'icd11',
#   'infectious',
#   'meningitis'},
#  'Meningococcal disease  ICD11  1C1C ': {'1c1c',
#   'disease',
#   'icd11',
#   'meningococcal'},
#  'Sarcoidosis  ICD11  4B20 ': {'4b20', 'icd11', 'sarcoidosis'},
#  'Functional bladder disorder  ICD11  GC50 ': {'bladder',
#   'disorder',
#   'functional',
#   'gc50',
#   'icd11'},
#  'Lips  oral mucosa miscellaneous disorder  ICD11  DA02 ': {'da02',
#   'disorder',
#   'icd11',
#   'lips',
#   'miscellaneous',
#   'mucosa',
#   'oral'},
#  'Cataract  ICD11  9B10 ': {'9b10', 'cataract', 'icd11'},
#  'Addictive disorder  ICD11  6C506C5Z ': {'6c506c5z',
#   'addictive',
#   'disorder',
#   'icd11'},
#  'Irritable bowel syndrome  ICD11  DD91 ': {'bowel',
#   'dd91',
#   'icd11',
#   'irritable',
#   'syndrome'},
#  'Colon cancer  ICD11  2B90 ': {'2b90', 'cancer', 'colon', 'icd11'},
#  'Parasitic infection  ICD11  1D0Y1G2Z ': {'1d0y1g2z',
#   'icd11',
#   'infection',
#   'parasitic'},
#  'Genetic prion disease  ICD11  8E02 ': {'8e02',
#   'disease',
#   'genetic',
#   'icd11',
#   'prion'},
#  'Gastrointestinal stromal tumour  ICD11  2B5B ': {'2b5b',
#   'gastrointestinal',
#   'icd11',
#   'stromal',
#   'tumour'},
#  'Esophageal cancer  ICD11  2B70 ': {'2b70', 'cancer', 'esophageal', 'icd11'},
#  'Secondary hypertension  ICD11  BA04 ': {'ba04',
#   'hypertension',
#   'icd11',
#   'secondary'},
#  'Zoster  ICD11  1E91 ': {'1e91', 'icd11', 'zoster'},
#  'Oral mucositis  ICD11  DA01 ': {'da01', 'icd11', 'mucositis', 'oral'},
#  'Retina cancer  ICD11  2D02 ': {'2d02', 'cancer', 'icd11', 'retina'},
#  'Female infertility  ICD11  GA31 ': {'female',
#   'ga31',
#   'icd11',
#   'infertility'},
#  'Male infertility  ICD11  GB04 ': {'gb04', 'icd11', 'infertility', 'male'},
#  'Bone paget disease  ICD11  FB85 ': {'bone',
#   'disease',
#   'fb85',
#   'icd11',
#   'paget'},
#  'Nail  perionychium infection  ICD11  EE12 ': {'ee12',
#   'icd11',
#   'infection',
#   'nail',
#   'perionychium'},
#  'Mycobacterium infection  ICD11  1B101B21 ': {'1b101b21',
#   'icd11',
#   'infection',
#   'mycobacterium'},
#  'Onchocerciasis  ICD11  1F6A ': {'1f6a', 'icd11', 'onchocerciasis'},
#  'Female genital tract inflammatory disorder  ICD11  GA0Z ': {'disorder',
#   'female',
#   'ga0z',
#   'genital',
#   'icd11',
#   'inflammatory',
#   'tract'},
#  'Congenital myopathy  ICD11  8C72 ': {'8c72',
#   'congenital',
#   'icd11',
#   'myopathy'},
#  'Metabolic disorder  ICD11  5C505D2Z ': {'5c505d2z',
#   'disorder',
#   'icd11',
#   'metabolic'},
#  'Hypoosmolality  hyponatraemia  ICD11  5C72 ': {'5c72',
#   'hyponatraemia',
#   'hypoosmolality',
#   'icd11'},
#  'Skin and skinstructure infection  ICD11  1F281G0Z ': {'1f281g0z',
#   'and',
#   'icd11',
#   'infection',
#   'skin',
#   'skinstructure'},
#  'Acute disease anaemia  ICD11  3A90 ': {'3a90',
#   'acute',
#   'anaemia',
#   'disease',
#   'icd11'},
#  'Graftversushost disease  ICD11  4B24 ': {'4b24',
#   'disease',
#   'graftversushost',
#   'icd11'},
#  'Sicklecell disorder  ICD11  3A51 ': {'3a51',
#   'disorder',
#   'icd11',
#   'sicklecell'},
#  'Insomnia  ICD11  7A007A0Z ': {'7a007a0z', 'icd11', 'insomnia'},
#  'Testicular dysfunction  ICD11  5A81 ': {'5a81',
#   'dysfunction',
#   'icd11',
#   'testicular'},
#  'Prostate hyperplasia  ICD11  GA90 ': {'ga90',
#   'hyperplasia',
#   'icd11',
#   'prostate'},
#  'Alcoholic liver disease  ICD11  DB94 ': {'alcoholic',
#   'db94',
#   'disease',
#   'icd11',
#   'liver'},
#  'Contraceptive management  ICD11  QA21 ': {'contraceptive',
#   'icd11',
#   'management',
#   'qa21'},
#  'Oesophagitis  ICD11  DA24 ': {'da24', 'icd11', 'oesophagitis'},
#  'Cachexia  ICD11  MG20 ': {'cachexia', 'icd11', 'mg20'},
#  'Acne vulgaris  ICD11  ED80 ': {'acne', 'ed80', 'icd11', 'vulgaris'},
#  'Mammary tumour  ICD11  2C602C6Z ': {'2c602c6z',
#   'icd11',
#   'mammary',
#   'tumour'},
#  'Nephritic syndrome  ICD11  GB40 ': {'gb40',
#   'icd11',
#   'nephritic',
#   'syndrome'},
#  'Musculoskeletal system  connective tissue disease  ICD11  FC0Z ': {'connective',
#   'disease',
#   'fc0z',
#   'icd11',
#   'musculoskeletal',
#   'system',
#   'tissue'},
#  'Bone cancer  ICD11  2B5Z ': {'2b5z', 'bone', 'cancer', 'icd11'},
#  'Opioid use disorder  ICD11  6C43 ': {'6c43',
#   'disorder',
#   'icd11',
#   'opioid',
#   'use'},
#  'Squamous cell carcinoma  ICD11  2B602D01 ': {'2b602d01',
#   'carcinoma',
#   'cell',
#   'icd11',
#   'squamous'},
#  'Spine  trunk injury  ICD11  ND51 ': {'icd11',
#   'injury',
#   'nd51',
#   'spine',
#   'trunk'},
#  'Bodyfocused behaviour disorder  ICD11  6B25 ': {'6b25',
#   'behaviour',
#   'bodyfocused',
#   'disorder',
#   'icd11'},
#  'Prurigo  ICD11  EC91 ': {'ec91', 'icd11', 'prurigo'},
#  'Liver disease  ICD11  DB90DB9Z ': {'db90db9z', 'disease', 'icd11', 'liver'},
#  'Social anxiety disorder  ICD11  6B04 ': {'6b04',
#   'anxiety',
#   'disorder',
#   'icd11',
#   'social'},
#  'Light sensitivity impairment  ICD11  9D45 ': {'9d45',
#   'icd11',
#   'impairment',
#   'light',
#   'sensitivity'},
#  'Kinetoplastids  ICD11  1F611G2Z ': {'1f611g2z', 'icd11', 'kinetoplastids'},
#  'Rosacea  ICD11  ED90 ': {'ed90', 'icd11', 'rosacea'},
#  'Bleeding disorder  ICD11  GA20GA21 ': {'bleeding',
#   'disorder',
#   'ga20ga21',
#   'icd11'},
#  'Pulmonary thromboembolism  ICD11  BB00 ': {'bb00',
#   'icd11',
#   'pulmonary',
#   'thromboembolism'},
#  'Synovial sarcoma  ICD11  2B5A ': {'2b5a', 'icd11', 'sarcoma', 'synovial'},
#  'Extremities vasodilatation  ICD11  EG00 ': {'eg00',
#   'extremities',
#   'icd11',
#   'vasodilatation'},
#  'Radiculopathy  ICD11  8B93 ': {'8b93', 'icd11', 'radiculopathy'},
#  'Trigeminal nerve disorder  ICD11  8B82 ': {'8b82',
#   'disorder',
#   'icd11',
#   'nerve',
#   'trigeminal'},
#  'Obsessivecompulsive disorder  ICD11  6B20 ': {'6b20',
#   'disorder',
#   'icd11',
#   'obsessivecompulsive'},
#  'Sexually transmitted infection  ICD11  1A9Y1A9Z ': {'1a9y1a9z',
#   'icd11',
#   'infection',
#   'sexually',
#   'transmitted'},
#  'Ovarian dysfunction  ICD11  5A80 ': {'5a80',
#   'dysfunction',
#   'icd11',
#   'ovarian'},
#  'Ovarian developmental anomaly  ICD11  LB45 ': {'anomaly',
#   'developmental',
#   'icd11',
#   'lb45',
#   'ovarian'},
#  'Uterine fibroid  ICD11  2E86 ': {'2e86', 'fibroid', 'icd11', 'uterine'},
#  'Ventricular tachyarrhythmia  ICD11  BC71 ': {'bc71',
#   'icd11',
#   'tachyarrhythmia',
#   'ventricular'},
#  'Premature ageing appearance  ICD11  LD2B ': {'ageing',
#   'appearance',
#   'icd11',
#   'ld2b',
#   'premature'},
#  'Nutritional deficiency  ICD11  5B505B71 ': {'5b505b71',
#   'deficiency',
#   'icd11',
#   'nutritional'},
#  'Cushing syndrome  ICD11  5A70 ': {'5a70', 'cushing', 'icd11', 'syndrome'},
#  'Ocular cancer  ICD11  2D002D07 ': {'2d002d07', 'cancer', 'icd11', 'ocular'},
#  'Stimulants use disorder  ICD11  6C46 ': {'6c46',
#   'disorder',
#   'icd11',
#   'stimulants',
#   'use'},
#  'Inflammatory liver disease  ICD11  DB97 ': {'db97',
#   'disease',
#   'icd11',
#   'inflammatory',
#   'liver'},
#  'Kaposi sarcoma  ICD11  2B57 ': {'2b57', 'icd11', 'kaposi', 'sarcoma'},
#  'Pyoderma gangrenosum  ICD11  EB21 ': {'eb21',
#   'gangrenosum',
#   'icd11',
#   'pyoderma'},
#  'Cutaneous lupus erythematosus  ICD11  EB50EB5Z ': {'cutaneous',
#   'eb50eb5z',
#   'erythematosus',
#   'icd11',
#   'lupus'},
#  'Type1  2 diabete  ICD11  5A105A11 ': {'2',
#   '5a105a11',
#   'diabete',
#   'icd11',
#   'type1'},
#  'Cytomegaloviral disease  ICD11  1D82 ': {'1d82',
#   'cytomegaloviral',
#   'disease',
#   'icd11'},
#  'Clostridium difficile enterocolitis  ICD11  1A04 ': {'1a04',
#   'clostridium',
#   'difficile',
#   'enterocolitis',
#   'icd11'},
#  'Retinal vascular occlusion  ICD11  9B74 ': {'9b74',
#   'icd11',
#   'occlusion',
#   'retinal',
#   'vascular'},
#  'Metastatic biliary tract neoplasms  ICD11  2C142C17 ': {'2c142c17',
#   'biliary',
#   'icd11',
#   'metastatic',
#   'neoplasms',
#   'tract'},
#  'Testicular cancer  ICD11  2C80 ': {'2c80', 'cancer', 'icd11', 'testicular'},
#  'Spinal cord  cranial nerve neoplasm  ICD11  2A02 ': {'2a02',
#   'cord',
#   'cranial',
#   'icd11',
#   'neoplasm',
#   'nerve',
#   'spinal'},
#  'Head and neck cancer  ICD11  2D42 ': {'2d42',
#   'and',
#   'cancer',
#   'head',
#   'icd11',
#   'neck'},
#  'Malignant digestive organ neoplasm  ICD11  2C11 ': {'2c11',
#   'digestive',
#   'icd11',
#   'malignant',
#   'neoplasm',
#   'organ'},
#  'Urogenital cancer  ICD11  2C952C9Z ': {'2c952c9z',
#   'cancer',
#   'icd11',
#   'urogenital'},
#  'Metastatic malignant neoplasm  ICD11  2D502E09 ': {'2d502e09',
#   'icd11',
#   'malignant',
#   'metastatic',
#   'neoplasm'},
#  'Von Willebrand disease  ICD11  3B12 ': {'3b12',
#   'disease',
#   'icd11',
#   'von',
#   'willebrand'},
#  'Venous thromboembolism  ICD11  BD72 ': {'bd72',
#   'icd11',
#   'thromboembolism',
#   'venous'},
#  'Therapeutic intestinal toxicity  ICD11  DA94 ': {'da94',
#   'icd11',
#   'intestinal',
#   'therapeutic',
#   'toxicity'},
#  'Vasculitis  ICD11  4A44 ': {'4a44', 'icd11', 'vasculitis'},
#  'Degenerative high myopia  ICD11  9B76 ': {'9b76',
#   'degenerative',
#   'high',
#   'icd11',
#   'myopia'},
#  'Vitamin  nonprotein cofactor absorption  transport disorder  ICD11  5C63 ': {'5c63',
#   'absorption',
#   'cofactor',
#   'disorder',
#   'icd11',
#   'nonprotein',
#   'transport',
#   'vitamin'},
#  'Pleural mesothelioma  ICD11  2C26 ': {'2c26',
#   'icd11',
#   'mesothelioma',
#   'pleural'},
#  'Orthostatic hypotension  ICD11  BA21 ': {'ba21',
#   'hypotension',
#   'icd11',
#   'orthostatic'},
#  'Thyrotoxicosis  ICD11  5A02 ': {'5a02', 'icd11', 'thyrotoxicosis'},
#  'Haemolytic anemia  ICD11  3A203A2Z ': {'3a203a2z',
#   'anemia',
#   'haemolytic',
#   'icd11'},
#  'Toxicity  ICD11  NA  ': {'icd11', 'na', 'toxicity'},
#  'Lip  oral cavity  pharynx neoplasm  ICD11  2B6E ': {'2b6e',
#   'cavity',
#   'icd11',
#   'lip',
#   'neoplasm',
#   'oral',
#   'pharynx'},
#  'Metastatic liver  bile duct neoplasm  ICD11  2D80 ': {'2d80',
#   'bile',
#   'duct',
#   'icd11',
#   'liver',
#   'metastatic',
#   'neoplasm'},
#  'Inborn energy metabolism error  ICD11  5C53 ': {'5c53',
#   'energy',
#   'error',
#   'icd11',
#   'inborn',
#   'metabolism'},
#  'Ischemia  ICD11  8B108B11 ': {'8b108b11', 'icd11', 'ischemia'},
#  'Obstructive sleep apnoea  ICD11  7A41 ': {'7a41',
#   'apnoea',
#   'icd11',
#   'obstructive',
#   'sleep'},
#  'Neutropenia  ICD11  4B00 ': {'4b00', 'icd11', 'neutropenia'},
#  'Strongyloidiasis  ICD11  1F6B ': {'1f6b', 'icd11', 'strongyloidiasis'},
#  'Headache  ICD11  8A808A84 ': {'8a808a84', 'headache', 'icd11'},
#  'Hidradenitis suppurativa  ICD11  ED92 ': {'ed92',
#   'hidradenitis',
#   'icd11',
#   'suppurativa'},
#  'Nonalcoholic fatty liver disease  ICD11  DB92 ': {'db92',
#   'disease',
#   'fatty',
#   'icd11',
#   'liver',
#   'nonalcoholic'},
#  'concerning food  fluid intake symptom  ICD11  MG43 ': {'concerning',
#   'fluid',
#   'food',
#   'icd11',
#   'intake',
#   'mg43',
#   'symptom'},
#  'Metastatic peritoneum neoplasm  ICD11  2D91 ': {'2d91',
#   'icd11',
#   'metastatic',
#   'neoplasm',
#   'peritoneum'},
#  'Ascites  ICD11  ME04 ': {'ascites', 'icd11', 'me04'},
#  'Ewing sarcoma  ICD11  2B52 ': {'2b52', 'ewing', 'icd11', 'sarcoma'},
#  'Pemphigoid  ICD11  EB41 ': {'eb41', 'icd11', 'pemphigoid'},
#  'Cough  ICD11  MD12 ': {'cough', 'icd11', 'md12'},
#  'Pregnancy  childbirth  puerperium maternal infection  ICD11  JB63 ': {'childbirth',
#   'icd11',
#   'infection',
#   'jb63',
#   'maternal',
#   'pregnancy',
#   'puerperium'},
#  'Toxoplasmosis  ICD11  1F57 ': {'1f57', 'icd11', 'toxoplasmosis'},
#  'Tuberculosis  ICD11  1B101B12 ': {'1b101b12', 'icd11', 'tuberculosis'},
#  'Nasopharyngitis  ICD11  CA00 ': {'ca00', 'icd11', 'nasopharyngitis'},
#  'Episodic vestibular syndrome  ICD11  AB31 ': {'ab31',
#   'episodic',
#   'icd11',
#   'syndrome',
#   'vestibular'},
#  'Macular degeneration  ICD11  9B75 ': {'9b75',
#   'degeneration',
#   'icd11',
#   'macular'},
#  'Vision impairment  ICD11  9D90 ': {'9d90', 'icd11', 'impairment', 'vision'},
#  'Ischaemic heart disease  ICD11  BA6Z ': {'ba6z',
#   'disease',
#   'heart',
#   'icd11',
#   'ischaemic'},
#  'Cardiomegaly  ICD11  BC45 ': {'bc45', 'cardiomegaly', 'icd11'},
#  'Genitourinary disease  ICD11  GA0ZGC8Z ': {'disease',
#   'ga0zgc8z',
#   'genitourinary',
#   'icd11'},
#  'Arenavirus disease  ICD11  1D61 ': {'1d61',
#   'arenavirus',
#   'disease',
#   'icd11'},
#  'Encephalopathy  ICD11  8E47 ': {'8e47', 'encephalopathy', 'icd11'},
#  'Hyperhidrosis  ICD11  EE00 ': {'ee00', 'hyperhidrosis', 'icd11'},
#  'Tic disorder  ICD11  8A05 ': {'8a05', 'disorder', 'icd11', 'tic'},
#  'Rectum cancer  ICD11  2B92 ': {'2b92', 'cancer', 'icd11', 'rectum'},
#  'Vitreoretinopathy  ICD11  9B78 ': {'9b78', 'icd11', 'vitreoretinopathy'},
#  'Folate deficiency anaemia  ICD11  3A02 ': {'3a02',
#   'anaemia',
#   'deficiency',
#   'folate',
#   'icd11'},
#  'Skin postprocedural disorder  ICD11  EL8Y ': {'disorder',
#   'el8y',
#   'icd11',
#   'postprocedural',
#   'skin'},
#  'Injury  ICD11  NA00ND5Z ': {'icd11', 'injury', 'na00nd5z'},
#  'Dengue fever  ICD11  1D2Z ': {'1d2z', 'dengue', 'fever', 'icd11'},
#  'Ulcer  ICD11  CA02CB40 ': {'ca02cb40', 'icd11', 'ulcer'},
#  'Flatworm infection  ICD11  1F701F86 ': {'1f701f86',
#   'flatworm',
#   'icd11',
#   'infection'},
#  'Sarcoma  ICD11  2A602C35 ': {'2a602c35', 'icd11', 'sarcoma'},
#  'Multiple structural anomalies syndrome  ICD11  LD2F ': {'anomalies',
#   'icd11',
#   'ld2f',
#   'multiple',
#   'structural',
#   'syndrome'},
#  'Pleural effusion  ICD11  CB27 ': {'cb27', 'effusion', 'icd11', 'pleural'},
#  'Pancreatitis  ICD11  DC31DC34 ': {'dc31dc34', 'icd11', 'pancreatitis'},
#  'Infectious gastroenteritis  colitis  ICD11  1A40 ': {'1a40',
#   'colitis',
#   'gastroenteritis',
#   'icd11',
#   'infectious'},
#  'Pemphigus  ICD11  EB40 ': {'eb40', 'icd11', 'pemphigus'},
#  'Sleepwake disorder  ICD11  7A007B2Z ': {'7a007b2z',
#   'disorder',
#   'icd11',
#   'sleepwake'},
#  'Phakomatoses  hamartoneoplastic syndrome  ICD11  LD2D ': {'hamartoneoplastic',
#   'icd11',
#   'ld2d',
#   'phakomatoses',
#   'syndrome'},
#  'Glanders  ICD11  1B92 ': {'1b92', 'glanders', 'icd11'},
#  'Hypopharyngeal cancer  ICD11  2B6D ': {'2b6d',
#   'cancer',
#   'hypopharyngeal',
#   'icd11'},
#  'Vascular system developmental anomaly  ICD11  LA90 ': {'anomaly',
#   'developmental',
#   'icd11',
#   'la90',
#   'system',
#   'vascular'},
#  'Bone growth disorder  ICD11  FB86 ': {'bone',
#   'disorder',
#   'fb86',
#   'growth',
#   'icd11'},
#  'Transient ischaemic attack  ICD11  8B10 ': {'8b10',
#   'attack',
#   'icd11',
#   'ischaemic',
#   'transient'},
#  'Impetigo  ICD11  1B72 ': {'1b72', 'icd11', 'impetigo'},
#  'Adrenomedullary hyperfunction  ICD11  5A75 ': {'5a75',
#   'adrenomedullary',
#   'hyperfunction',
#   'icd11'},
#  'Acute laryngitis  tracheitis  ICD11  CA05 ': {'acute',
#   'ca05',
#   'icd11',
#   'laryngitis',
#   'tracheitis'},
#  'Intracerebral haemorrhage  ICD11  8B00 ': {'8b00',
#   'haemorrhage',
#   'icd11',
#   'intracerebral'},
#  'Retina disorder  ICD11  9B709B7Z ': {'9b709b7z',
#   'disorder',
#   'icd11',
#   'retina'},
#  'Acute pain  ICD11  MG31 ': {'acute', 'icd11', 'mg31', 'pain'},
#  'Fatigue  ICD11  MG22 ': {'fatigue', 'icd11', 'mg22'},
#  'Endocrine disease  ICD11  5B3Z ': {'5b3z', 'disease', 'endocrine', 'icd11'},
#  'Abortion  ICD11  JA00 ': {'abortion', 'icd11', 'ja00'},
#  'Staphylococcal  streptococcal disease  ICD11  1B5Y ': {'1b5y',
#   'disease',
#   'icd11',
#   'staphylococcal',
#   'streptococcal'},
#  'Gonococcal infection  ICD11  1A701A7Z ': {'1a701a7z',
#   'gonococcal',
#   'icd11',
#   'infection'},
#  'Bronchitis  ICD11  CA20 ': {'bronchitis', 'ca20', 'icd11'},
#  'Joint direct infection  ICD11  FA10 ': {'direct',
#   'fa10',
#   'icd11',
#   'infection',
#   'joint'},
#  'Conjunctiva disorder  ICD11  9A60 ': {'9a60',
#   'conjunctiva',
#   'disorder',
#   'icd11'},
#  'Digestive organ benign neoplasm  ICD11  2E92 ': {'2e92',
#   'benign',
#   'digestive',
#   'icd11',
#   'neoplasm',
#   'organ'},
#  'Diabetic foot ulcer  ICD11  BD54 ': {'bd54',
#   'diabetic',
#   'foot',
#   'icd11',
#   'ulcer'},
#  'Escherichia coli intestinal infection  ICD11  1A03 ': {'1a03',
#   'coli',
#   'escherichia',
#   'icd11',
#   'infection',
#   'intestinal'},
#  'Angiosarcoma  ICD11  2B56 ': {'2b56', 'angiosarcoma', 'icd11'},
#  'Gynecologic cancer  ICD11  2F332F76 ': {'2f332f76',
#   'cancer',
#   'gynecologic',
#   'icd11'},
#  'Emphysema  ICD11  CA21 ': {'ca21', 'emphysema', 'icd11'},
#  'Anterior uveitis  ICD11  9A96 ': {'9a96', 'anterior', 'icd11', 'uveitis'},
#  'Preterm labour  delivery  ICD11  JB00 ': {'delivery',
#   'icd11',
#   'jb00',
#   'labour',
#   'preterm'},
#  'Female genital system disease  ICD11  GA6Z ': {'disease',
#   'female',
#   'ga6z',
#   'genital',
#   'icd11',
#   'system'},
#  'Menstrual cycle bleeding disorder  ICD11  GA20 ': {'bleeding',
#   'cycle',
#   'disorder',
#   'ga20',
#   'icd11',
#   'menstrual'},
#  'Head injury  ICD11  NA00NA0Z ': {'head', 'icd11', 'injury', 'na00na0z'},
#  'Anaerobic bacterial infection  ICD11  1A001A09 ': {'1a001a09',
#   'anaerobic',
#   'bacterial',
#   'icd11',
#   'infection'},
#  'Intracranial embolism  ICD11  8B22 ': {'8b22',
#   'embolism',
#   'icd11',
#   'intracranial'},
#  'Increased intracranial pressure  ICD11  8D60 ': {'8d60',
#   'icd11',
#   'increased',
#   'intracranial',
#   'pressure'},
#  'Coronary vasospastic disease  ICD11  BA85 ': {'ba85',
#   'coronary',
#   'disease',
#   'icd11',
#   'vasospastic'},
#  'Sensation disturbance  ICD11  MB40 ': {'disturbance',
#   'icd11',
#   'mb40',
#   'sensation'},
#  'Enzyme deficiency  ICD11  5C515C57 ': {'5c515c57',
#   'deficiency',
#   'enzyme',
#   'icd11'},
#  'Chronic lower extremities peripheral venous insufficiency  ICD11  BD74 ': {'bd74',
#   'chronic',
#   'extremities',
#   'icd11',
#   'insufficiency',
#   'lower',
#   'peripheral',
#   'venous'},
#  'Hemangioma  ICD11  2E812F2Y ': {'2e812f2y', 'hemangioma', 'icd11'},
#  'Gallbladder  bile ducts  liver structural developmental anomaly  ICD11  LB20 ': {'anomaly',
#   'bile',
#   'developmental',
#   'ducts',
#   'gallbladder',
#   'icd11',
#   'lb20',
#   'liver',
#   'structural'},
#  'Inborn porphyrin  heme metabolism error  ICD11  5C58 ': {'5c58',
#   'error',
#   'heme',
#   'icd11',
#   'inborn',
#   'metabolism',
#   'porphyrin'},
#  'Spontaneous urticaria  ICD11  EB00 ': {'eb00',
#   'icd11',
#   'spontaneous',
#   'urticaria'},
#  'Varicose veins  ICD11  BD74BD75 ': {'bd74bd75',
#   'icd11',
#   'varicose',
#   'veins'},
#  'Keratosis pilaris  ICD11  ED56 ': {'ed56', 'icd11', 'keratosis', 'pilaris'},
#  'Neonatal hyperbilirubinaemia  ICD11  KA87 ': {'hyperbilirubinaemia',
#   'icd11',
#   'ka87',
#   'neonatal'},
#  'Visual system disease  ICD11  9E1Z ': {'9e1z',
#   'disease',
#   'icd11',
#   'system',
#   'visual'},
#  'Sex development malformative disorder  ICD11  LD2A ': {'development',
#   'disorder',
#   'icd11',
#   'ld2a',
#   'malformative',
#   'sex'},
#  'Autism spectrum disorder  ICD11  6A02 ': {'6a02',
#   'autism',
#   'disorder',
#   'icd11',
#   'spectrum'},
#  'Intentional selfharm  ICD11  PC91 ': {'icd11',
#   'intentional',
#   'pc91',
#   'selfharm'},
#  'Gingival disease  ICD11  DA0B ': {'da0b', 'disease', 'gingival', 'icd11'},
#  'Hirsutism  ICD11  ED72 ': {'ed72', 'hirsutism', 'icd11'},
#  'Smallpox  ICD11  1E70 ': {'1e70', 'icd11', 'smallpox'},
#  'Ischemic heart disease  ICD11  BA40BA6Z ': {'ba40ba6z',
#   'disease',
#   'heart',
#   'icd11',
#   'ischemic'},
#  'Ejaculatory dysfunction  ICD11  HA03 ': {'dysfunction',
#   'ejaculatory',
#   'ha03',
#   'icd11'},
#  'Soft tissue disorder  ICD11  FB56 ': {'disorder',
#   'fb56',
#   'icd11',
#   'soft',
#   'tissue'},
#  'Neurobehavioral disorder  ICD11  8A008A0Z ': {'8a008a0z',
#   'disorder',
#   'icd11',
#   'neurobehavioral'},
#  'Menopausal disorder  ICD11  GA30 ': {'disorder',
#   'ga30',
#   'icd11',
#   'menopausal'},
#  'Anthrax  ICD11  1B97 ': {'1b97', 'anthrax', 'icd11'},
#  'Cystitis  ICD11  GC00 ': {'cystitis', 'gc00', 'icd11'},
#  'Bladder disorder  ICD11  GC01 ': {'bladder', 'disorder', 'gc01', 'icd11'},
#  'Labour  delivery anaesthesia complication  ICD11  JB0C ': {'anaesthesia',
#   'complication',
#   'delivery',
#   'icd11',
#   'jb0c',
#   'labour'},
#  'Panic disorder  ICD11  6B01 ': {'6b01', 'disorder', 'icd11', 'panic'},
#  'Fragile X chromosome  ICD11  LD55 ': {'chromosome',
#   'fragile',
#   'icd11',
#   'ld55',
#   'x'},
#  'Mood  affect symptom  ICD11  MB24 ': {'affect',
#   'icd11',
#   'mb24',
#   'mood',
#   'symptom'},
#  'Sebaceous gland disorder  ICD11  ED91 ': {'disorder',
#   'ed91',
#   'gland',
#   'icd11',
#   'sebaceous'},
#  'Intellectual development disorder  ICD11  LD90 ': {'development',
#   'disorder',
#   'icd11',
#   'intellectual',
#   'ld90'},
#  'Epileptic encephalopathy  ICD11  8A62 ': {'8a62',
#   'encephalopathy',
#   'epileptic',
#   'icd11'},
#  'Schizoaffective disorder  ICD11  6A21 ': {'6a21',
#   'disorder',
#   'icd11',
#   'schizoaffective'},
#  'Abdominal pelvic pain  ICD11  MD81 ': {'abdominal',
#   'icd11',
#   'md81',
#   'pain',
#   'pelvic'},
#  'Dystonic disorder  ICD11  8A02 ': {'8a02', 'disorder', 'dystonic', 'icd11'},
#  'Keloid  hypertrophic scar  ICD11  EE60 ': {'ee60',
#   'hypertrophic',
#   'icd11',
#   'keloid',
#   'scar'},
#  'Scabies  ICD11  1G04 ': {'1g04', 'icd11', 'scabies'},
#  'Postpartum haemorrhage  ICD11  JA43 ': {'haemorrhage',
#   'icd11',
#   'ja43',
#   'postpartum'},
#  'Oesophagogastric junction cancer  ICD11  2B71 ': {'2b71',
#   'cancer',
#   'icd11',
#   'junction',
#   'oesophagogastric'},
#  'Epidermolysis bullosa  ICD11  EC3Z ': {'bullosa',
#   'ec3z',
#   'epidermolysis',
#   'icd11'},
#  'Vaccination  ICD11  NA  ': {'icd11', 'na', 'vaccination'},
#  'Pediculosis  ICD11  1G00 ': {'1g00', 'icd11', 'pediculosis'},
#  'Parasitic worm infestation  ICD11  1F90 ': {'1f90',
#   'icd11',
#   'infestation',
#   'parasitic',
#   'worm'},
#  'Oesophageal  gastroduodenal disorder  ICD11  DD90 ': {'dd90',
#   'disorder',
#   'gastroduodenal',
#   'icd11',
#   'oesophageal'},
#  'Biliary tract cancer  ICD11  2C17 ': {'2c17',
#   'biliary',
#   'cancer',
#   'icd11',
#   'tract'},
#  'Chronic myelomonocytic leukaemia  ICD11  2A40 ': {'2a40',
#   'chronic',
#   'icd11',
#   'leukaemia',
#   'myelomonocytic'},
#  'Hyperkalaemia  ICD11  5C76 ': {'5c76', 'hyperkalaemia', 'icd11'},
#  'Hydrocephalus  ICD11  8D64 ': {'8d64', 'hydrocephalus', 'icd11'},
#  'Trichuriasis  ICD11  1F6G ': {'1f6g', 'icd11', 'trichuriasis'},
#  'Nematode disease  ICD11  1F6Y ': {'1f6y', 'disease', 'icd11', 'nematode'},
#  'Hypoglycaemia  ICD11  5A41 ': {'5a41', 'hypoglycaemia', 'icd11'},
#  'Eyelid inflammatory disorder  ICD11  9A02 ': {'9a02',
#   'disorder',
#   'eyelid',
#   'icd11',
#   'inflammatory'},
#  'Breathing abnormality  ICD11  MD11 ': {'abnormality',
#   'breathing',
#   'icd11',
#   'md11'},
#  'Optic nerve disorder  ICD11  9C40 ': {'9c40',
#   'disorder',
#   'icd11',
#   'nerve',
#   'optic'},
#  'Peroxisomal disease  ICD11  5C57 ': {'5c57',
#   'disease',
#   'icd11',
#   'peroxisomal'},
#  'Lichen planus  ICD11  EA91 ': {'ea91', 'icd11', 'lichen', 'planus'},
#  'Synthesis disorder  ICD11  5C525C59 ': {'5c525c59',
#   'disorder',
#   'icd11',
#   'synthesis'},
#  'Contact dermatitis  ICD11  EK00EK0Z ': {'contact',
#   'dermatitis',
#   'ek00ek0z',
#   'icd11'},
#  'Idiopathic inflammatory myopathy  ICD11  4A41 ': {'4a41',
#   'icd11',
# ...
#   'microvascular'},
#  'Skeletal anomaly  ICD11  LD24 ': {'anomaly', 'icd11', 'ld24', 'skeletal'},
#  'Cholelithiasis  ICD11  DC11 ': {'cholelithiasis', 'dc11', 'icd11'},
#  'Small intestine developmental anomaly  ICD11  DA90 ': {'anomaly',
#   'da90',
#   'developmental',
#   'icd11',
#   'intestine',
#   'small'},
#  'Oesophageal ulcer  ICD11  DA25 ': {'da25', 'icd11', 'oesophageal', 'ulcer'},
#  'Helicobacter infection  ICD11  DA42DA63 ': {'da42da63',
#   'helicobacter',
#   'icd11',
#   'infection'},
#  'Lung structural developmental anomaly  ICD11  LA75 ': {'anomaly',
#   'developmental',
#   'icd11',
#   'la75',
#   'lung',
#   'structural'},
#  'Oedema  ICD11  MG29 ': {'icd11', 'mg29', 'oedema'},
#  'Endocarditis  ICD11  BB40BA42 ': {'bb40ba42', 'endocarditis', 'icd11'},
#  'CNS anomalies syndrome  ICD11  LD20 ': {'anomalies',
#   'cns',
#   'icd11',
#   'ld20',
#   'syndrome'},
#  'Sleeprelated breathing disorder  ICD11  7A4Z ': {'7a4z',
#   'breathing',
#   'disorder',
#   'icd11',
#   'sleeprelated'},
#  'Infants  toddlers  children functional digestive disorder  ICD11  DD93 ': {'children',
#   'dd93',
#   'digestive',
#   'disorder',
#   'functional',
#   'icd11',
#   'infants',
#   'toddlers'},
#  'Postoperative ileus  ICD11  DA91DB30 ': {'da91db30',
#   'icd11',
#   'ileus',
#   'postoperative'},
#  'Stress  ICD11  6B406B45 ': {'6b406b45', 'icd11', 'stress'},
#  'Endocrine gland neoplasm  ICD11  2F37 ': {'2f37',
#   'endocrine',
#   'gland',
#   'icd11',
#   'neoplasm'},
#  'Blood  bloodforming organ sympton  ICD11  MA14 ': {'blood',
#   'bloodforming',
#   'icd11',
#   'ma14',
#   'organ',
#   'sympton'},
#  'Vaginal discharge  ICD11  MF3A ': {'discharge', 'icd11', 'mf3a', 'vaginal'},
#  'Syphilis  ICD11  1A611A6Z ': {'1a611a6z', 'icd11', 'syphilis'},
#  'Trypanosomiasis  ICD11  1D511F53 ': {'1d511f53', 'icd11', 'trypanosomiasis'},
#  'Dysplasia  ICD11  LB30LD2F ': {'dysplasia', 'icd11', 'lb30ld2f'},
#  'Genital organ in situ carcinoma  ICD11  2E67 ': {'2e67',
#   'carcinoma',
#   'genital',
#   'icd11',
#   'in',
#   'organ',
#   'situ'},
#  'Cervical intraepithelial neoplasia  ICD11  2E66 ': {'2e66',
#   'cervical',
#   'icd11',
#   'intraepithelial',
#   'neoplasia'},
#  'Retinal detachment  ICD11  9B73 ': {'9b73',
#   'detachment',
#   'icd11',
#   'retinal'},
#  'Joint lubricant  ICD11  FA30FA38 ': {'fa30fa38',
#   'icd11',
#   'joint',
#   'lubricant'},
#  'Enthesopathy  ICD11  FB53FB55 ': {'enthesopathy', 'fb53fb55', 'icd11'},
#  'Monitored anaesthesia care  ICD11  NA  ': {'anaesthesia',
#   'care',
#   'icd11',
#   'monitored',
#   'na'},
#  'Appearance  behaviour symptom  ICD11  MB23 ': {'appearance',
#   'behaviour',
#   'icd11',
#   'mb23',
#   'symptom'},
#  'Pervasive developmental disorder  ICD11  6A006A0Z ': {'6a006a0z',
#   'developmental',
#   'disorder',
#   'icd11',
#   'pervasive'},
#  'Burn and burn infection  ICD11  ND90NE2Z ': {'and',
#   'burn',
#   'icd11',
#   'infection',
#   'nd90ne2z'},
#  'Precursor Blymphoblastic neoplasm  ICD11  2A70 ': {'2a70',
#   'blymphoblastic',
#   'icd11',
#   'neoplasm',
#   'precursor'},
#  'Neuromyelitis optica  ICD11  8A43 ': {'8a43',
#   'icd11',
#   'neuromyelitis',
#   'optica'},
#  'Nervous system paraneoplastic  autoimmune disorder  ICD11  8E4A ': {'8e4a',
#   'autoimmune',
#   'disorder',
#   'icd11',
#   'nervous',
#   'paraneoplastic',
#   'system'},
#  'Lipidaemia  ICD11  5C8Z ': {'5c8z', 'icd11', 'lipidaemia'},
#  'Aortic valve stenosis  ICD11  BB70 ': {'aortic',
#   'bb70',
#   'icd11',
#   'stenosis',
#   'valve'},
#  'Dermatophytosis  ICD11  1F28 ': {'1f28', 'dermatophytosis', 'icd11'},
#  'Respiratory failure  ICD11  CB41 ': {'cb41',
#   'failure',
#   'icd11',
#   'respiratory'},
#  'Periodontal disease  ICD11  DA0C ': {'da0c',
#   'disease',
#   'icd11',
#   'periodontal'},
#  'Urethral cancer  ICD11  2C93 ': {'2c93', 'cancer', 'icd11', 'urethral'},
#  'Cryptosporidiosis  ICD11  1A32 ': {'1a32', 'cryptosporidiosis', 'icd11'},
#  'Small intestine motility disorder  ICD11  DA93 ': {'da93',
#   'disorder',
#   'icd11',
#   'intestine',
#   'motility',
#   'small'},
#  'Anorexia nervosa  ICD11  6B80 ': {'6b80', 'anorexia', 'icd11', 'nervosa'},
#  'Old age  ICD11  MG2A ': {'age', 'icd11', 'mg2a', 'old'},
#  'Penile cancer  ICD11  2C81 ': {'2c81', 'cancer', 'icd11', 'penile'},
#  'Uterine ligament  parametrium  uterine adnexa neoplasm  ICD11  2C72 ': {'2c72',
#   'adnexa',
#   'icd11',
#   'ligament',
#   'neoplasm',
#   'parametrium',
#   'uterine'},
#  'Childbirth associated breast  lactation disorder  ICD11  JB46 ': {'associated',
#   'breast',
#   'childbirth',
#   'disorder',
#   'icd11',
#   'jb46',
#   'lactation'},
#  'Joint derangement  ICD11  FA34 ': {'derangement', 'fa34', 'icd11', 'joint'},
#  'Urinary  pelvic organs injury  ICD11  NB92 ': {'icd11',
#   'injury',
#   'nb92',
#   'organs',
#   'pelvic',
#   'urinary'},
#  'Fever  ICD11  MG26 ': {'fever', 'icd11', 'mg26'},
#  'Shoulder lesion  ICD11  FB53 ': {'fb53', 'icd11', 'lesion', 'shoulder'},
#  'Hypothyroidism  ICD11  5A00 ': {'5a00', 'hypothyroidism', 'icd11'},
#  'Osteopathy  chondropathy  ICD11  FB8Y ': {'chondropathy',
#   'fb8y',
#   'icd11',
#   'osteopathy'},
#  'Whooping cough  ICD11  1C12 ': {'1c12', 'cough', 'icd11', 'whooping'},
#  'Acute viral hepatitis  ICD11  1E50 ': {'1e50',
#   'acute',
#   'hepatitis',
#   'icd11',
#   'viral'},
#  'Meningioma  ICD11  2A01 ': {'2a01', 'icd11', 'meningioma'},
#  'Gingival  edentulous alveolar ridge disorder  ICD11  DA0D ': {'alveolar',
#   'da0d',
#   'disorder',
#   'edentulous',
#   'gingival',
#   'icd11',
#   'ridge'},
#  'Acquired methaemoglobinaemia  ICD11  3A93 ': {'3a93',
#   'acquired',
#   'icd11',
#   'methaemoglobinaemia'},
#  'Neurotransmitter metabolic error  ICD11  5C59 ': {'5c59',
#   'error',
#   'icd11',
#   'metabolic',
#   'neurotransmitter'},
#  'Anal cancer  ICD11  2C00 ': {'2c00', 'anal', 'cancer', 'icd11'},
#  'Delayed methotrexate clearance  ICD11  NA  ': {'clearance',
#   'delayed',
#   'icd11',
#   'methotrexate',
#   'na'},
#  'Preprocedural examination  ICD11  QA0B ': {'examination',
#   'icd11',
#   'preprocedural',
#   'qa0b'},
#  'CNS nonviral infection  ICD11  1D0Y ': {'1d0y',
#   'cns',
#   'icd11',
#   'infection',
#   'nonviral'},
#  'Heart beat abnormality  ICD11  MC81 ': {'abnormality',
#   'beat',
#   'heart',
#   'icd11',
#   'mc81'},
#  'Osteosarcoma  ICD11  2B51 ': {'2b51', 'icd11', 'osteosarcoma'},
#  'Ascariasis  ICD11  1F62 ': {'1f62', 'ascariasis', 'icd11'},
#  'Enterobiasis  ICD11  1F65 ': {'1f65', 'enterobiasis', 'icd11'},
#  'Eexposure to noxious substances harmful effect  ICD11  NE61 ': {'eexposure',
#   'effect',
#   'harmful',
#   'icd11',
#   'ne61',
#   'noxious',
#   'substances',
#   'to'},
#  'Vaginitis  ICD11  GA02 ': {'ga02', 'icd11', 'vaginitis'},
#  'Adenocarcinoma  ICD11  2D40 ': {'2d40', 'adenocarcinoma', 'icd11'},
#  'Schistosomiasis  ICD11  1F86 ': {'1f86', 'icd11', 'schistosomiasis'},
#  'Enuresis  ICD11  6C00 ': {'6c00', 'enuresis', 'icd11'},
#  'Polyuria  ICD11  MF55 ': {'icd11', 'mf55', 'polyuria'},
#  'Knee osteoarthritis  ICD11  FA01 ': {'fa01',
#   'icd11',
#   'knee',
#   'osteoarthritis'},
#  'Large intestine polyp  ICD11  DB35 ': {'db35',
#   'icd11',
#   'intestine',
#   'large',
#   'polyp'},
#  'Hyperaemia  ICD11  9A619B7Y ': {'9a619b7y', 'hyperaemia', 'icd11'},
#  'Faecal incontinence  ICD11  ME07 ': {'faecal',
#   'icd11',
#   'incontinence',
#   'me07'},
#  'Gangrene  ICD11  MC85 ': {'gangrene', 'icd11', 'mc85'},
#  'Overgrowth syndrome  ICD11  LD2C ': {'icd11',
#   'ld2c',
#   'overgrowth',
#   'syndrome'},
#  'LambertEaton syndrome  ICD11  8C62 ': {'8c62',
#   'icd11',
#   'lamberteaton',
#   'syndrome'},
#  'Deep vein thrombosis  ICD11  BD71 ': {'bd71',
#   'deep',
#   'icd11',
#   'thrombosis',
#   'vein'},
#  'Myotonic disorder  ICD11  8C71 ': {'8c71', 'disorder', 'icd11', 'myotonic'},
#  'Chondrosarcoma  ICD11  2B50 ': {'2b50', 'chondrosarcoma', 'icd11'},
#  'Nervous system disease  ICD11  8A008E7Z ': {'8a008e7z',
#   'disease',
#   'icd11',
#   'nervous',
#   'system'},
#  'Thought content symptom  ICD11  MB26 ': {'content',
#   'icd11',
#   'mb26',
#   'symptom',
#   'thought'},
#  'Dizziness and giddiness  ICD11  MB48 ': {'and',
#   'dizziness',
#   'giddiness',
#   'icd11',
#   'mb48'},
#  'Lipoatrophy  lipodystrophy  ICD11  EF01 ': {'ef01',
#   'icd11',
#   'lipoatrophy',
#   'lipodystrophy'},
#  'Hypertensive crisis  ICD11  BA03 ': {'ba03',
#   'crisis',
#   'hypertensive',
#   'icd11'},
#  'Eyelid inflammatory  movement disorder  ICD11  9A05 ': {'9a05',
#   'disorder',
#   'eyelid',
#   'icd11',
#   'inflammatory',
#   'movement'},
#  'Anal fissure  fistula  ICD11  DB50 ': {'anal',
#   'db50',
#   'fissure',
#   'fistula',
#   'icd11'},
#  'Acute  subacute hepatic failure  ICD11  DB91 ': {'acute',
#   'db91',
#   'failure',
#   'hepatic',
#   'icd11',
#   'subacute'},
#  'Gramnegative bacterial infection  ICD11  1F411G40 ': {'1f411g40',
#   'bacterial',
#   'gramnegative',
#   'icd11',
#   'infection'},
#  'Pituitary hypofunction  ICD11  5A61 ': {'5a61',
#   'hypofunction',
#   'icd11',
#   'pituitary'},
#  'Infancy  childhood primary interstitial lung disease  ICD11  CB04 ': {'cb04',
#   'childhood',
#   'disease',
#   'icd11',
#   'infancy',
#   'interstitial',
#   'lung',
#   'primary'},
#  'Aspergillosis  ICD11  1F20 ': {'1f20', 'aspergillosis', 'icd11'},
#  'Coronary thrombosis  ICD11  BA43 ': {'ba43',
#   'coronary',
#   'icd11',
#   'thrombosis'},
#  'Tinnitus  ICD11  MC41 ': {'icd11', 'mc41', 'tinnitus'},
#  'kidney  ureter disorder  ICD11  GB90 ': {'disorder',
#   'gb90',
#   'icd11',
#   'kidney',
#   'ureter'},
#  'Nondermatophyte superficial dermatomycose  ICD11  1F2D ': {'1f2d',
#   'dermatomycose',
#   'icd11',
#   'nondermatophyte',
#   'superficial'},
#  'Abnormal urine serum electrolytes level  ICD11  MF98 ': {'abnormal',
#   'electrolytes',
#   'icd11',
#   'level',
#   'mf98',
#   'serum',
#   'urine'},
#  'Lymphangioleiomyomatosis  ICD11  CB07 ': {'cb07',
#   'icd11',
#   'lymphangioleiomyomatosis'},
#  'Brain disease  ICD11  8C708E61 ': {'8c708e61', 'brain', 'disease', 'icd11'},
#  'Cannabis use disorder  ICD11  6C41 ': {'6c41',
#   'cannabis',
#   'disorder',
#   'icd11',
#   'use'},
#  'Radionuclide imaging  ICD11  NA  ': {'icd11',
#   'imaging',
#   'na',
#   'radionuclide'},
#  'Morning sickness disorder  ICD11  SC00 ': {'disorder',
#   'icd11',
#   'morning',
#   'sc00',
#   'sickness'},
#  'Insecticide  ICD11  NA  ': {'icd11', 'insecticide', 'na'},
#  'Pulmonary eosinophilia  ICD11  CB02 ': {'cb02',
#   'eosinophilia',
#   'icd11',
#   'pulmonary'},
#  'Juvenile idiopathic arthritis  ICD11  FA24 ': {'arthritis',
#   'fa24',
#   'icd11',
#   'idiopathic',
#   'juvenile'},
#  'Skin  mucosal anomaly  ICD11  LD27 ': {'anomaly',
#   'icd11',
#   'ld27',
#   'mucosal',
#   'skin'},
#  'Episode  ICD11  NA  ': {'episode', 'icd11', 'na'},
#  'Localisation  ICD11  NA  ': {'icd11', 'localisation', 'na'},
#  'Intermittent explosive disorder  ICD11  6C73 ': {'6c73',
#   'disorder',
#   'explosive',
#   'icd11',
#   'intermittent'},
#  'Nystagmus  ICD11  9C84 ': {'9c84', 'icd11', 'nystagmus'},
#  'Gastritis  ICD11  DA42 ': {'da42', 'gastritis', 'icd11'},
#  'Urgency  ICD11  NA  ': {'icd11', 'na', 'urgency'},
#  'General examination  ICD11  QA00 ': {'examination',
#   'general',
#   'icd11',
#   'qa00'},
#  'Irregularities  ICD11  NA  ': {'icd11', 'irregularities', 'na'},
#  'Hearing disorder  ICD11  AB50AB57 ': {'ab50ab57',
#   'disorder',
#   'hearing',
#   'icd11'},
#  'Muscle calcification  ossification  ICD11  FB31 ': {'calcification',
#   'fb31',
#   'icd11',
#   'muscle',
#   'ossification'},
#  'Kidney malfunction  ICD11  MG02 ': {'icd11',
#   'kidney',
#   'malfunction',
#   'mg02'},
#  'Autosomal dominant polycystic kidney disease  ICD11  GB81 ': {'autosomal',
#   'disease',
#   'dominant',
#   'gb81',
#   'icd11',
#   'kidney',
#   'polycystic'},
#  'Primary psychotic disorder manifestation  ICD11  6A25 ': {'6a25',
#   'disorder',
#   'icd11',
#   'manifestation',
#   'primary',
#   'psychotic'},
#  'Lower limb mononeuropathy  ICD11  8C11 ': {'8c11',
#   'icd11',
#   'limb',
#   'lower',
#   'mononeuropathy'},
#  'Esophagus sensitivity  ICD11  DA2YDA2Z ': {'da2yda2z',
#   'esophagus',
#   'icd11',
#   'sensitivity'},
#  'Hyperaldosteronism  ICD11  5A72 ': {'5a72', 'hyperaldosteronism', 'icd11'},
#  'Bloodforming organ disease  ICD11  3C0Z ': {'3c0z',
#   'bloodforming',
#   'disease',
#   'icd11',
#   'organ'},
#  'Necrotising fasciitis  ICD11  1B71 ': {'1b71',
#   'fasciitis',
#   'icd11',
#   'necrotising'},
#  'Chemoprotection  ICD11  NA  ': {'chemoprotection', 'icd11', 'na'},
#  'Leiomyosarcoma  ICD11  2B58 ': {'2b58', 'icd11', 'leiomyosarcoma'},
#  'Myelofibrosis  ICD11  2A22 ': {'2a22', 'icd11', 'myelofibrosis'},
#  'Focal  segmental autonomic disorder  ICD11  8D8A ': {'8d8a',
#   'autonomic',
#   'disorder',
#   'focal',
#   'icd11',
#   'segmental'},
#  'Hyperlipidemia  ICD11  5C80 ': {'5c80', 'hyperlipidemia', 'icd11'},
#  'Antiphospholipid syndrome  ICD11  4A45 ': {'4a45',
#   'antiphospholipid',
#   'icd11',
#   'syndrome'},
#  'Desmoid tumour  ICD11  2F7C ': {'2f7c', 'desmoid', 'icd11', 'tumour'},
#  'Dystrophic epidermolysis bullosa  ICD11  EC32 ': {'bullosa',
#   'dystrophic',
#   'ec32',
#   'epidermolysis',
#   'icd11'},
#  'Mesothelin positive tumour  ICD11  2C512F10 ': {'2c512f10',
#   'icd11',
#   'mesothelin',
#   'positive',
#   'tumour'},
#  'Metastatic pleura neoplasm  ICD11  2D72 ': {'2d72',
#   'icd11',
#   'metastatic',
#   'neoplasm',
#   'pleura'},
#  'Mesothelial tumour  ICD11  2F10 ': {'2f10',
#   'icd11',
#   'mesothelial',
#   'tumour'},
#  'Rheumatic fever  ICD11  1B40 ': {'1b40', 'fever', 'icd11', 'rheumatic'},
#  'Subarachnoid haemorrhage  ICD11  8B01 ': {'8b01',
#   'haemorrhage',
#   'icd11',
#   'subarachnoid'},
#  'Ophthalmic devices  implants  grafts injury  ICD11  PK97 ': {'devices',
#   'grafts',
#   'icd11',
#   'implants',
#   'injury',
#   'ophthalmic',
#   'pk97'},
#  'Eye disorder  ICD11  9A019A0Z ': {'9a019a0z', 'disorder', 'eye', 'icd11'},
#  'Atrophy  ICD11  9A2Y9C40 ': {'9a2y9c40', 'atrophy', 'icd11'},
#  'Acquired prion disease  ICD11  8E01 ': {'8e01',
#   'acquired',
#   'disease',
#   'icd11',
#   'prion'},
#  'Dyspareunia  ICD11  GA12 ': {'dyspareunia', 'ga12', 'icd11'},
#  'Female genital tract noninflammatory disorder  ICD11  GA1Y ': {'disorder',
#   'female',
#   'ga1y',
#   'genital',
#   'icd11',
#   'noninflammatory',
#   'tract'},
#  'Breast in situ carcinoma  ICD11  2E65 ': {'2e65',
#   'breast',
#   'carcinoma',
#   'icd11',
#   'in',
#   'situ'},
#  'Choroidal dystrophy  ICD11  9B61 ': {'9b61',
#   'choroidal',
#   'dystrophy',
#   'icd11'},
#  'Vitreous body disorder  ICD11  9B8Z ': {'9b8z',
#   'body',
#   'disorder',
#   'icd11',
#   'vitreous'},
#  'Blood chemistry clinical sympton  ICD11  MA18 ': {'blood',
#   'chemistry',
#   'clinical',
#   'icd11',
#   'ma18',
#   'sympton'},
#  'Hypokalaemia  ICD11  5C77 ': {'5c77', 'hypokalaemia', 'icd11'},
#  'Paroxysmal nocturnal haemoglobinuria  ICD11  3A21 ': {'3a21',
#   'haemoglobinuria',
#   'icd11',
#   'nocturnal',
#   'paroxysmal'},
#  'Amino acid absorption  transport disorder  ICD11  5C60 ': {'5c60',
#   'absorption',
#   'acid',
#   'amino',
#   'disorder',
#   'icd11',
#   'transport'},
#  'Nail plate acquired deformity  ICD11  EE10 ': {'acquired',
#   'deformity',
#   'ee10',
#   'icd11',
#   'nail',
#   'plate'},
#  'Metastatic lung neoplasm  ICD11  2D70 ': {'2d70',
#   'icd11',
#   'lung',
#   'metastatic',
#   'neoplasm'},
#  'Anogenital warts  ICD11  1A95 ': {'1a95', 'anogenital', 'icd11', 'warts'},
#  'Pneumococcal infection  ICD11  CA00CA40 ': {'ca00ca40',
#   'icd11',
#   'infection',
#   'pneumococcal'},
#  'Skin pigmentation genetic disorder  ICD11  EC23 ': {'disorder',
#   'ec23',
#   'genetic',
#   'icd11',
#   'pigmentation',
#   'skin'},
#  'Acquired melanotic macule  lentigine  ICD11  ED61 ': {'acquired',
#   'ed61',
#   'icd11',
#   'lentigine',
#   'macule',
#   'melanotic'},
#  'Lesion  ICD11  8A008C12 ': {'8a008c12', 'icd11', 'lesion'},
#  'Fragrance  cosmetics phototoxic reaction  ICD11  EK20 ': {'cosmetics',
#   'ek20',
#   'fragrance',
#   'icd11',
#   'phototoxic',
#   'reaction'},
#  'Irritant contact dermatitis  ICD11  EK02 ': {'contact',
#   'dermatitis',
#   'ek02',
#   'icd11',
#   'irritant'},
#  'Parathyroid disease  ICD11  5A505A5Z ': {'5a505a5z',
#   'disease',
#   'icd11',
#   'parathyroid'},
#  'Idiopathic multicentric Castlemans disease  ICD11  2A81 ': {'2a81',
#   'castlemans',
#   'disease',
#   'icd11',
#   'idiopathic',
#   'multicentric'},
#  'Advanced  metastatic breast cancer  ICD11  2C60 ': {'2c60',
#   'advanced',
#   'breast',
#   'cancer',
#   'icd11',
#   'metastatic'},
#  'Arthropathy  ICD11  FA11FA5Z ': {'arthropathy', 'fa11fa5z', 'icd11'},
#  'Postviral fatigue syndrome  ICD11  8E49 ': {'8e49',
#   'fatigue',
#   'icd11',
#   'postviral',
#   'syndrome'},
#  'Pleomorphic sarcoma  ICD11  2B54 ': {'2b54',
#   'icd11',
#   'pleomorphic',
#   'sarcoma'},
#  '': set()}

# %% [markdown]
# ### Functions to match diaseases and genes from test.json and TTD

# %%
# conventional transformation for genes from sentences and from TTD
def process_gene(gene):
    words = gene.lower().split()
    for i in range(len(words)):
        if words[i] == 's':
            words[i] = words[i][:-1]
            
    return words


# gene match rool: all first gene words are included in second set or vice versa
def check_genes_intesection(gene0, gene1):
    
    return len(set(gene0) & set(gene1)) == min(len(gene0), len(gene0))
    
    
# find matches between 2 gene sets for the same disease (from different sources)
def check_gene_sets_intersection(genes0, genes1):

    intersection_dict = {}
    
    for gene0 in genes0:
        gene0_processed = process_gene(gene0)
        for gene1 in genes1:
            gene1_processed = process_gene(gene1)
            same = check_genes_intesection(gene0_processed, gene1_processed)
            if same:
                if gene0 in intersection_dict:
                    intersection_dict[gene0].append(gene1)
                else:
                    intersection_dict[gene0] = [gene1]
    return intersection_dict


# compare 2 disease names and decide if they different version of the same disease
def check_diseases_intersection(disease0_words, disease1_words):
    n_words = min(len(disease0_words), len(disease1_words))
    intersection = len(disease_words & disease_words_ttd) == n_words
    return intersection


# for each target of the disease find target_id from TTD
def get_disease_result(disease0, disease0_words, disease1, disease1_words):
    result = []
    intersection = check_diseases_intersection(disease0_words, disease1_words)
    if intersection:
        intersection_dict = check_gene_sets_intersection(disease2genes[disease0], disease2genes_ttd[disease1])
        for gene, genes1 in intersection_dict.items():
            for  gene1 in genes1:
                result.append([disease0, gene, t_name2t_id[gene1]])
    return result

# %%
all_data = []

for disease, disease_words in disease_word_sets.items():
    for disease_ttd, disease_words_ttd in disease_word_sets_ttd.items():
        data = get_disease_result(disease, disease_words, disease_ttd, disease_words_ttd)
        if len(data):
            all_data.extend(data)
            
            
df = pd.DataFrame(all_data, columns=['disease', 'target', 'ttd_target_id'])

# %%
df.head()
# Out:
#                        disease                              target  \
# 0  Acute myocardial infarction           endothelial growth factor
# 1  Acute myocardial infarction  vascular endothelial growth factor
# 2          Psoriatic arthritis                      Protein kinase
# 3          Psoriatic arthritis                            cytokine
# 4       Chronic kidney disease                      protein kinase
#
#   ttd_target_id
# 0        T99993
# 1        T99993
# 2        T06093
# 3        T06542
# 4        T51282

# %%
df.to_csv('matched_target_id.csv')

# %%
df['ttd_target_name'] = df['ttd_target_id'].map(lambda x: t_id2t_meta[x][0])
df['ttd_diseases_set'] = df['ttd_target_id'].map(lambda x: t_id2t_meta[x][1])

# %%
df.head()
# Out:
#                        disease                              target  \
# 0  Acute myocardial infarction           endothelial growth factor
# 1  Acute myocardial infarction  vascular endothelial growth factor
# 2          Psoriatic arthritis                      Protein kinase
# 3          Psoriatic arthritis                            cytokine
# 4       Chronic kidney disease                      protein kinase
#
#   ttd_target_id                                  ttd_target_name  \
# 0        T99993  HUMAN vascular endothelial growth factor (VEGF)
# 1        T99993  HUMAN vascular endothelial growth factor (VEGF)
# 2        T06093          Rho-associated protein kinase 2 (ROCK2)
# 3        T06542                            Cytokine ML-1 (IL17F)
# 4        T51282          Rho-associated protein kinase 1 (ROCK1)
#
#                                     ttd_diseases_set
# 0  {COVID19  ICD11  1D6Y , Colorectal cancer  ICD...
# 1  {COVID19  ICD11  1D6Y , Colorectal cancer  ICD...
# 2  {Rheumatoid arthritis  ICD11  FA20 , Chronic o...
# 3  {Psoriasis  ICD11  EA90 , Psoriatic arthritis ...
# 4  {Pulmonary hypertension  ICD11  BB01 , Chronic...

# %%
df.to_csv('matched_target_meta.csv')

# %%
len(set(df['disease']))
# Out:
# 46

# %% [markdown]
# ## Conclusion
#
# * Targets are mached with TTD only for 46 diseases
# * Matching rule (disease to disease and gene 2 gene) should be replaced with embedding based comparison
